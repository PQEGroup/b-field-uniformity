# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 14 main
# n = 14
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 14
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [19.29085902053344, 157.07978656853243]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 76
# [7.036978355110895, 210.31493620462103]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 58
#          Function evaluations: 122
# [12.085183266870182, 247.76835954853402]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 96
# [18.45659294247781, 148.52354367147856]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 46
#          Function evaluations: 96
# [11.696292039576793, 162.7365088124966]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 96
# [7.643941020220893, 66.58805395215133]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 80
# [16.492241997566346, 281.9306308901141]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 87
# [10.795532855146991, 212.24683745822088]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 47
#          Function evaluations: 97
# [13.08944897812718, 243.28908757199792]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 88
# [5.265021846667755, 80.58373921109214]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 62
#          Function evaluations: 159
# [3.694195674097619, 149.67514862201315]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 47
#          Function evaluations: 111
# [12.652676403966616, 263.4558209420278]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 94
# [13.411773839459629, 252.18018645569344]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 86
# [19.174644217626675, 237.93845395842803]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 87
# [15.395252598138011, 156.8273490049027]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 87
# [17.804435919422335, 298.0611722420099]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 96
# [19.813016175058145, 157.06767185754282]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 82
# [18.972606232906944, 92.11468351993958]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 28
#          Function evaluations: 62
# [10.312202301345492, 247.54651780019705]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 58
#          Function evaluations: 114
# [12.747924849099766, 186.29287094062548]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 86
# [19.23797676792585, 70.36370922290719]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 55
# [3.600828942304149, 138.50234724184526]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 52
#          Function evaluations: 109
# [7.832829137653749, 238.03216108300802]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 112
# [7.0240311033777045, 212.04497182796092]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 61
#          Function evaluations: 127
# [18.101394914173643, 238.00677003206764]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 85
# Objective function values:
# [1.6269735120082439e-07, 1.62697228385314e-07, 1.6269728513801319e-07, 1.6269733547542232e-07, 1.6269729440035007e-07, 1.6269728292172313e-07, 1.6269729216595392e-07, 1.626973702991414e-07, 1.6269784878577515e-07, 1.6327007115590123e-07, 1.632786255131344e-07, 1.6269730153126777e-07, 1.6269735302301518e-07, 1.6269729402572765e-07, 1.6269734294999368e-07, 1.6269731686019846e-07, 1.6269728427704737e-07, 1.6269741579345098e-07, 1.6269731412691912e-07, 1.626973351542481e-07, 1.6269738578821994e-07, 1.6269732672117283e-07, 1.6269729488088165e-07, 1.626975454282995e-07, 1.6269733519377609e-07]
# Result parameters:
# [array([20.        , 68.39451791]), array([20.        , 68.39590756]), array([20.        , 68.39479362]), array([20.        , 68.39413348]), array([20.        , 68.39696628]), array([20.        , 68.39333444]), array([20.        , 68.39342434]), array([20.        , 68.39577542]), array([19.99110834, 68.39965363]), array([ 6.18819793, 68.40058758]), array([ 5.71290061, 68.37334075]), array([20.        , 68.39599566]), array([20.        , 68.40175461]), array([20.        , 68.39227269]), array([20.        , 68.39255901]), array([20.        , 68.39231937]), array([20.        , 68.39383071]), array([20.        , 68.40234897]), array([20.        , 68.39261482]), array([20.        , 68.39677712]), array([20.        , 68.39503708]), array([20.        , 68.39544206]), array([20.       , 68.3938102]), array([19.99628181, 68.39308304]), array([20.        , 68.39637585])]
# Starting guesses:
# [[19.29085902053344, 157.07978656853243], [7.036978355110895, 210.31493620462103], [12.085183266870182, 247.76835954853402], [18.45659294247781, 148.52354367147856], [11.696292039576793, 162.7365088124966], [7.643941020220893, 66.58805395215133], [16.492241997566346, 281.9306308901141], [10.795532855146991, 212.24683745822088], [13.08944897812718, 243.28908757199792], [5.265021846667755, 80.58373921109214], [3.694195674097619, 149.67514862201315], [12.652676403966616, 263.4558209420278], [13.411773839459629, 252.18018645569344], [19.174644217626675, 237.93845395842803], [15.395252598138011, 156.8273490049027], [17.804435919422335, 298.0611722420099], [19.813016175058145, 157.06767185754282], [18.972606232906944, 92.11468351993958], [10.312202301345492, 247.54651780019705], [12.747924849099766, 186.29287094062548], [19.23797676792585, 70.36370922290719], [3.600828942304149, 138.50234724184526], [7.832829137653749, 238.03216108300802], [7.0240311033777045, 212.04497182796092], [18.101394914173643, 238.00677003206764]]

# %%
print(results_x)
# Out:
# [array([20.        , 68.39451791]), array([20.        , 68.39590756]), array([20.        , 68.39479362]), array([20.        , 68.39413348]), array([20.        , 68.39696628]), array([20.        , 68.39333444]), array([20.        , 68.39342434]), array([20.        , 68.39577542]), array([19.99110834, 68.39965363]), array([ 6.18819793, 68.40058758]), array([ 5.71290061, 68.37334075]), array([20.        , 68.39599566]), array([20.        , 68.40175461]), array([20.        , 68.39227269]), array([20.        , 68.39255901]), array([20.        , 68.39231937]), array([20.        , 68.39383071]), array([20.        , 68.40234897]), array([20.        , 68.39261482]), array([20.        , 68.39677712]), array([20.        , 68.39503708]), array([20.        , 68.39544206]), array([20.       , 68.3938102]), array([19.99628181, 68.39308304]), array([20.        , 68.39637585])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 14).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [6524.108127033524, 6523.842993727022, 6524.055522611053, 6524.181475406376, 6523.641010227904, 6524.3339347088095, 6524.316782347519, 6523.868205503064, 6517.329501995123, 624.4712083220462, 532.651875594972, 6523.826186405937, 6522.727606182063, 6524.536528849508, 6524.481895378148, 6524.527622162719, 6524.239245179831, 6522.61424174917, 6524.471245294331, 6523.677098983007, 6524.009071072264, 6523.931805283374, 6524.243156905821, 6521.956239012875, 6523.753652965108]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [1.6269735120082439e-07, 1.62697228385314e-07, 1.6269728513801319e-07, 1.6269733547542232e-07, 1.6269729440035007e-07, 1.6269728292172313e-07, 1.6269729216595392e-07, 1.626973702991414e-07, 1.6269784878577515e-07, 1.6327007115590123e-07, 1.632786255131344e-07, 1.6269730153126777e-07, 1.6269735302301518e-07, 1.6269729402572765e-07, 1.6269734294999368e-07, 1.6269731686019846e-07, 1.6269728427704737e-07, 1.6269741579345098e-07, 1.6269731412691912e-07, 1.626973351542481e-07, 1.6269738578821994e-07, 1.6269732672117283e-07, 1.6269729488088165e-07, 1.626975454282995e-07, 1.6269733519377609e-07]
# [1.6269735120082439e-07, 1.62697228385314e-07, 1.6269728513801319e-07, 1.6269733547542232e-07, 1.6269729440035007e-07, 1.6269728292172313e-07, 1.6269729216595392e-07, 1.626973702991414e-07, 1.6269784878577515e-07, 1.6327007115590123e-07, 1.632786255131344e-07, 1.6269730153126777e-07, 1.6269735302301518e-07, 1.6269729402572765e-07, 1.6269734294999368e-07, 1.6269731686019846e-07, 1.6269728427704737e-07, 1.6269741579345098e-07, 1.6269731412691912e-07, 1.626973351542481e-07, 1.6269738578821994e-07, 1.6269732672117283e-07, 1.6269729488088165e-07, 1.626975454282995e-07, 1.6269733519377609e-07]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/14/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    1.626972e-07         6523.842994    14.0       640.0     20.000000
# 1    1.626973e-07         6524.333935    14.0       640.0     20.000000
# 2    1.626973e-07         6524.239245    14.0       640.0     20.000000
# 3    1.626973e-07         6524.055523    14.0       640.0     20.000000
# 4    1.626973e-07         6524.316782    14.0       640.0     20.000000
# 5    1.626973e-07         6524.536529    14.0       640.0     20.000000
# 6    1.626973e-07         6523.641010    14.0       640.0     20.000000
# 7    1.626973e-07         6524.243157    14.0       640.0     20.000000
# 8    1.626973e-07         6523.826186    14.0       640.0     20.000000
# 9    1.626973e-07         6524.471245    14.0       640.0     20.000000
# 10   1.626973e-07         6524.527622    14.0       640.0     20.000000
# 11   1.626973e-07         6523.931805    14.0       640.0     20.000000
# 12   1.626973e-07         6523.677099    14.0       640.0     20.000000
# 13   1.626973e-07         6523.753653    14.0       640.0     20.000000
# 14   1.626973e-07         6524.181475    14.0       640.0     20.000000
# 15   1.626973e-07         6524.481895    14.0       640.0     20.000000
# 16   1.626974e-07         6524.108127    14.0       640.0     20.000000
# 17   1.626974e-07         6522.727606    14.0       640.0     20.000000
# 18   1.626974e-07         6523.868206    14.0       640.0     20.000000
# 19   1.626974e-07         6524.009071    14.0       640.0     20.000000
# 20   1.626974e-07         6522.614242    14.0       640.0     20.000000
# 21   1.626975e-07         6521.956239    14.0       640.0     19.996282
# 22   1.626978e-07         6517.329502    14.0       640.0     19.991108
# 23   1.632701e-07          624.471208    14.0       640.0      6.188198
# 24   1.632786e-07          532.651876    14.0       640.0      5.712901
#
#             D  g_cyl_diameter         g_D
# 0   68.395908        7.036978  210.314936
# 1   68.393334        7.643941   66.588054
# 2   68.393831       19.813016  157.067672
# 3   68.394794       12.085183  247.768360
# 4   68.393424       16.492242  281.930631
# 5   68.392273       19.174644  237.938454
# 6   68.396966       11.696292  162.736509
# 7   68.393810        7.832829  238.032161
# 8   68.395996       12.652676  263.455821
# 9   68.392615       10.312202  247.546518
# 10  68.392319       17.804436  298.061172
# 11  68.395442        3.600829  138.502347
# 12  68.396777       12.747925  186.292871
# 13  68.396376       18.101395  238.006770
# 14  68.394133       18.456593  148.523544
# 15  68.392559       15.395253  156.827349
# 16  68.394518       19.290859  157.079787
# 17  68.401755       13.411774  252.180186
# 18  68.395775       10.795533  212.246837
# 19  68.395037       19.237977   70.363709
# 20  68.402349       18.972606   92.114684
# 21  68.393083        7.024031  212.044972
# 22  68.399654       13.089449  243.289088
# 23  68.400588        5.265022   80.583739
# 24  68.373341        3.694196  149.675149

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/14/2023_08_14_pippin1_halbach14main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[ 14.         640.          20.          68.39590756   7.03697836
#   210.3149362 ]
#  [ 14.         640.          20.          68.39333444   7.64394102
#    66.58805395]
#  [ 14.         640.          20.          68.39383071  19.81301618
#   157.06767186]
#  [ 14.         640.          20.          68.39479362  12.08518327
#   247.76835955]
#  [ 14.         640.          20.          68.39342434  16.492242
#   281.93063089]
#  [ 14.         640.          20.          68.39227269  19.17464422
#   237.93845396]
#  [ 14.         640.          20.          68.39696628  11.69629204
#   162.73650881]
#  [ 14.         640.          20.          68.3938102    7.83282914
#   238.03216108]
#  [ 14.         640.          20.          68.39599566  12.6526764
#   263.45582094]
#  [ 14.         640.          20.          68.39261482  10.3122023
#   247.5465178 ]
#  [ 14.         640.          20.          68.39231937  17.80443592
#   298.06117224]
#  [ 14.         640.          20.          68.39544206   3.60082894
#   138.50234724]
#  [ 14.         640.          20.          68.39677712  12.74792485
#   186.29287094]
#  [ 14.         640.          20.          68.39637585  18.10139491
#   238.00677003]
#  [ 14.         640.          20.          68.39413348  18.45659294
#   148.52354367]
#  [ 14.         640.          20.          68.39255901  15.3952526
#   156.827349  ]
#  [ 14.         640.          20.          68.39451791  19.29085902
#   157.07978657]
#  [ 14.         640.          20.          68.40175461  13.41177384
#   252.18018646]
#  [ 14.         640.          20.          68.39577542  10.79553286
#   212.24683746]
#  [ 14.         640.          20.          68.39503708  19.23797677
#    70.36370922]
#  [ 14.         640.          20.          68.40234897  18.97260623
#    92.11468352]
#  [ 14.         640.          19.99628181  68.39308304   7.0240311
#   212.04497183]
#  [ 14.         640.          19.99110834  68.39965363  13.08944898
#   243.28908757]
#  [ 14.         640.           6.18819793  68.40058758   5.26502185
#    80.58373921]
#  [ 14.         640.           5.71290061  68.37334075   3.69419567
#   149.67514862]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 14
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_10770/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 57
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 59
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 62
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 68
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 60
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 56
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 63
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 60
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 64
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 60
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 0.001021
#          Iterations: 57
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 103
#          Function evaluations: 220
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 79
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 82
#          Function evaluations: 174
# [array([20.        , 71.18784825]), array([20.        , 71.18183231]), array([20.        , 71.17066031]), array([20.        , 71.18658448]), array([20.        , 71.18860482]), array([20.       , 71.1874063]), array([20.        , 71.18039375]), array([20.        , 71.18723222]), array([20.        , 71.18773285]), array([20.       , 71.1944477]), array([20.        , 71.17660141]), array([20.        , 71.18820029]), array([20.        , 71.17612674]), array([20.        , 71.18126637]), array([20.        , 71.17264515]), array([20.        , 71.19774131]), array([20.        , 71.18932563]), array([20.        , 71.18391256]), array([20.        , 71.19105198]), array([20.        , 71.18433807]), array([20.        , 71.18286438]), array([10.70684395, 70.95782365]), array([ 1.        , 87.34436146]), array([ 1.        , 87.34436146]), array([ 1.        , 87.34436146])]
# [0.0010212799563256026, 0.00102128005663092, 0.0010212800183572086, 0.0010212801191145152, 0.0010212797629865435, 0.0010212800350199865, 0.0010212797179065688, 0.0010212798014486402, 0.0010212800629731814, 0.0010212803429970878, 0.0010212798985678377, 0.0010212800732253406, 0.0010212803738610557, 0.0010212796995299114, 0.0010212802307838558, 0.0010212806337107658, 0.001021279971944455, 0.0010212801148796274, 0.0010212802177197748, 0.0010212797515616492, 0.0010212799993048402, 0.0002924625453292524, 2.139521289344746e-18, 8.930073832099813e-18, 1.4792387788174282e-18]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 14).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [6022.10648807618, 6023.124562465595, 6025.015878845408, 6022.320334779646, 6021.97847354879, 6022.18127005832, 6023.368047545253, 6022.210727306819, 6022.126015674228, 6020.989963806389, 6024.009994267527, 6022.046921704149, 6024.090350729771, 6023.220350232209, 6024.679797777882, 6020.432852521255, 6021.856511357814, 6022.772493337585, 6021.564428599748, 6022.700482835749, 6022.949887601137, 1737.0919730859694, 9.999999999993967, 9.999999999974822, 9.99999999999583]
# [1.6987057004913482e-07, 1.698418261623636e-07, 1.6978841601216936e-07, 1.6986455515463573e-07, 1.6987415498573727e-07, 1.698684702183106e-07, 1.6983489283072745e-07, 1.698675990863222e-07, 1.6987003604225855e-07, 1.6990218735124524e-07, 1.6981679437535154e-07, 1.6987227254305144e-07, 1.6981460442095452e-07, 1.6983906127612191e-07, 1.6979793856377307e-07, 1.6991798407370266e-07, 1.6987763597068833e-07, 1.6985178069039705e-07, 1.6988593066741164e-07, 1.6985375447805217e-07, 1.6984675049608294e-07, 1.6933814173583363e-07, 3.546653151297203e-07, 3.546764955432106e-07, 3.5465817786808757e-07]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/14/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    1.693381e-07         1737.091973    14.0       640.0
# 1    1.697884e-07         6025.015879    14.0       640.0
# 2    1.697979e-07         6024.679798    14.0       640.0
# 3    1.698146e-07         6024.090351    14.0       640.0
# 4    1.698168e-07         6024.009994    14.0       640.0
# 5    1.698349e-07         6023.368048    14.0       640.0
# 6    1.698391e-07         6023.220350    14.0       640.0
# 7    1.698418e-07         6023.124562    14.0       640.0
# 8    1.698468e-07         6022.949888    14.0       640.0
# 9    1.698518e-07         6022.772493    14.0       640.0
# 10   1.698538e-07         6022.700483    14.0       640.0
# 11   1.698646e-07         6022.320335    14.0       640.0
# 12   1.698676e-07         6022.210727    14.0       640.0
# 13   1.698685e-07         6022.181270    14.0       640.0
# 14   1.698700e-07         6022.126016    14.0       640.0
# 15   1.698706e-07         6022.106488    14.0       640.0
# 16   1.698723e-07         6022.046922    14.0       640.0
# 17   1.698742e-07         6021.978474    14.0       640.0
# 18   1.698776e-07         6021.856511    14.0       640.0
# 19   1.698859e-07         6021.564429    14.0       640.0
# 20   1.699022e-07         6020.989964    14.0       640.0
# 21   1.699180e-07         6020.432853    14.0       640.0
# 22   3.546582e-07           10.000000    14.0       640.0
# 23   3.546653e-07           10.000000    14.0       640.0
# 24   3.546765e-07           10.000000    14.0       640.0
#
#     stage2_cyl_diameter   stage2_D  stage1_cyl_diameter   stage1_D  \
# 0             10.706844  70.957824            19.996282  68.393083
# 1             20.000000  71.170660            20.000000  68.393831
# 2             20.000000  71.172645            20.000000  68.394133
# 3             20.000000  71.176127            20.000000  68.396777
# 4             20.000000  71.176601            20.000000  68.392319
# 5             20.000000  71.180394            20.000000  68.396966
# 6             20.000000  71.181266            20.000000  68.396376
# 7             20.000000  71.181832            20.000000  68.393334
# 8             20.000000  71.182864            20.000000  68.402349
# 9             20.000000  71.183913            20.000000  68.401755
# 10            20.000000  71.184338            20.000000  68.395037
# 11            20.000000  71.186584            20.000000  68.394794
# 12            20.000000  71.187232            20.000000  68.393810
# 13            20.000000  71.187406            20.000000  68.392273
# 14            20.000000  71.187733            20.000000  68.395996
# 15            20.000000  71.187848            20.000000  68.395908
# 16            20.000000  71.188200            20.000000  68.395442
# 17            20.000000  71.188605            20.000000  68.393424
# 18            20.000000  71.189326            20.000000  68.394518
# 19            20.000000  71.191052            20.000000  68.395775
# 20            20.000000  71.194448            20.000000  68.392615
# 21            20.000000  71.197741            20.000000  68.392559
# 22             1.000000  87.344361             5.712901  68.373341
# 23             1.000000  87.344361            19.991108  68.399654
# 24             1.000000  87.344361             6.188198  68.400588
#
#        objective
# 0   2.924625e-04
# 1   1.021280e-03
# 2   1.021280e-03
# 3   1.021280e-03
# 4   1.021280e-03
# 5   1.021280e-03
# 6   1.021280e-03
# 7   1.021280e-03
# 8   1.021280e-03
# 9   1.021280e-03
# 10  1.021280e-03
# 11  1.021280e-03
# 12  1.021280e-03
# 13  1.021280e-03
# 14  1.021280e-03
# 15  1.021280e-03
# 16  1.021280e-03
# 17  1.021280e-03
# 18  1.021280e-03
# 19  1.021280e-03
# 20  1.021280e-03
# 21  1.021281e-03
# 22  1.479239e-18
# 23  2.139521e-18
# 24  8.930074e-18
