# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 11 main
# n = 11
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 11
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [2.353465888187838, 200.72063767059987]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 50
#          Function evaluations: 110
# [11.033281893653704, 37.23046166027049]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 57
#          Function evaluations: 117
# [11.888417753352226, 219.77754507944945]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 46
#          Function evaluations: 94
# [11.546854466800594, 115.07543118925382]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 51
#          Function evaluations: 106
# [10.348961351538998, 90.10059997053463]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 51
#          Function evaluations: 102
# [18.537715371471783, 71.9399492631099]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 75
# [1.4167351941787134, 221.57464137006]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 90
#          Function evaluations: 215
# [17.206079774428165, 182.73416799742736]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 90
# [2.095171696571433, 254.45541722600865]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 72
#          Function evaluations: 166
# [10.114392737477228, 212.66398406715413]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 55
#          Function evaluations: 104
# [5.204669565431593, 296.7972224833605]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 91
# [1.1945878448551266, 267.31079154732043]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 113
#          Function evaluations: 258
# [13.380618646385633, 279.32658661143256]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 94
# [5.252134323441219, 298.79442105132745]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 49
#          Function evaluations: 102
# [19.67649310768445, 279.78654237693945]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 37
#          Function evaluations: 79
# [17.637213699170413, 215.67334692863582]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 85
# [3.329458901454466, 32.99678176074887]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 91
#          Function evaluations: 221
# [16.142554796056075, 61.585547909547905]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 81
# [8.652131856771867, 226.90830591393146]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 92
# [2.4181082359252866, 144.28419394182725]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 48
#          Function evaluations: 111
# [8.361586320428444, 199.36697217922705]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 53
#          Function evaluations: 111
# [18.406730704828394, 207.11200288946563]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations:
# [array([ 3.97477517, 48.78401721]), array([20.        , 48.79771886]), array([20.        , 48.80359801]), array([20.        , 48.80043868]), array([20.        , 48.80058806]), array([20.        , 48.79993878]), array([ 1.87605246, 48.76607393]), array([20.        , 48.80344256]), array([ 3.5232225, 48.7937724]), array([20.        , 48.79950331]), array([19.99938895, 48.80256234]), array([ 1.78056873, 48.81106153]), array([20.       , 48.7948873]), array([20.        , 48.79848625]), array([20.        , 48.80212285]), array([20.        , 48.80171969]), array([ 2.72534557, 48.79759524]), array([20.       , 48.8024836]), array([14.34374131, 48.79295711]), array([ 3.8630734 , 48.77656449]), array([20.        , 48.80496559]), array([20.        , 48.80614136]), array([ 1.        , 48.75459297]), array([20.        , 48.79780293]), array([ 1.42485675, 48.88425965])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 11).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [397.97313731173, 10070.35311737377, 10067.92694347053, 10069.230612183444, 10069.16896239697, 10069.436912858258, 88.72338844800672, 10067.991081856233, 312.5612162554572, 10069.616629847462, 10067.739059365656, 79.77461358560541, 10071.521945373805, 10070.036387677126, 10068.535622203879, 10068.701982436472, 186.99502444846195, 10068.38676567702, 5180.770502764723, 376.03411808846425, 10067.362706981981, 10066.877640440818, 25.220441512310853, 10070.318420448335, 50.93168199526792]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [3.978463041748378e-08, 3.9624054729882046e-08, 3.962405653954626e-08, 3.9624036330959095e-08, 3.9624004815928825e-08, 3.9623990814081845e-08, 3.9780280106233224e-08, 3.9623994620852376e-08, 3.9784750601909006e-08, 3.962404925322918e-08, 3.9624043281682615e-08, 3.977572192222161e-08, 3.9624042348120607e-08, 3.9623969117233256e-08, 3.9624038477117814e-08, 3.962401693059885e-08, 3.978515181357596e-08, 3.962400822840633e-08, 3.9706452175516433e-08, 3.978544055966379e-08, 3.962405284717593e-08, 3.962405321240398e-08, 3.9748124150877386e-08, 3.962400810991153e-08, 3.976754615097743e-08]
# [3.978463041748378e-08, 3.9624054729882046e-08, 3.962405653954626e-08, 3.9624036330959095e-08, 3.9624004815928825e-08, 3.9623990814081845e-08, 3.9780280106233224e-08, 3.9623994620852376e-08, 3.9784750601909006e-08, 3.962404925322918e-08, 3.9624043281682615e-08, 3.977572192222161e-08, 3.9624042348120607e-08, 3.9623969117233256e-08, 3.9624038477117814e-08, 3.962401693059885e-08, 3.978515181357596e-08, 3.962400822840633e-08, 3.9706452175516433e-08, 3.978544055966379e-08, 3.962405284717593e-08, 3.962405321240398e-08, 3.9748124150877386e-08, 3.962400810991153e-08, 3.976754615097743e-08]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/11/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    3.962397e-08        10070.036388    11.0       640.0     20.000000
# 1    3.962399e-08        10069.436913    11.0       640.0     20.000000
# 2    3.962399e-08        10067.991082    11.0       640.0     20.000000
# 3    3.962400e-08        10069.168962    11.0       640.0     20.000000
# 4    3.962401e-08        10070.318420    11.0       640.0     20.000000
# 5    3.962401e-08        10068.386766    11.0       640.0     20.000000
# 6    3.962402e-08        10068.701982    11.0       640.0     20.000000
# 7    3.962404e-08        10069.230612    11.0       640.0     20.000000
# 8    3.962404e-08        10068.535622    11.0       640.0     20.000000
# 9    3.962404e-08        10071.521945    11.0       640.0     20.000000
# 10   3.962404e-08        10067.739059    11.0       640.0     19.999389
# 11   3.962405e-08        10069.616630    11.0       640.0     20.000000
# 12   3.962405e-08        10067.362707    11.0       640.0     20.000000
# 13   3.962405e-08        10066.877640    11.0       640.0     20.000000
# 14   3.962405e-08        10070.353117    11.0       640.0     20.000000
# 15   3.962406e-08        10067.926943    11.0       640.0     20.000000
# 16   3.970645e-08         5180.770503    11.0       640.0     14.343741
# 17   3.974812e-08           25.220442    11.0       640.0      1.000000
# 18   3.976755e-08           50.931682    11.0       640.0      1.424857
# 19   3.977572e-08           79.774614    11.0       640.0      1.780569
# 20   3.978028e-08           88.723388    11.0       640.0      1.876052
# 21   3.978463e-08          397.973137    11.0       640.0      3.974775
# 22   3.978475e-08          312.561216    11.0       640.0      3.523223
# 23   3.978515e-08          186.995024    11.0       640.0      2.725346
# 24   3.978544e-08          376.034118    11.0       640.0      3.863073
#
#             D  g_cyl_diameter         g_D
# 0   48.798486        5.252134  298.794421
# 1   48.799939       18.537715   71.939949
# 2   48.803443       17.206080  182.734168
# 3   48.800588       10.348961   90.100600
# 4   48.797803        5.340121   23.146019
# 5   48.802484       16.142555   61.585548
# 6   48.801720       17.637214  215.673347
# 7   48.800439       11.546854  115.075431
# 8   48.802123       19.676493  279.786542
# 9   48.794887       13.380619  279.326587
# 10  48.802562        5.204670  296.797222
# 11  48.799503       10.114393  212.663984
# 12  48.804966        8.361586  199.366972
# 13  48.806141       18.406731  207.112003
# 14  48.797719       11.033282   37.230462
# 15  48.803598       11.888418  219.777545
# 16  48.792957        8.652132  226.908306
# 17  48.754593       12.835792   22.071674
# 18  48.884260        1.070943  111.337816
# 19  48.811062        1.194588  267.310792
# 20  48.766074        1.416735  221.574641
# 21  48.784017        2.353466  200.720638
# 22  48.793772        2.095172  254.455417
# 23  48.797595        3.329459   32.996782
# 24  48.776564        2.418108  144.284194

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/11/2023_08_13_pippin1_halbach11main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[ 11.         640.          20.          48.79848625   5.25213432
#   298.79442105]
#  [ 11.         640.          20.          48.79993878  18.53771537
#    71.93994926]
#  [ 11.         640.          20.          48.80344256  17.20607977
#   182.734168  ]
#  [ 11.         640.          20.          48.80058806  10.34896135
#    90.10059997]
#  [ 11.         640.          20.          48.79780293   5.34012112
#    23.14601929]
#  [ 11.         640.          20.          48.8024836   16.1425548
#    61.58554791]
#  [ 11.         640.          20.          48.80171969  17.6372137
#   215.67334693]
#  [ 11.         640.          20.          48.80043868  11.54685447
#   115.07543119]
#  [ 11.         640.          20.          48.80212285  19.67649311
#   279.78654238]
#  [ 11.         640.          20.          48.7948873   13.38061865
#   279.32658661]
#  [ 11.         640.          19.99938895  48.80256234   5.20466957
#   296.79722248]
#  [ 11.         640.          20.          48.79950331  10.11439274
#   212.66398407]
#  [ 11.         640.          20.          48.80496559   8.36158632
#   199.36697218]
#  [ 11.         640.          20.          48.80614136  18.4067307
#   207.11200289]
#  [ 11.         640.          20.          48.79771886  11.03328189
#    37.23046166]
#  [ 11.         640.          20.          48.80359801  11.88841775
#   219.77754508]
#  [ 11.         640.          14.34374131  48.79295711   8.65213186
#   226.90830591]
#  [ 11.         640.           1.          48.75459297  12.83579161
#    22.07167376]
#  [ 11.         640.           1.42485675  48.88425965   1.07094341
#   111.33781556]
#  [ 11.         640.           1.78056873  48.81106153   1.19458784
#   267.31079155]
#  [ 11.         640.           1.87605246  48.76607393   1.41673519
#   221.57464137]
#  [ 11.         640.           3.97477517  48.78401721   2.35346589
#   200.72063767]
#  [ 11.         640.           3.5232225   48.7937724    2.0951717
#   254.45541723]
#  [ 11.         640.           2.72534557  48.79759524   3.3294589
#    32.99678176]
#  [ 11.         640.           3.8630734   48.77656449   2.41810824
#   144.28419394]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 11
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000391
#          Iterations: 66
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 0.000391
#          Iterations: 63
#          Function evaluations: 178

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 11).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [16229.755153091219, 16229.038307205861, 16231.407111682027, 16229.315957637247, 16224.529333429111, 16229.0226870453, 16233.356558221283, 16230.11805332515, 16233.597900946414, 16230.257253150337, 16231.329537647573, 39.81630262503445, 39.744416229328216, 39.5663640359069, 39.86782703909588, 39.51513161907513, 39.99204591980982, 39.66852513424777, 40.073434836670245, 39.843711076773246, 39.85380962811382, 10.00000000000554, 40.12343191998386, 10.000000000038218, 14792.73114843142]
# [4.760716845215901e-08, 4.76092576755398e-08, 4.7602270552368745e-08, 4.76084705709267e-08, 4.7622540819966256e-08, 4.7609300380158494e-08, 4.759663771650231e-08, 4.760609741400602e-08, 4.759593203916673e-08, 4.7605697964340554e-08, 4.7602540369772185e-08, 4.8842733920416666e-08, 4.896294068163222e-08, 4.926736219293267e-08, 4.8758444873688255e-08, 4.935626871041617e-08, 4.857935567828955e-08, 4.90953250888442e-08, 4.844641700674128e-08, 4.881483239208857e-08, 4.878578808838887e-08, 7.040213315374961e-07, 4.837894602431885e-08, 7.040214658990463e-07, 0.11417449445152296]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/20/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
