# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 13 main
# n = 13
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 13
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [6.629475550946956, 125.5716500480367]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 69
#          Function evaluations: 138
# [13.179095602683253, 296.6493198913041]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 96
# [9.372652232744638, 156.27037591352394]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 63
#          Function evaluations: 127
# [19.86609424151603, 51.77615939176363]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 26
#          Function evaluations: 53
# [6.410617195083276, 239.97611390074425]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 93
# [14.19349039572985, 69.56684738440427]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 84
# [15.042445925078981, 25.47822743664826]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 98
#          Function evaluations: 251
# [9.23436480153202, 230.33966444995667]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 97
# [18.863140933330378, 238.76620137333006]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 84
# [4.020655022680636, 137.22522981002794]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 91
# [6.794856482036516, 44.17365167850613]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 37
#          Function evaluations: 76
# [14.592410477338312, 194.84133413590857]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 93
# [13.3205761781099, 167.27611853607544]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 91
# [10.036949469272965, 162.48305087935347]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 69
#          Function evaluations: 138
# [7.764459531529461, 101.54584594213571]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 46
#          Function evaluations: 96
# [2.837732983991106, 101.69712493325652]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 92
#          Function evaluations: 221
# [18.245365760600002, 39.21747463043024]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 73
# [13.970398413588887, 58.64659156401527]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 85
# [2.880022904437497, 164.5805462615117]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 56
#          Function evaluations: 124
# [9.295952865915673, 238.3849419124077]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations:
# [array([20.        , 43.90382458]), array([20.        , 43.90632267]), array([20.        , 43.90410911]), array([20.        , 43.90481797]), array([10.88364874, 43.89233465]), array([20.        , 43.90483731]), array([ 2.41455266, 43.92407353]), array([15.46261923, 43.89035207]), array([20.        , 43.90452475]), array([ 6.48263602, 43.90121458]), array([20.        , 43.90683225]), array([20.        , 43.90575506]), array([20.        , 43.90135428]), array([20.        , 43.90213438]), array([12.03325378, 43.9036112 ]), array([ 4.35295192, 43.89115443]), array([20.        , 43.90357829]), array([20.        , 43.90878413]), array([ 4.84581614, 43.90639865]), array([20.        , 43.90417822]), array([20.        , 43.90128645]), array([12.09906995, 43.89197171]), array([20.       , 43.9046431]), array([ 2.68573775, 43.92305436]), array([ 2.04505013, 43.91959804])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 13).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [14702.512828214474, 14700.839829181632, 14702.322260346606, 14701.84750866004, 4356.201421013203, 14701.834557518006, 214.09395865231627, 8793.550848180526, 14702.04388643454, 1544.8505889164153, 14700.498588399678, 14701.219938718044, 14704.167508595056, 14703.644942369463, 5322.3317758235635, 696.8671845249362, 14702.677787618188, 14699.191628350281, 863.0073745093136, 14702.275979448268, 14704.21294240146, 5383.566434270905, 14701.964627974863, 264.8978373964877, 153.61282487143907]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [2.5732691103443975e-08, 2.5732678927016802e-08, 2.5732695271446652e-08, 2.5732714088843004e-08, 2.5812349403494784e-08, 2.573270022707933e-08, 2.5834961556620518e-08, 2.5778320412102775e-08, 2.573271413203771e-08, 2.583309686525e-08, 2.573265601345484e-08, 2.5732699136027803e-08, 2.573269657983561e-08, 2.573270220964521e-08, 2.5804894677784374e-08, 2.5838113973784737e-08, 2.5732632621343488e-08, 2.5732676332835726e-08, 2.583786990917921e-08, 2.5732715977400613e-08, 2.5732674763599717e-08, 2.580444009712597e-08, 2.5732707340210405e-08, 2.5838890260577267e-08, 2.583329456064048e-08]
# [2.5732691103443975e-08, 2.5732678927016802e-08, 2.5732695271446652e-08, 2.5732714088843004e-08, 2.5812349403494784e-08, 2.573270022707933e-08, 2.5834961556620518e-08, 2.5778320412102775e-08, 2.573271413203771e-08, 2.583309686525e-08, 2.573265601345484e-08, 2.5732699136027803e-08, 2.573269657983561e-08, 2.573270220964521e-08, 2.5804894677784374e-08, 2.5838113973784737e-08, 2.5732632621343488e-08, 2.5732676332835726e-08, 2.583786990917921e-08, 2.5732715977400613e-08, 2.5732674763599717e-08, 2.580444009712597e-08, 2.5732707340210405e-08, 2.5838890260577267e-08, 2.583329456064048e-08]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/13/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    2.573263e-08        14702.677788    13.0       640.0     20.000000
# 1    2.573266e-08        14700.498588    13.0       640.0     20.000000
# 2    2.573267e-08        14704.212942    13.0       640.0     20.000000
# 3    2.573268e-08        14699.191628    13.0       640.0     20.000000
# 4    2.573268e-08        14700.839829    13.0       640.0     20.000000
# 5    2.573269e-08        14702.512828    13.0       640.0     20.000000
# 6    2.573270e-08        14702.322260    13.0       640.0     20.000000
# 7    2.573270e-08        14704.167509    13.0       640.0     20.000000
# 8    2.573270e-08        14701.219939    13.0       640.0     20.000000
# 9    2.573270e-08        14701.834558    13.0       640.0     20.000000
# 10   2.573270e-08        14703.644942    13.0       640.0     20.000000
# 11   2.573271e-08        14701.964628    13.0       640.0     20.000000
# 12   2.573271e-08        14701.847509    13.0       640.0     20.000000
# 13   2.573271e-08        14702.043886    13.0       640.0     20.000000
# 14   2.573272e-08        14702.275979    13.0       640.0     20.000000
# 15   2.577832e-08         8793.550848    13.0       640.0     15.462619
# 16   2.580444e-08         5383.566434    13.0       640.0     12.099070
# 17   2.580489e-08         5322.331776    13.0       640.0     12.033254
# 18   2.581235e-08         4356.201421    13.0       640.0     10.883649
# 19   2.583310e-08         1544.850589    13.0       640.0      6.482636
# 20   2.583329e-08          153.612825    13.0       640.0      2.045050
# 21   2.583496e-08          214.093959    13.0       640.0      2.414553
# 22   2.583787e-08          863.007375    13.0       640.0      4.845816
# 23   2.583811e-08          696.867185    13.0       640.0      4.352952
# 24   2.583889e-08          264.897837    13.0       640.0      2.685738
#
#             D  g_cyl_diameter         g_D
# 0   43.903578       18.245366   39.217475
# 1   43.906832        6.794856   44.173652
# 2   43.901286        8.291416  266.512953
# 3   43.908784       13.970398   58.646592
# 4   43.906323       13.179096  296.649320
# 5   43.903825        6.629476  125.571650
# 6   43.904109        9.372652  156.270376
# 7   43.901354       13.320576  167.276119
# 8   43.905755       14.592410  194.841334
# 9   43.904837       14.193490   69.566847
# 10  43.902134       10.036949  162.483051
# 11  43.904643       15.613920  214.347049
# 12  43.904818       19.866094   51.776159
# 13  43.904525       18.863141  238.766201
# 14  43.904178        9.295953  238.384942
# 15  43.890352        9.234365  230.339664
# 16  43.891972        7.236840  244.811339
# 17  43.903611        7.764460  101.545846
# 18  43.892335        6.410617  239.976114
# 19  43.901215        4.020655  137.225230
# 20  43.919598        1.882333   34.551520
# 21  43.924074       15.042446   25.478227
# 22  43.906399        2.880023  164.580546
# 23  43.891154        2.837733  101.697125
# 24  43.923054        1.606022  256.498909

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/13/2023_08_14_pippin1_halbach13main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[ 13.         640.          20.          43.90357829  18.24536576
#    39.21747463]
#  [ 13.         640.          20.          43.90683225   6.79485648
#    44.17365168]
#  [ 13.         640.          20.          43.90128645   8.29141572
#   266.51295344]
#  [ 13.         640.          20.          43.90878413  13.97039841
#    58.64659156]
#  [ 13.         640.          20.          43.90632267  13.1790956
#   296.64931989]
#  [ 13.         640.          20.          43.90382458   6.62947555
#   125.57165005]
#  [ 13.         640.          20.          43.90410911   9.37265223
#   156.27037591]
#  [ 13.         640.          20.          43.90135428  13.32057618
#   167.27611854]
#  [ 13.         640.          20.          43.90575506  14.59241048
#   194.84133414]
#  [ 13.         640.          20.          43.90483731  14.1934904
#    69.56684738]
#  [ 13.         640.          20.          43.90213438  10.03694947
#   162.48305088]
#  [ 13.         640.          20.          43.9046431   15.6139195
#   214.34704925]
#  [ 13.         640.          20.          43.90481797  19.86609424
#    51.77615939]
#  [ 13.         640.          20.          43.90452475  18.86314093
#   238.76620137]
#  [ 13.         640.          20.          43.90417822   9.29595287
#   238.38494191]
#  [ 13.         640.          15.46261923  43.89035207   9.2343648
#   230.33966445]
#  [ 13.         640.          12.09906995  43.89197171   7.23683996
#   244.81133853]
#  [ 13.         640.          12.03325378  43.9036112    7.76445953
#   101.54584594]
#  [ 13.         640.          10.88364874  43.89233465   6.4106172
#   239.9761139 ]
#  [ 13.         640.           6.48263602  43.90121458   4.02065502
#   137.22522981]
#  [ 13.         640.           2.04505013  43.91959804   1.88233253
#    34.55151966]
#  [ 13.         640.           2.41455266  43.92407353  15.04244593
#    25.47822744]
#  [ 13.         640.           4.84581614  43.90639865   2.8800229
#   164.58054626]
#  [ 13.         640.           4.35295192  43.89115443   2.83773298
#   101.69712493]
#  [ 13.         640.           2.68573775  43.92305436   1.60602216
#   256.49890915]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 13
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_10756/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 63
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 56
#          Function evaluations: 156
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 68
#          Function evaluations: 180
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 66
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 64
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 67
#          Function evaluations: 164
# Optimization terminated successfully.
#          Current function value: 0.000372
#          Iterations: 65
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 94
#          Function evaluations: 237
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 102
#          Function evaluations: 252
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 90
#          Function evaluations: 237
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 103
#          Function evaluations: 254
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 103
#          Function evaluations: 249
# [array([20.        , 44.67532088]), array([20.        , 44.67407627]), array([20.        , 44.66417984]), array([20.        , 44.66360874]), array([20.       , 44.6716819]), array([20.        , 44.67771532]), array([20.        , 44.66728614]), array([20.        , 44.67674212]), array([20.        , 44.67070243]), array([20.        , 44.67231445]), array([20.      , 44.672068]), array([20.        , 44.67670168]), array([20.        , 44.67069636]), array([20.        , 44.67443958]), array([20.        , 44.67380539]), array([ 1.        , 45.20406232]), array([ 1.        , 44.99355733]), array([ 1.        , 45.04269876]), array([ 1.        , 45.20402571]), array([ 1.        , 44.98143877]), array([ 1.        , 45.05511694]), array([ 1.        , 45.18691612]), array([ 1.        , 45.10746678]), array([ 1.        , 44.99519752]), array([ 1.       , 45.1118305])]
# [0.0003719679043384303, 0.0003719677314672268, 0.0003719679734331907, 0.00037196687571156137, 0.00037196736058963325, 0.0003719671798886284, 0.00037196740613018364, 0.00037196775818350097, 0.0003719669513748617, 0.0003719674999851256, 0.00037196729188337805, 0.000371967972671691, 0.00037196770076760834, 0.00037196756012639976, 0.00037196755739839584, 6.679336845570766e-07, 6.682381267156596e-07, 6.68125216014589e-07, 6.674370214692736e-07, 6.682218111185861e-07, 6.677430914106425e-07, 6.676109797710328e-07, 6.680940418409152e-07, 6.680017972665662e-07, 6.683021737214006e-07]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 13).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [14199.094790511424, 14199.88597977038, 14206.179444127765, 14206.54275710473, 14201.408255450548, 14197.572838758548, 14204.203595927025, 14198.191396013737, 14202.031045555035, 14201.006076388376, 14201.162770171886, 14198.217096719512, 14202.034908175418, 14199.655021768323, 14200.058190027537, 34.67216053361322, 34.99735689638596, 34.92103318063584, 34.672216685460626, 35.01621722096757, 34.901785472316725, 34.698478746414, 34.82081989986087, 34.99480541218777, 34.81408359272633]
# [2.621505528225619e-08, 2.621358141971807e-08, 2.6201977433235027e-08, 2.6201229558190055e-08, 2.6210743422645905e-08, 2.6217816402849678e-08, 2.6205584809063775e-08, 2.62167141534338e-08, 2.6209564380241565e-08, 2.621149606890956e-08, 2.6211191986692484e-08, 2.6216681781511117e-08, 2.620961005058787e-08, 2.621399601017537e-08, 2.6213251025271094e-08, 2.7072362943127226e-08, 2.673235132360219e-08, 2.68096916837997e-08, 2.705217086807588e-08, 2.671154496366101e-08, 2.6815068829219958e-08, 2.7030449390246924e-08, 2.691667900320489e-08, 2.6725625034905867e-08, 2.6932373755575556e-08]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/13/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    2.620123e-08        14206.542757    13.0       640.0
# 1    2.620198e-08        14206.179444    13.0       640.0
# 2    2.620558e-08        14204.203596    13.0       640.0
