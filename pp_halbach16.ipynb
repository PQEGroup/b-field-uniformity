# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 16 main
# n = 16
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 16
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [11.532085581006715, 198.6122917209087]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 113
# [17.316910262354845, 74.95824073332457]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 67
# [4.9475629943709185, 208.7719686859447]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 50
#          Function evaluations: 107
# [13.37161125557516, 251.91166294941874]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 62
#          Function evaluations: 125
# [16.651694283638495, 244.01602472688862]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 85
# [4.01561949220826, 67.29096404430851]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 52
#          Function evaluations: 122
# [19.147545081928794, 174.14058834169268]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 86
# [12.761575077339588, 40.28332368518204]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 47
#          Function evaluations: 97
# [12.743816655025928, 169.0104023236082]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 37
#          Function evaluations: 81
# [4.028246389249244, 38.07186335499124]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 103
#          Function evaluations: 244
# [15.715167421680079, 211.9466106965134]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 84
# [10.004497761548828, 272.49695616603947]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 68
#          Function evaluations: 141
# [14.27243650542063, 196.78145045788216]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 85
# [4.05755694997641, 231.37757655784256]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 88
# [11.504891754843984, 133.99189744925263]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 49
#          Function evaluations: 107
# [10.558882083297522, 226.93353410314063]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 60
#          Function evaluations: 119
# [19.056721197011463, 63.750111401023034]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 24
#          Function evaluations: 47
# [12.198376924492342, 181.9903628482339]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 51
#          Function evaluations: 105
# [5.396207047085211, 161.62274139889982]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 65
#          Function evaluations: 123
# [12.475654409660347, 144.29842149813658]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 51
#          Function evaluations: 102
# [4.890102703297279, 21.381830285489066]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 52
#          Function evaluations: 111
# [17.194068797843233, 248.55681621175594]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 86
# [13.337363364979808, 34.342823310870415]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 49
#          Function evaluations: 99
# [7.072116837426509, 58.14939118521964]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 97
# [12.555331949186959, 45.63028556828219]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 81
# Objective function values:
# [9.455455436419228e-08, 9.455455811388559e-08, 9.487105682841059e-08, 9.455453822651429e-08, 9.455458617920672e-08, 9.490765125109071e-08, 9.455459130320227e-08, 9.45545384902694e-08, 9.455457604088076e-08, 9.492204203226281e-08, 9.455456291712952e-08, 9.455457346901465e-08, 9.455455606290429e-08, 9.489060923783152e-08, 9.455454451798736e-08, 9.455455239766888e-08, 9.45545804281861e-08, 9.455454798735469e-08, 9.455456589222906e-08, 9.455452483961057e-08, 9.455456944839512e-08, 9.45545575617927e-08, 9.455457713274502e-08, 9.455457677211312e-08, 9.455455480820644e-08]
# Result parameters:
# [array([20.        , 60.35536027]), array([19.99983366, 60.35822011]), array([ 8.21413371, 60.35231791]), array([20.        , 60.36057445]), array([20.        , 60.36564608]), array([ 5.59755686, 60.29172759]), array([20.       , 60.3666954]), array([20.        , 60.35867477]), array([20.        , 60.36175953]), array([ 3.31283418, 60.32114697]), array([20.        , 60.35733715]), array([20.        , 60.36244285]), array([20.        , 60.35704369]), array([ 6.84813659, 60.34830497]), array([20.        , 60.35993389]), array([20.        , 60.36307742]), array([20.        , 60.35725841]), array([20.        , 60.35552177]), array([20.        , 60.36005701]), array([20.        , 60.36279244]), array([20.        , 60.36056313]), array([20.        , 60.36046803]), array([20.        , 60.35621871]), array([20.        , 60.35942703]), array([20.        , 60.36015257])]
# Starting guesses:
# [[11.532085581006715, 198.6122917209087], [17.316910262354845, 74.95824073332457], [4.9475629943709185, 208.7719686859447], [13.37161125557516, 251.91166294941874], [16.651694283638495, 244.01602472688862], [4.01561949220826, 67.29096404430851], [19.147545081928794, 174.14058834169268], [12.761575077339588, 40.28332368518204], [12.743816655025928, 169.0104023236082], [4.028246389249244, 38.07186335499124], [15.715167421680079, 211.9466106965134], [10.004497761548828, 272.49695616603947], [14.27243650542063, 196.78145045788216], [4.05755694997641, 231.37757655784256], [11.504891754843984, 133.99189744925263], [10.558882083297522, 226.93353410314063], [19.056721197011463, 63.750111401023034], [12.198376924492342, 181.9903628482339], [5.396207047085211, 161.62274139889982], [12.475654409660347, 144.29842149813658], [4.890102703297279, 21.381830285489066], [17.194068797843233, 248.55681621175594], [13.337363364979808, 34.342823310870415], [7.072116837426509, 58.14939118521964], [12.555331949186959, 45.63028556828219]]

# %%
print(results_x)
# Out:
# [array([20.        , 60.35536027]), array([19.99983366, 60.35822011]), array([ 8.21413371, 60.35231791]), array([20.        , 60.36057445]), array([20.        , 60.36564608]), array([ 5.59755686, 60.29172759]), array([20.       , 60.3666954]), array([20.        , 60.35867477]), array([20.        , 60.36175953]), array([ 3.31283418, 60.32114697]), array([20.        , 60.35733715]), array([20.        , 60.36244285]), array([20.        , 60.35704369]), array([ 6.84813659, 60.34830497]), array([20.        , 60.35993389]), array([20.        , 60.36307742]), array([20.        , 60.35725841]), array([20.        , 60.35552177]), array([20.        , 60.36005701]), array([20.        , 60.36279244]), array([20.        , 60.36056313]), array([20.        , 60.36046803]), array([20.        , 60.35621871]), array([20.        , 60.35942703]), array([20.        , 60.36015257])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 16).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [9574.853124834892, 9573.786500318605, 1615.2487995766119, 9573.19887263004, 9571.590259083046, 751.597658548327, 9571.257489064534, 9573.801516177547, 9572.822954906944, 263.00501952296736, 9574.225889055484, 9572.606210911068, 9574.31899348201, 1122.8415546786987, 9573.402075791488, 9572.404932990936, 9574.250869880521, 9574.801880491803, 9573.363018462589, 9572.495322838062, 9573.20246405224, 9573.2326333908, 9574.580745536909, 9573.562866169324, 9573.33270224988]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [9.455455436419228e-08, 9.455455811388559e-08, 9.487105682841059e-08, 9.455453822651429e-08, 9.455458617920672e-08, 9.490765125109071e-08, 9.455459130320227e-08, 9.45545384902694e-08, 9.455457604088076e-08, 9.492204203226281e-08, 9.455456291712952e-08, 9.455457346901465e-08, 9.455455606290429e-08, 9.489060923783152e-08, 9.455454451798736e-08, 9.455455239766888e-08, 9.45545804281861e-08, 9.455454798735469e-08, 9.455456589222906e-08, 9.455452483961057e-08, 9.455456944839512e-08, 9.45545575617927e-08, 9.455457713274502e-08, 9.455457677211312e-08, 9.455455480820644e-08]
# [9.455455436419228e-08, 9.455455811388559e-08, 9.487105682841059e-08, 9.455453822651429e-08, 9.455458617920672e-08, 9.490765125109071e-08, 9.455459130320227e-08, 9.45545384902694e-08, 9.455457604088076e-08, 9.492204203226281e-08, 9.455456291712952e-08, 9.455457346901465e-08, 9.455455606290429e-08, 9.489060923783152e-08, 9.455454451798736e-08, 9.455455239766888e-08, 9.45545804281861e-08, 9.455454798735469e-08, 9.455456589222906e-08, 9.455452483961057e-08, 9.455456944839512e-08, 9.45545575617927e-08, 9.455457713274502e-08, 9.455457677211312e-08, 9.455455480820644e-08]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/16/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    9.455452e-08         9572.495323    16.0       640.0     20.000000
# 1    9.455454e-08         9573.198873    16.0       640.0     20.000000
# 2    9.455454e-08         9573.801516    16.0       640.0     20.000000
# 3    9.455454e-08         9573.402076    16.0       640.0     20.000000
# 4    9.455455e-08         9574.801880    16.0       640.0     20.000000
# 5    9.455455e-08         9572.404933    16.0       640.0     20.000000
# 6    9.455455e-08         9574.853125    16.0       640.0     20.000000
# 7    9.455455e-08         9573.332702    16.0       640.0     20.000000
# 8    9.455456e-08         9574.318993    16.0       640.0     20.000000
# 9    9.455456e-08         9573.232633    16.0       640.0     20.000000
# 10   9.455456e-08         9573.786500    16.0       640.0     19.999834
# 11   9.455456e-08         9574.225889    16.0       640.0     20.000000
# 12   9.455457e-08         9573.363018    16.0       640.0     20.000000
# 13   9.455457e-08         9573.202464    16.0       640.0     20.000000
# 14   9.455457e-08         9572.606211    16.0       640.0     20.000000
# 15   9.455458e-08         9572.822955    16.0       640.0     20.000000
# 16   9.455458e-08         9573.562866    16.0       640.0     20.000000
# 17   9.455458e-08         9574.580746    16.0       640.0     20.000000
# 18   9.455458e-08         9574.250870    16.0       640.0     20.000000
# 19   9.455459e-08         9571.590259    16.0       640.0     20.000000
# 20   9.455459e-08         9571.257489    16.0       640.0     20.000000
# 21   9.487106e-08         1615.248800    16.0       640.0      8.214134
# 22   9.489061e-08         1122.841555    16.0       640.0      6.848137
# 23   9.490765e-08          751.597659    16.0       640.0      5.597557
# 24   9.492204e-08          263.005020    16.0       640.0      3.312834
#
#             D  g_cyl_diameter         g_D
# 0   60.362792       12.475654  144.298421
# 1   60.360574       13.371611  251.911663
# 2   60.358675       12.761575   40.283324
# 3   60.359934       11.504892  133.991897
# 4   60.355522       12.198377  181.990363
# 5   60.363077       10.558882  226.933534
# 6   60.355360       11.532086  198.612292
# 7   60.360153       12.555332   45.630286
# 8   60.357044       14.272437  196.781450
# 9   60.360468       17.194069  248.556816
# 10  60.358220       17.316910   74.958241
# 11  60.357337       15.715167  211.946611
# 12  60.360057        5.396207  161.622741
# 13  60.360563        4.890103   21.381830
# 14  60.362443       10.004498  272.496956
# 15  60.361760       12.743817  169.010402
# 16  60.359427        7.072117   58.149391
# 17  60.356219       13.337363   34.342823
# 18  60.357258       19.056721   63.750111
# 19  60.365646       16.651694  244.016025
# 20  60.366695       19.147545  174.140588
# 21  60.352318        4.947563  208.771969
# 22  60.348305        4.057557  231.377577
# 23  60.291728        4.015619   67.290964
# 24  60.321147        4.028246   38.071863

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/16/2023_08_13_pippin1_halbach16main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[ 16.         640.          20.          60.36279244  12.47565441
#   144.2984215 ]
#  [ 16.         640.          20.          60.36057445  13.37161126
#   251.91166295]
#  [ 16.         640.          20.          60.35867477  12.76157508
#    40.28332369]
#  [ 16.         640.          20.          60.35993389  11.50489175
#   133.99189745]
#  [ 16.         640.          20.          60.35552177  12.19837692
#   181.99036285]
#  [ 16.         640.          20.          60.36307742  10.55888208
#   226.9335341 ]
#  [ 16.         640.          20.          60.35536027  11.53208558
#   198.61229172]
#  [ 16.         640.          20.          60.36015257  12.55533195
#    45.63028557]
#  [ 16.         640.          20.          60.35704369  14.27243651
#   196.78145046]
#  [ 16.         640.          20.          60.36046803  17.1940688
#   248.55681621]
#  [ 16.         640.          19.99983366  60.35822011  17.31691026
#    74.95824073]
#  [ 16.         640.          20.          60.35733715  15.71516742
#   211.9466107 ]
#  [ 16.         640.          20.          60.36005701   5.39620705
#   161.6227414 ]
#  [ 16.         640.          20.          60.36056313   4.8901027
#    21.38183029]
#  [ 16.         640.          20.          60.36244285  10.00449776
#   272.49695617]
#  [ 16.         640.          20.          60.36175953  12.74381666
#   169.01040232]
#  [ 16.         640.          20.          60.35942703   7.07211684
#    58.14939119]
#  [ 16.         640.          20.          60.35621871  13.33736336
#    34.34282331]
#  [ 16.         640.          20.          60.35725841  19.0567212
#    63.7501114 ]
#  [ 16.         640.          20.          60.36564608  16.65169428
#   244.01602473]
#  [ 16.         640.          20.          60.3666954   19.14754508
#   174.14058834]
#  [ 16.         640.           8.21413371  60.35231791   4.94756299
#   208.77196869]
#  [ 16.         640.           6.84813659  60.34830497   4.05755695
#   231.37757656]
#  [ 16.         640.           5.59755686  60.29172759   4.01561949
#    67.29096404]
#  [ 16.         640.           3.31283418  60.32114697   4.02824639
#    38.07186335]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 16
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_5242/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 66
#          Function evaluations: 167
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 67
#          Function evaluations: 178
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 68
#          Function evaluations: 179
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 80
#          Function evaluations: 197
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 114
#          Function evaluations: 240
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 59
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 67
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 65
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 62
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 0.000882
#          Iterations: 92
#          Function evaluations: 221
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 93
#          Function evaluations: 197
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 125
#          Function evaluations: 282
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 93
#          Function evaluations: 191
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 76
#          Function evaluations: 150
# [array([20.        , 62.01654976]), array([20.       , 62.0151172]), array([20.        , 62.01722369]), array([20.        , 62.01970311]), array([20.        , 62.01522724]), array([20.        , 62.01986943]), array([20.        , 62.01528002]), array([20.       , 62.0178039]), array([20.        , 62.01866472]), array([20.        , 62.01558325]), array([ 1.        , 93.37328087]), array([20.        , 62.01952164]), array([20.        , 62.01937488]), array([20.        , 62.01564667]), array([20.        , 62.01482161]), array([20.        , 62.01594835]), array([20.        , 62.01761518]), array([20.       , 62.0183724]), array([20.        , 62.01577408]), array([20.        , 62.01783654]), array([20.        , 62.02310433]), array([ 1.        , 93.37328087]), array([ 1.00796543, 94.11679519]), array([ 1.        , 93.37328087]), array([ 1.        , 93.37328087])]
# [0.0008816409296240229, 0.0008816411046763394, 0.0008816410061793983, 0.0008816413928129913, 0.0008816412648944699, 0.0008816412826838699, 0.00088164089272568, 0.0008816410499029656, 0.000881641365797635, 0.0008816410860925999, 6.883151933455692e-18, 0.0008816416455391195, 0.0008816416861670492, 0.000881641092748082, 0.0008816415902315607, 0.0008816412143376418, 0.0008816412283832348, 0.0008816416291845053, 0.0008816411828573317, 0.0008816412682360878, 0.000881642033836684, 3.147913324633371e-17, 4.420395672628873e-19, 3.255716486598818e-18, 6.700695108782767e-19]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 16).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [9068.744594933092, 9069.163606601162, 9068.547485673223, 9067.822368928735, 9069.131417969855, 9067.773732291736, 9069.11597895962, 9068.37779448989, 9068.126040419924, 9069.027287973857, 10.000000000015, 9067.875438810173, 9067.918358045907, 9069.008737193682, 9069.250066529385, 9068.920498113108, 9068.432988681714, 9068.211530675633, 9068.971471125846, 9068.368248218216, 9066.827812357014, 10.000000000068596, 10.000000000000934, 9.999999999992905, 10.00000000000146]
# [9.732484676929284e-08, 9.732036454600642e-08, 9.732697295827836e-08, 9.733480707651178e-08, 9.732072802759331e-08, 9.7335317567135e-08, 9.732085280432966e-08, 9.732880101768972e-08, 9.733154096813199e-08, 9.73218269540932e-08, 4.5889034347829174e-07, 9.733426469540085e-08, 9.733380798071673e-08, 9.732202698164065e-08, 9.731948933487375e-08, 9.732298837607415e-08, 9.73282276840623e-08, 9.733065144248685e-08, 9.732243728412599e-08, 9.732892769175144e-08, 9.734556647237826e-08, 4.589076184681696e-07, 4.7309154715022686e-07, 4.5888969566444717e-07, 4.5889975661553183e-07]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/16/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    9.731949e-08         9069.250067    16.0       640.0
# 1    9.732036e-08         9069.163607    16.0       640.0
# 2    9.732073e-08         9069.131418    16.0       640.0
# 3    9.732085e-08         9069.115979    16.0       640.0
# 4    9.732183e-08         9069.027288    16.0       640.0
# 5    9.732203e-08         9069.008737    16.0       640.0
# 6    9.732244e-08         9068.971471    16.0       640.0
# 7    9.732299e-08         9068.920498    16.0       640.0
# 8    9.732485e-08         9068.744595    16.0       640.0
# 9    9.732697e-08         9068.547486    16.0       640.0
# 10   9.732823e-08         9068.432989    16.0       640.0
# 11   9.732880e-08         9068.377794    16.0       640.0
# 12   9.732893e-08         9068.368248    16.0       640.0
# 13   9.733065e-08         9068.211531    16.0       640.0
# 14   9.733154e-08         9068.126040    16.0       640.0
# 15   9.733381e-08         9067.918358    16.0       640.0
# 16   9.733426e-08         9067.875439    16.0       640.0
# 17   9.733481e-08         9067.822369    16.0       640.0
# 18   9.733532e-08         9067.773732    16.0       640.0
# 19   9.734557e-08         9066.827812    16.0       640.0
# 20   4.588897e-07           10.000000    16.0       640.0
# 21   4.588903e-07           10.000000    16.0       640.0
# 22   4.588998e-07           10.000000    16.0       640.0
# 23   4.589076e-07           10.000000    16.0       640.0
# 24   4.730915e-07           10.000000    16.0       640.0
#
#     stage2_cyl_diameter   stage2_D  stage1_cyl_diameter   stage1_D  \
# 0             20.000000  62.014822            20.000000  60.362443
# 1             20.000000  62.015117            20.000000  60.360574
# 2             20.000000  62.015227            20.000000  60.355522
# 3             20.000000  62.015280            20.000000  60.355360
# 4             20.000000  62.015583            20.000000  60.360468
# 5             20.000000  62.015647            20.000000  60.360563
# 6             20.000000  62.015774            20.000000  60.357258
# 7             20.000000  62.015948            20.000000  60.361760
# 8             20.000000  62.016550            20.000000  60.362792
# 9             20.000000  62.017224            20.000000  60.358675
# 10            20.000000  62.017615            20.000000  60.359427
# 11            20.000000  62.017804            20.000000  60.360153
# 12            20.000000  62.017837            20.000000  60.365646
# 13            20.000000  62.018372            20.000000  60.356219
# 14            20.000000  62.018665            20.000000  60.357044
# 15            20.000000  62.019375            20.000000  60.360057
# 16            20.000000  62.019522            20.000000  60.357337
# 17            20.000000  62.019703            20.000000  60.359934
# 18            20.000000  62.019869            20.000000  60.363077
# 19            20.000000  62.023104            20.000000  60.366695
# 20             1.000000  93.373281             5.597557  60.291728
# 21             1.000000  93.373281            19.999834  60.358220
# 22             1.000000  93.373281             3.312834  60.321147
# 23             1.000000  93.373281             8.214134  60.352318
# 24             1.007965  94.116795             6.848137  60.348305
#
#        objective
# 0   8.816416e-04
# 1   8.816411e-04
# 2   8.816413e-04
# 3   8.816409e-04
# 4   8.816411e-04
# 5   8.816411e-04
# 6   8.816412e-04
# 7   8.816412e-04
# 8   8.816409e-04
# 9   8.816410e-04
# 10  8.816412e-04
# 11  8.816410e-04
# 12  8.816413e-04
# 13  8.816416e-04
# 14  8.816414e-04
# 15  8.816417e-04
# 16  8.816416e-04
# 17  8.816414e-04
# 18  8.816413e-04
# 19  8.816420e-04
# 20  3.255716e-18
# 21  6.883152e-18
# 22  6.700695e-19
# 23  3.147913e-17
# 24  4.420396e-19
