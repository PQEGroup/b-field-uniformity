# %%
import numpy as np
import magpylib as magpy
from scipy.optimize import minimize, Bounds
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
from maggeometry import n_rings
from alive_progress import alive_bar

# %% [markdown]
# ### Nelder Mead Adaptive Optimization of 2 rings
# All variables can be optimized independently for each ring set
#
# 1. Run 50 shots using Nelder-Mead with nonuniformity cost function
# 2. Optimize for field strength using new cost function

# %%
Br = 1.09e3
mag_dir = (0,0,1)
mirror_z = True
base_ring_config = [Br, mag_dir, mirror_z]
# innerrad, width, thickness, dist
bounds = ((1, 150), (2, 20), (2, 20), (1, 300))

# %% [markdown]
# ### Definition of 2 ring objective function

# %%
from maggeometry import n_rings
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
def obj1_nonuniformity(x):
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maggeometry import n_rings
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 50
results_x = []
results_fun = []
guesses_x0 = []
with alive_bar(shots, force_tty=True) as bar:
    for i in range(shots):
        x0 = np.zeros(len(bounds))
        for b in range(len(bounds)):
            x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
        res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
        guesses_x0.append(x0)
        results_x.append(res.x)
        results_fun.append(res.fun)
        bar()

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# on 0: Optimization terminated successfully.
# on 0:          Current function value: 0.000010
# on 0:          Iterations: 468
# on 0:          Function evaluations: 824
# on 1: Optimization terminated successfully.
# on 1:          Current function value: 0.000010
# on 1:          Iterations: 603
# on 1:          Function evaluations: 1039
# on 2: Optimization terminated successfully.
# on 2:          Current function value: 0.000010
# on 2:          Iterations: 408
# on 2:          Function evaluations: 709
# on 3: Optimization terminated successfully.
# on 3:          Current function value: 0.000001
# on 3:          Iterations: 153
# on 3:          Function evaluations: 293
# on 4: Optimization terminated successfully.
# on 4:          Current function value: 0.000012
# on 4:          Iterations: 408
# on 4:          Function evaluations: 715
# on 5: Optimization terminated successfully.
# on 5:          Current function value: 0.000001
# on 5:          Iterations: 601
# on 5:          Function evaluations: 1078
# on 6: Optimization terminated successfully.
# on 6:          Current function value: 0.000283
# on 6:          Iterations: 61
# on 6:          Function evaluations: 116
# on 7: Optimization terminated successfully.
# on 7:          Current function value: 0.000437
# on 7:          Iterations: 28
# on 7:          Function evaluations: 52
# on 8: Optimization terminated successfully.
# on 8:          Current function value: 0.000283
# on 8:          Iterations: 80
# on 8:          Function evaluations: 145
# on 9: Optimization terminated successfully.
# on 9:          Current function value: 0.000001
# on 9:          Iterations: 205
# on 9:          Function evaluations: 382
# on 10: Optimization terminated successfully.
# on 10:          Current function value: 0.000283
# on 10:          Iterations: 38
# on 10:          Function evaluations: 69
# on 11: Optimization terminated successfully.
# on 11:          Current function value: 0.000283
# on 11:          Iterations: 47
# on 11:          Function evaluations: 84
# on 12: Optimization terminated successfully.
# on 12:          Current function value: 0.000283
# on 12:          Iterations: 61
# on 12:          Function evaluations: 104
# on 13: Optimization terminated successfully.
# on 13:          Current function value: 0.002238
# on 13:          Iterations: 44
# on 13:          Function evaluations: 76
# on 14: Optimization terminated successfully.
# on 14:          Current function value: 0.000001
# on 14:          Iterations: 634
# on 14:          Function evaluations: 1127
# on 15: Optimization terminated successfully.
# on 15:          Current function value: 0.000001
# on 15:          Iterations: 706
# on 15:          Function evaluations: 1269
# on 16: Optimization terminated successfully.
# on 16:          Current function value: 0.000287
# on 16:          Iterations: 55
# on 16:          Function evaluations: 97
# on 17: Optimization terminated successfully.
# on 17:          Current function value: 0.000001
# on 17:          Iterations: 199
# on 17:          Function evaluations: 372
# on 18: Optimization terminated successfully.
# on 18:          Current function value: 0.000001
# on 18:          Iterations: 374
# on 18:          Function evaluations: 670
# on 19: Optimization terminated successfully.
# on 19:          Current function value: 0.000283
# on 19:          Iterations: 51
# on 19:          Function evaluations: 86
# on 20: Optimization terminated successfully.
# on 20:          Current function value: 0.000009
# on 20:          Iterations: 1024
# on 20:          Function evaluations: 1773
# on 21: Optimization terminated successfully.
# on 21:          Current function value: 0.000001
# on 21:          Iterations: 246
# on 21:          Function evaluations: 434
# on 22: Optimization terminated successfully.
# on 22:          Current function value: 0.000010
# on 22:          Iterations: 706
# on 22:          Function evaluations: 1230
# on 23: Optimization terminated successfully.
# on 23:          Current function value: 0.000283
# on 23:          Iterations: 48
# on 23:          Function evaluations: 86
# on 24: Optimization terminated successfully.
# on 24:          Current function value: 0.000009
# on 24:          Iterations: 831
# on 24:          Function evaluations: 1451
# on 25: Optimization terminated successfully.
# on 25:          Current function value: 0.000001
# on 25:          Iterations: 277
# on 25:          Function evaluations: 496
# on 26: Optimization terminated successfully.
# on 26:          Current function value: 0.000001
# on 26:          Iterations: 228
# on 26:          Function evaluations: 412
# on 27: Optimization terminated successfully.
# on 27:          Current function value: 0.000001
# on 27:          Iterations: 492
# on 27:          Function evaluations: 890
# on 28: /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_54136/2633242801.py:19: RuntimeWarning: Maximum number of iterations has been exceeded.
#          res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
# on 29: Optimization terminated successfully.
# on 29:          Current function value: 0.000001
# on 29:          Iterations: 583
# on 29:          Function evaluations: 1040
# on 30: Optimization terminated successfully.
# on 30:          Current function value: 0.000010
# on 30:          Iterations: 221
# on 30:          Function evaluations: 399
# on 31: Optimization terminated successfully.
# on 31:          Current function value: 0.000001
# on 31:          Iterations: 239
# on 31:          Function evaluations: 448
# on 32: Optimization terminated successfully.
# on 32:          Current function value: 0.000001
# on 32:          Iterations: 736
# on 32:          Function evaluations: 1340
# on 33: Optimization terminated successfully.
# on 33:          Current function value: 0.000001
# on 33:          Iterations: 432
# on 33:          Function evaluations: 932
# on 34: Optimization terminated successfully.
# on 34:          Current function value: 0.000283
# on 34:          Iterations: 81
# on 34:          Function evaluations: 151
# on 35: Optimization terminated successfully.
# on 35:          Current function value: 0.000001
# on 35:          Iterations: 326
# on 35:          Function evaluations: 581
# on 36: Optimization terminated successfully.
# on 36:          Current function value: 0.000010
# on 36:          Iterations: 294
# on 36:          Function evaluations: 538
# on 37: Optimization terminated successfully.
# on 37:          Current function value: 0.000001
# on 37:          Iterations: 259
# on 37:          Function evaluations: 476
# on 38: Optimization terminated successfully.
# on 38:          Current function value: 0.000434
# on 38:          Iterations: 50
# on 38:          Function evaluations: 89
# on 39: Optimization terminated successfully.
# on 39:          Current function value: 0.000283
# on 39:          Iterations: 47
# on 39:          Function evaluations: 80
# on 40: Optimization terminated successfully.
# on 40:          Current function value: 0.000001
# on 40:          Iterations: 230
# on 40:          Function evaluations: 410
# on 41: Optimization terminated successfully.
# on 41:          Current function value: 0.000434
# on 41:          Iterations: 40
# on 41:          Function evaluations: 69
# on 42: Optimization terminated successfully.
# on 42:          Current function value: 0.000434
# on 42:          Iterations: 51
# on 42:          Function evaluations: 95
# on 43: Optimization terminated successfully.
# on 43:          Current function value: 0.000001
# on 43:          Iterations: 210
# on 43:          Function evaluations: 393
# on 44: Optimization terminated successfully.
# on 44:          Current function value: 0.000009
# on 44:          Iterations: 641
# on 44:          Function evaluations: 1092
# on 45: Optimization terminated successfully.
# on 45:          Current function value: 0.000287
# on 45:          Iterations: 35
# on 45:          Function evaluations: 63
# on 46: Optimization terminated successfully.
# on 46:          Current function value: 0.000001
# on 46:          Iterations: 328
# on 46:          Function evaluations: 582
# on 47: Optimization terminated successfully.
# on 47:          Current function value: 0.000001
# on 47:          Iterations: 295
# on 47:          Function evaluations: 538
# on 48: Optimization terminated successfully.
# on 48:          Current function value: 0.000001
# on 48:          Iterations: 439
# on 48:          Function evaluations: 777
# on 49: Optimization terminated successfully.
# on 49:          Current function value: 0.000283
# on 49:          Iterations: 48
# on 49:          Function evaluations: 85
# |████████████████████████████████████████| 50/50 [100%] in 14:48.1 (0.06/s)
# Objective function values:
# [9.608972835642003e-06, 9.59847838428125e-06, 9.608863231527988e-06, 7.959436318216096e-07, 1.1550067589165138e-05, 8.090894705342308e-07, 0.0002830875189033077, 0.00043735987226945655, 0.0002830875189033077, 7.971587255078131e-07, 0.0002830875189033077, 0.0002830875189033077, 0.0002830875189033077, 0.0022375150181476494, 7.971587195868254e-07, 7.970285465504155e-07, 0.0002867944253671033, 7.971664428572879e-07, 7.978371863788618e-07, 0.0002830875189033077, 9.377162915234788e-06, 9.523557558720817e-07, 9.608910333951428e-06, 0.0002830875189033077, 9.377396759603645e-06, 7.971647248724014e-07, 9.41011516916476e-07, 7.976520164762284
#         2.00000000e+00, 2.69979562e+02, 7.71221684e+01, 1.04117611e+01,
#         1.18101609e+01, 1.65478614e+02],
#        [8.09089471e-07, 2.81962541e+00, 1.49999997e+02, 1.88236730e+01,
#         2.16777652e+00, 2.69567821e+02, 8.17391697e+01, 5.86641151e+00,
#         1.66189714e+01, 1.19033467e+02],
#        [8.20126271e-07, 1.90022940e+01, 1.49999997e+02, 1.76806250e+01,
#         1.54648518e+01, 2.68928146e+02, 1.14456667e+02, 1.96051007e+01,
#         1.70774120e+01, 2.67357212e+02],
#        [8.91016103e-07, 1.63444847e+00, 1.49999978e+02, 1.12756429e+01,
#         2.00000000e+00, 2.63352830e+02, 5.15533001e+01, 1.02052679e+01,
#         1.09956072e+01, 1.66684972e+02],
#        [9.41011517e-07, 4.58849599e+00, 1.50000000e+02, 7.05009094e+00,
#         8.74247792e+00, 2.59930625e+02, 1.17310833e+02, 9.11893958e+00,
#         8.26532671e+00, 2.59729899e+02],
#        [9.52240574e-07, 1.06389773e+00, 1.50000000e+02, 6.16675118e+00,
#         2.30305298e+00, 2.59098805e+02, 9.98314065e+01, 4.99860114e+00,
#         7.45350095e+00, 9.49108458e+01],
#        [9.52355756e-07, 1.87828983e+00, 1.50000000e+02, 6.15393690e+00,
#         4.07441761e+00, 2.59102847e+02, 1.45314797e+02, 3.75526866e+00,
#         4.88980565e+00, 1.31001243e+02],
#        [9.67270507e-07, 3.50639457e+00, 1.49999998e+02, 4.94659757e+00,
#         9.39259867e+00, 2.58185229e+02, 9.34539017e+01, 4.18165314e+00,
#         1.11235503e+01, 1.26682546e+02],
#        [9.68692745e-07, 7.37418693e-01, 1.49999973e+02, 4.86251933e+00,
#         2.00726853e+00, 2.58003870e+02, 4.06362861e+01, 1.94056379e+01,
#         9.34027953e+00, 7.69654640e+01],
#        [9.96304855e-07, 3.69875163e+00, 1.49999974e+02, 2.62115955e+00,
#         1.84449204e+01, 2.56563592e+02, 8.47465746e+01, 3.99029451e+00,
#         1.65752484e+01, 1.78437135e+02]])

# %%
Br = 1.09e3
mag_dir = (0,0,1)
mirror_z = True
base_ring_config = [Br, mag_dir, mirror_z]
# innerrad, width, thickness, dist
bounds = ((1, 150), (2, 20), (2, 20), (1, 300))

# %%
# 10G target
field_strength_target = 10

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
alpha = 0.2
def obj2_nonuniformity(x):
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*abs(center_field - field_strength_target)
#     cost = alpha*av_nonuniformity * 1e6 + (1-alpha)*abs(center_field - field_strength_target)
    return cost

# %% [markdown]
# ### Optimize 2 rings 2nd stage

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
options2 = {'disp': True, 'fatol': 1e-17, 'maxiter': 5e3, 'adaptive': True}
with alive_bar(len(st2g), force_tty=True) as bar:
    for s0 in st2g:
        res2 = minimize(obj2_nonuniformity, s0[2:6], method=method2, options=options2, bounds=bounds)
        results2_x.append(res2.x)
        results2_fun.append(res2.fun)
        bar()
        
print(results2_x)
print(results2_fun)
# Out:
# on 0: /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_54289/3678240242.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#         res2 = minimize(obj2_nonuniformity, s0[2:6], method=method2, options=options2, bounds=bounds)
# on 1: Optimization terminated successfully.
# on 1:          Current function value: 0.000000
# on 1:          Iterations: 247
# on 1:          Function evaluations: 444
# on 2: Optimization terminated successfully.
# on 2:          Current function value: 0.000000
# on 2:          Iterations: 246
# on 2:          Function evaluations: 487
# on 3: Optimization terminated successfully.
# on 3:          Current function value: 0.000000
# on 3:          Iterations: 242
# on 3:          Function evaluations: 439
# on 4: Optimization terminated successfully.
# on 4:          Current function value: 0.000000
# on 4:          Iterations: 242
# on 4:          Function evaluations: 441
# on 5: Optimization terminated successfully.
# on 5:          Current function value: 0.000000
# on 5:          Iterations: 243
# on 5:          Function evaluations: 439
# on 6: Optimization terminated successfully.
# on 6:          Current function value: 0.000000
# on 6:          Iterations: 249
# on 6:          Function evaluations: 450
# on 7: Optimization terminated successfully.
# on 7:          Current function value: 0.000000
# on 7:          Iterations: 247
# on 7:          Function evaluations: 447
# on 8: Optimization terminated successfully.
# on 8:          Current function value: 0.000000
# on 8:          Iterations: 246
# on 8:          Function evaluations: 440
# on 9: Optimization terminated successfully.
# on 9:          Current function value: 0.000000
# on 9:          Iterations: 231
# on 9:          Function evaluations: 420
# on 10: Optimization terminated successfully.
# on 10:          Current function value: 0.000000
# on 10:          Iterations: 251
# on 10:          Function evaluations: 451
# on 11: Optimization terminated successfully.
# on 11:          Current function value: 0.000000
# on 11:          Iterations: 244
# on 11:          Function evaluations: 439
# on 12: Optimization terminated successfully.
# on 12:          Current function value: 0.000000
# on 12:          Iterations: 254
# on 12:          Function evaluations: 455
# on 13: Optimization terminated successfully.
# on 13:          Current function value: 0.000000
# on 13:          Iterations: 259
# on 13:          Function evaluations: 457
# on 14: Optimization terminated successfully.
# on 14:          Current function value: 0.000000
# on 14:          Iterations: 243
# on 14:          Function evaluations: 443
# on 15: Optimization terminated successfully.
# on 15:          Current function value: 0.000000
# on 15:          Iterations: 255
# on 15:          Function evaluations: 460
# on 16: Optimization terminated successfully.
# on 16:          Current function value: 0.000000
# on 16:          Iterations: 256
# on 16:          Function evaluations: 456
# on 17: Optimization terminated successfully.
# on 17:          Current function value: 0.000000
# on 17:          Iterations: 290
# on 17:          Function evaluations: 513
# on 18: Optimization terminated successfully.
# on 18:          Current function value: 0.000000
# on 18:          Iterations: 254
# on 18:          Function evaluations: 464
# on 19: Optimization terminated successfully.
# on 19:          Current function value: 0.000000
# on 19:          Iterations: 270
# on 19:          Function evaluations: 482
# on 20: Optimization terminated successfully.
# on 20:          Current function value: 0.000000
# on 20:          Iterations: 279
# on 20:          Function evaluations: 496
# on 21: Optimization terminated successfully.
# on 21:          Current function value: 0.000000
# on 21:          Iterations: 276
# on 21:          Function evaluations: 493
# |████████████████████████████████████████| 22/22 [100%] in 10:40.0 (0.03/s)
# %%
def make_opt_res2_csv(name, nonun, g_center, x, fun):
    r_f = np.array([fun])
    r_n = np.array([nonun])
    r_gc = np.array([g_center])
    r_x = np.array(x)

    a = np.concatenate((r_n.T, r_gc.T, r_x, r_f.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss']
    n = int(b.shape[1]) - len(columns)
    # need 4 specs to define a ring: innerrad, width, thickness, dist
    n_ring_sets = int(n/ 4)
    
    for i in range(1, n_ring_sets+1):
        columns.append('r_' + str(i) + '_innerrad')
        columns.append('r_' + str(i) + '_width')
        columns.append('r_' + str(i) + '_thickness')
        columns.append('r_' + str(i) + '_dist')
    
    columns.append('objective')
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_n.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

# %%
from maghelper import make_opt_res2_csv 
make_opt_res2_csv('results/2 rings/2023_07_13_adaptive_stage2opt_2rings_1090T_', results2_nonun, results2_g_center, results2_x, results2_fun)
# Out:
# Number of unique results: 22
#     nonuniformity  center_field_gauss  r_1_innerrad  r_1_width  r_1_thickness  \
# 0    7.959436e-07           27.373627    150.000000  20.000000      20.000000
# 1    7.973901e-07           10.000000    150.000000  19.963117       7.303095
# 2    7.980526e-07           10.000000    149.999973  19.988032       7.294967
# 3    8.418790e-07           10.000000    149.999941  19.571384       7.430387
# 4    8.429631e-07           10.000000    150.000000  20.000000       7.290414
# 5    8.436268e-07           10.000000    150.000000  19.999602       7.290535
# 6    8.440086e-07           10.000000    150.000000  20.000000       7.290404
# 7    8.620417e-07           10.000000    149.999997  17.640173       8.145608
# 8    8.849469e-07           10.000000    150.000000  19.999810       7.290128
# 9    9.122362e-07           10.000000    150.000000  19.999741       7.289962
# 10   9.607352e-07           10.000000    149.999961  19.998779       7.289973
# 11   9.637272e-07           10.000000    149.999997  19.999529       7.289720
# 12   9.673193e-07           10.000000    149.999986   6.922306      19.428013
# 13   9.752411e-07           10.000000    149.998477  20.000000       7.292921
# 14   9.782581e-07           10.000000    149.999885  19.988359       7.296787
# 15   1.063986e-06           10.000000    149.999535  11.735514      11.798764
# 16   1.136074e-06           10.000000    149.997569   6.874508      19.560287
# 17   1.376317e-06           10.000000    150.000000   7.449240      18.100915
# 18   1.974021e-06           10.000000    149.994455   6.736356      19.952415
# 19   2.938779e-06           10.000000    150.000000   7.423351      18.150326
# 20   3.336012e-06           10.000000    150.000000   6.864327      19.561599
# 21   1.396613e-04           10.000000    149.999862  19.996339       7.735768
#
#       r_1_dist     objective
# 0   271.023541  1.382843e-05
# 1   270.559669  1.259932e-17
# 2   270.575560  2.122186e-17
# 3   270.218460  1.523144e-17
# 4   270.564171  1.394831e-17
# 5   270.563667  1.463366e-17
# 6   270.563883  1.527746e-17
st1 = pd.read_csv('results/2 rings/2023_07_13_adaptive_stage1opt_2rings_1090T_38.csv')
st1 = np.delete(st1.to_numpy(), 0, axis=1) #remove first column of indices
min_nonun = st1[0][0]
# nonun_threshold = min_nonun*guess_threshold
nonun_threshold = 1e-6
print("Nonuniformity threshold:", nonun_threshold)
st2g = st1[st1[:,0] < nonun_threshold]

# 10G target
field_strength_target = 10
Br = 1.09e3
mag_dir = (0,0,1)
mirror_z = True
base_ring_config = [Br, mag_dir, mirror_z]
# innerrad, width, thickness, dist
bounds2 = ((1, 150), (2, 20), (2, 20), (1, 300))

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
alpha = 0.2
def obj2_nonuniformity(x):
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
#     cost = av_nonuniformity*abs(center_field - field_strength_target)
    cost = alpha*av_nonuniformity * 1e6 + (1-alpha)*abs(center_field - field_strength_target)
    return cost

results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
options2 = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
with alive_bar(len(st2g), force_tty=True) as bar:
    for s0 in st2g:
        res2 = minimize(obj2_nonuniformity, s0[2:6], method=method2, options=options2, bounds=bounds2)
        results2_x.append(res2.x)
        results2_fun.append(res2.fun)
        bar()
        
print(results2_x)
print(results2_fun)
# Out:
# Nonuniformity threshold: 1e-06
# on 0: /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_54427/2064920539.py:40: RuntimeWarning: Maximum number of iterations has been exceeded.
#         res2 = minimize(obj2_nonuniformity, s0[2:6], method=method2, options=options2, bounds=bounds2)
# |█████▌⚠︎                                 | (!) 3/22 [14%] in 31:03.0 (0.00/s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 40
#      38 with alive_bar(len(st2g), force_tty=True) as bar:
#      39     for s0 in st2g:
# ---> 40         res2 = minimize(obj2_nonuniformity, s0[2:6], method=method2, options=options2, bounds=bounds2)
#      41         results2_x.append(res2.x)
#      42         results2_fun.append(res2.fun)
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/scipy/optimize/_minimize.py:684, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     681     bounds = standardize_bounds(bounds, x0, meth)
#     683 if meth == 'nelder-mead':
# --> 684     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     685                                **options)
#     686 elif meth == 'powell':
#     687     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/scipy/optimize/_optimize.py:921, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     918                     if bounds is not None:
#     919                         sim[j] = np.clip(
#     920                             sim[j], lower_bound, upper_bound)
# --> 921                     fsim[j] = func(sim[j])
#     922     iterations += 1
#     923 except _MaxFuncCallError:
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/scipy/optimize/_optimize.py:569, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     567 ncalls[0] += 1
#     568 # A copy of x is sent to the user function (gh13740)
# --> 569 fx = function(np.copy(x), *(wrapper_args + args))
#     570 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     571 # backwards-compatibility, also allow np.array([1.3]),
#     572 # np.array([[1.3]]) etc.
#     573 if not np.isscalar(fx):
#
# Cell In[4], line 29, in obj2_nonuniformity(x)
#      27     obj_ring_config=[[*base_ring_config, *x]]
#      28     magnets = n_rings(obj_ring_config)
# ---> 29     grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
#      30 #     cost = av_nonuniformity*abs(center_field - field_strength_target)
#      31     cost = alpha*av_nonuniformity * 1e6 + (1-alpha)*abs(center_field - field_strength_target)
#
# File ~/Documents/quantum/quantum_notes/projects/b_field/simulations/b-field-uniformity/maghelper.py:491, in get_grid_nonuniformity(magnets, grid, grid_res, use_z)
#     490 def get_grid_nonuniformity(magnets, grid, grid_res, use_z=False):
# --> 491     Gmag, Gnon, Gcenter, av_nonuniformity, max_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res, use_z)
#     492     return Gnon, Gcenter, av_nonuniformity, max_nonuniformity
#
# File ~/Documents/quantum/quantum_notes/projects/b_field/simulations/b-field-uniformity/maghelper.py:467, in get_grid_mag_and_nonuniformity(magnets, grid, grid_res, use_z)
#     465 def get_grid_mag_and_nonuniformity(magnets, grid, grid_res, use_z=False):
#     466     mT_to_G = 10
# --> 467     B = magnets.getB(grid)
#     468     G = B * mT_to_G
#     469     # find magnitude of the b-field at all points over grid
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/obj_classes/class_Collection.py:580, in BaseCollection.getB(self, squeeze, pixel_agg, output, *inputs)
#     520 """Compute B-field in [mT] for given sources and observers.
#     521
#     522 Parameters
#    (...)
#     575   [ 0.          0.         83.33333333]]]
#     576 """
#     578 sources, sensors = self._validate_getBH_inputs(*inputs)
# --> 580 return getBH_level2(
#     581     sources,
#     582     sensors,
#     583     sumup=False,
#     584     squeeze=squeeze,
#     585     pixel_agg=pixel_agg,
#     586     output=output,
#     587     field="B",
#     588 )
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/field_wrap_BH.py:311, in getBH_level2(sources, observers, field, sumup, squeeze, pixel_agg, output, **kwargs)
#     309 gr = group["sources"]
#     310 src_dict = get_src_dict(gr, n_pix, n_pp, poso)  # compute array dict for level1
# --> 311 B_group = getBH_level1(
#     312     field_func=field_func, field=field, **src_dict
#     313 )  # compute field
#     314 B_group = B_group.reshape(
#     315     (lg, max_path_len, n_pix, 3)
#     316 )  # reshape (2% slower for large arrays)
#     317 for gr_ind in range(lg):  # put into dedicated positions in B
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/field_wrap_BH.py:140, in getBH_level1(field_func, field, position, orientation, observers, **kwargs)
#     137 pos_rel_rot = orientation.apply(observers - position, inverse=True)
#     139 # compute field
# --> 140 BH = field_func(field=field, observers=pos_rel_rot, **kwargs)
#     142 # transform field back into global CS
#     143 BH = orientation.apply(BH)
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/field_BH_cylinder_segment.py:2338, in magnet_cylinder_segment_field_internal(field, observers, magnetization, dimension)
#    2336 # case2a: hollow cylinder <- should be vectorized together with above
#    2337 mask2 = (r1 != 0) & mask1x
# -> 2338 BHfinal[mask2] -= magnet_cylinder_field(
#    2339     field,
#    2340     observers[mask2],
#    2341     magnetization[mask2],
#    2342     np.c_[2 * r1[mask2], h[mask2]],
#    2343 )
#    2345 return BHfinal
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/field_BH_cylinder.py:374, in magnet_cylinder_field(field, observers, magnetization, dimension)
#     372 # axial magnetization contributions -----------------------------
#     373 if any(mask_ax):
# --> 374     br_ax, bz_ax = fieldB_cylinder_axial(z0[mask_ax], r[mask_ax], z[mask_ax])
#     375     Br[mask_ax] += magz[mask_ax] * br_ax
#     376     Bz[mask_ax] += magz[mask_ax] * bz_ax
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/field_BH_cylinder.py:51, in fieldB_cylinder_axial(z0, r, z)
#      48 one = np.ones(n)
#      50 # radial field (unit magnetization)
# ---> 51 Br = (cel(k1, one, one, -one) / sq1 - cel(k0, one, one, -one) / sq0) / np.pi
#      53 # axial field (unit magnetization)
#      54 Bz = (
#      55     1
#      56     / dpr
#    (...)
#      61     / np.pi
#      62 )
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/special_cel.py:132, in cel(kcv, pv, cv, sv)
#     129 if n_input < 10:
#     130     return np.array([cel0(kc, p, c, s) for kc, p, c, s in zip(kcv, pv, cv, sv)])
# --> 132 return celv(kcv, pv, cv, sv)
#
# File /opt/homebrew/anaconda3/envs/pqe/lib/python3.11/site-packages/magpylib/_src/fields/special_cel.py:72, in celv(kc, p, c, s)
#      69 mask = p <= 0
#      71 # if p>0:
# ---> 72 pp[~mask] = np.sqrt(p[~mask])
#      73 ss[~mask] = s[~mask] / pp[~mask]
#      75 # else:
#
# KeyboardInterrupt:

# %%
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_nonun = []
results2_g_center = []
print(results2_x)
print(results2_fun)
for x in results2_x:
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    results2_nonun.append(obj1_nonuniformity(x))
    results2_g_center.append(center_field)

print(results2_nonun)
print(results2_g_center)
# Out:
# [array([150.        ,  20.        ,  20.        , 271.02624605]), array([149.999999  ,  19.99985767,   7.29131183, 270.58872114]), array([149.99998338,  19.99667535,   7.29234498, 270.58663141])]
# [14.057950947068836, 0.15940514441094852, 0.15940954011131594]
# [7.966516559649687e-07, 7.970256867996016e-07, 7.970476826015555e-07]
# [27.373275769844803, 10.000000008813785, 10.000000004488756]
