# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 7 main
# n = 7
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 7
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [1.7334921079464718, 101.81135692759388]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 109
#          Function evaluations: 261
# [17.239434673880613, 174.1643020393193]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 76
# [3.426327193108807, 74.96571242905586]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 88
# [18.557736736678187, 169.0133622941936]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 79
# [6.168912831171517, 297.665637331466]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 96
# [17.145396339351663, 251.86767863350872]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 95
# [10.765019287956134, 58.01150822019423]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 88
# [8.504881657178455, 94.01903079873337]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 49
#          Function evaluations: 99
# [16.360107378220704, 167.7515479547293]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 73
# [3.9643658170406875, 249.7540697090905]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 67
#          Function evaluations: 129
# [3.060719753287596, 201.10577010939343]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 111
# [13.565794760133796, 100.72661652092785]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 93
# [12.56484076574542, 290.96487085680667]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 87
# [4.311047009967769, 276.74966654751313]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 69
#          Function evaluations: 136
# [19.094797544790108, 108.71914453058763]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 77
# [5.5337396462068655, 289.1271810796102]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 61
#          Function evaluations: 125
# [17.921017558396255, 102.66350224676636]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 32
#          Function evaluations: 68
# [2.643363947770956, 255.72375309218955]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 55
#          Function evaluations: 127
# [6.584531668708737, 255.1483586048193]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 62
#          Function evaluations: 126
# [11.178746882696572, 138.7162562307414]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations:
# [array([ 8.34358734, 50.69241176]), array([20.        , 50.71707293]), array([20.        , 50.71758445]), array([ 2.82936851, 50.64949677]), array([20.        , 50.71277821]), array([19.99657538, 50.70699887]), array([ 4.44424855, 50.7112574 ]), array([20.        , 50.71490322]), array([ 2.44389602, 50.65903755]), array([20.       , 50.7184983]), array([ 8.4428112 , 22.91796283]), array([ 8.74727022, 50.70969275]), array([ 1.89504876, 50.68998326]), array([20.        , 50.71253783]), array([ 4.02387395, 50.68464753]), array([ 9.72813987, 50.71424828]), array([20.        , 50.71292173]), array([ 6.72834649, 50.71538985]), array([ 2.05811186, 50.68144609]), array([20.        , 50.71506164]), array([20.        , 50.71332937]), array([ 4.39039334, 50.70653856]), array([20.        , 50.71071062]), array([19.996647  , 50.71143127]), array([20.        , 50.71780311])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 20).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [2952.839774741462, 16950.081351585686, 16949.739438663615, 340.1331314007339, 16952.952463240876, 16951.01065120878, 837.1592246420926, 16951.531753540377, 253.67154227024065, 16949.128622573062, 14792.731148622395, 3243.271280471382, 152.34094273130233, 16953.1131807668, 686.9988849791622, 4010.6962694160084, 16952.856507119992, 1918.480127124212, 179.7463634440992, 16951.425851152148, 16952.583959427706, 817.1449094233478, 16954.334947804407, 16948.168928066996, 16949.59327765279]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [4.667109136247317e-08, 4.6509281716138064e-08, 4.6509277690546795e-08, 4.6697203891585186e-08, 4.6509235533793164e-08, 4.6509341554141656e-08, 4.669464029679305e-08, 4.6509272812305944e-08, 4.669656098205972e-08, 4.650926759193496e-08, 0.11417449445200617, 4.6667765961158566e-08, 4.66924300707056e-08, 4.6509195799841105e-08, 4.669534437596689e-08, 4.6658816022715904e-08, 4.6509251765984454e-08, 4.668277327067187e-08, 4.669089710640207e-08, 4.650926716054473e-08, 4.65092513068992e-08, 4.669395935451796e-08, 4.6509262995343646e-08, 4.6509329268187796e-08, 4.650927032043707e-08]
# [4.667109136247317e-08, 4.6509281716138064e-08, 4.6509277690546795e-08, 4.6697203891585186e-08, 4.6509235533793164e-08, 4.6509341554141656e-08, 4.669464029679305e-08, 4.6509272812305944e-08, 4.669656098205972e-08, 4.650926759193496e-08, 0.11417449445200617, 4.6667765961158566e-08, 4.66924300707056e-08, 4.6509195799841105e-08, 4.669534437596689e-08, 4.6658816022715904e-08, 4.6509251765984454e-08, 4.668277327067187e-08, 4.669089710640207e-08, 4.650926716054473e-08, 4.65092513068992e-08, 4.669395935451796e-08, 4.6509262995343646e-08, 4.6509329268187796e-08, 4.650927032043707e-08]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/20/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    4.650920e-08        16953.113181    20.0       640.0     20.000000
# 1    4.650924e-08        16952.952463    20.0       640.0     20.000000
# 2    4.650925e-08        16952.583959    20.0       640.0     20.000000
# 3    4.650925e-08        16952.856507    20.0       640.0     20.000000
# 4    4.650926e-08        16954.334948    20.0       640.0     20.000000
# 5    4.650927e-08        16951.425851    20.0       640.0     20.000000
# 6    4.650927e-08        16949.128623    20.0       640.0     20.000000
# 7    4.650927e-08        16949.593278    20.0       640.0     20.000000
# 8    4.650927e-08        16951.531754    20.0       640.0     20.000000
# 9    4.650928e-08        16949.739439    20.0       640.0     20.000000
# 10   4.650928e-08        16950.081352    20.0       640.0     20.000000
# 11   4.650933e-08        16948.168928    20.0       640.0     19.996647
# 12   4.650934e-08        16951.010651    20.0       640.0     19.996575
# 13   4.665882e-08         4010.696269    20.0       640.0      9.728140
# 14   4.666777e-08         3243.271280    20.0       640.0      8.747270
# 15   4.667109e-08         2952.839775    20.0       640.0      8.343587
# 16   4.668277e-08         1918.480127    20.0       640.0      6.728346
# 17   4.669090e-08          179.746363    20.0       640.0      2.058112
# 18   4.669243e-08          152.340943    20.0       640.0      1.895049
# 19   4.669396e-08          817.144909    20.0       640.0      4.390393
# 20   4.669464e-08          837.159225    20.0       640.0      4.444249
# 21   4.669534e-08          686.998885    20.0       640.0      4.023874
# 22   4.669656e-08          253.671542    20.0       640.0      2.443896
# 23   4.669720e-08          340.133131    20.0       640.0      2.829369
# 24   1.141745e-01        14792.731149    20.0       640.0      8.442811
#
#             D  g_cyl_diameter         g_D
# 0   50.712538        7.453630  156.326231
# 1   50.712778       14.131991  185.884221
# 2   50.713329       11.118856  114.810042
# 3   50.712922       13.316059  164.881940
# 4   50.710711       15.508547  137.199592
# 5   50.715062       18.408236  264.667239
# 6   50.718498       17.490131   35.732633
# 7   50.717803       15.912088  153.398354
# 8   50.714903       17.791904  113.542432
# 9   50.717584       15.359869  143.692169
# 10  50.717073       18.662337  192.784818
# 11  50.711431       11.315983  226.996858
# 12  50.706999       13.137488  264.936493
# 13  50.714248        5.899967  179.090948
# 14  50.709693        5.250190  245.481378
# 15  50.692412        5.093923  173.814570
# 16  50.715390        4.764260   94.618723
# 17  50.681446        1.341041  112.665012
# 18  50.689983        1.523665   26.401147
# 19  50.706539        2.605479  214.557635
# 20  50.711257        1.723116  293.172285
# 21  50.684648        2.402856  213.113916
# 22  50.659038       13.594344   29.908752
# 23  50.649497        2.749315   53.845680
# 24  22.917963        8.129496   22.437600

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/20/2023_08_13_pippin1_halbach20main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[ 20.         640.          20.          50.71253783   7.45362974
#   156.32623084]
#  [ 20.         640.          20.          50.71277821  14.13199127
#   185.88422073]
#  [ 20.         640.          20.          50.71332937  11.11885608
#   114.81004174]
#  [ 20.         640.          20.          50.71292173  13.31605937
#   164.8819402 ]
#  [ 20.         640.          20.          50.71071062  15.50854707
#   137.19959219]
#  [ 20.         640.          20.          50.71506164  18.40823627
#   264.66723923]
#  [ 20.         640.          20.          50.7184983   17.49013098
#    35.73263254]
#  [ 20.         640.          20.          50.71780311  15.91208756
#   153.39835437]
#  [ 20.         640.          20.          50.71490322  17.79190442
#   113.542432  ]
#  [ 20.         640.          20.          50.71758445  15.35986864
#   143.69216857]
#  [ 20.         640.          20.          50.71707293  18.66233742
#   192.78481824]
#  [ 20.         640.          19.996647    50.71143127  11.31598291
#   226.99685763]
#  [ 20.         640.          19.99657538  50.70699887  13.13748761
#   264.93649328]
#  [ 20.         640.           9.72813987  50.71424828   5.89996708
#   179.090948  ]
#  [ 20.         640.           8.74727022  50.70969275   5.25018998
#   245.48137787]
#  [ 20.         640.           8.34358734  50.69241176   5.09392259
#   173.81457018]
#  [ 20.         640.           6.72834649  50.71538985   4.76425992
#    94.61872312]
#  [ 20.         640.           2.05811186  50.68144609   1.34104071
#   112.6650117 ]
#  [ 20.         640.           1.89504876  50.68998326   1.52366507
#    26.40114664]
#  [ 20.         640.           4.39039334  50.70653856   2.60547895
#   214.55763453]
#  [ 20.         640.           4.44424855  50.7112574    1.72311587
#   293.17228484]
#  [ 20.         640.           4.02387395  50.68464753   2.40285605
#   213.11391557]
#  [ 20.         640.           2.44389602  50.65903755  13.59434399
#    29.90875164]
#  [ 20.         640.           2.82936851  50.64949677   2.7493151
#    53.84568025]
#  [ 20.         640.           8.4428112   22.91796283   8.12949581
#    22.4375997 ]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 20
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_5347/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.000772
#          Iterations: 62
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 0.000772
#          Iterations: 58
#          Function evaluations: 155
# Optimization terminated successfully.
#          Current function value: 0.000772
#          Iterations: 61
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 0.000772
#          Iterations: 60
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 106
#          Function evaluations: 264
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 109
#          Function evaluations: 252
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 97
#          Function evaluations: 246
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 105
#          Function evaluations: 251
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 99
#          Function evaluations: 239
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 105
#          Function evaluations: 254
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 95
#          Function evaluations: 237
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 95
#          Function evaluations: 196
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 97
#          Function evaluations: 242
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 95
#          Function evaluations: 194
# Optimization terminated successfully.
#          Current function value: 1687.810855
#          Iterations: 66
#          Function evaluations: 214
# [array([20.        , 51.83030974]), array([20.        , 51.83145438]), array([20.        , 51.82767223]), array([20.        , 51.83101103]), array([20.        , 51.83865592]), array([20.        , 51.83147932]), array([20.        , 51.82456027]), array([20.       , 51.8297303]), array([20.        , 51.82417505]), array([20.        , 51.82950805]), array([20.        , 51.82779608]), array([ 1.        , 52.32137967]), array([ 1.        , 52.36867401]), array([ 1.       , 52.4863697]), array([ 1.        , 52.28756028]), array([ 1.        , 52.52038253]), array([ 1.        , 52.20629486]), array([ 1.        , 52.41874249]), array([ 1.       , 52.1532543]), array([ 1.        , 52.30338126]), array([ 1.        , 52.29675448]), array([  1.        , 104.38980226]), array([ 1.        , 52.12075161]), array([  1.        , 104.38980226]), array([ 8.4428112 , 22.91796283])]
# [0.0007721766158259878, 0.0007721763740172146, 0.0007721758100704063, 0.0007721768264497347, 0.0007721770850577681, 0.0007721763229801451, 0.0007721772246473002, 0.0007721765201132748, 0.0007721772631242135, 0.0007721766676973791, 0.0007721764941672466, 1.4563097356051788e-06, 1.4563740874463763e-06, 1.4566567656851238e-06, 1.456308798182612e-06, 1.4567567672143726e-06, 1.4569942662580341e-06, 1.4565858863724393e-06, 1.456950164922387e-06, 1.4568157541706032e-06, 1.4564416301482642e-06, 3.900599901856783e-18, 1.4573398869241424e-06, 2.6906515839929278e-17, 1687.8108554849387]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 20).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [16229.755153091219, 16229.038307205861, 16231.407111682027, 16229.315957637247, 16224.529333429111, 16229.0226870453, 16233.356558221283, 16230.11805332515, 16233.597900946414, 16230.257253150337, 16231.329537647573, 39.81630262503445, 39.744416229328216, 39.5663640359069, 39.86782703909588, 39.51513161907513, 39.99204591980982, 39.66852513424777, 40.073434836670245, 39.843711076773246, 39.85380962811382, 10.00000000000554, 40.12343191998386, 10.000000000038218, 14792.73114843142]
# [4.760716845215901e-08, 4.76092576755398e-08, 4.7602270552368745e-08, 4.76084705709267e-08, 4.7622540819966256e-08, 4.7609300380158494e-08, 4.759663771650231e-08, 4.760609741400602e-08, 4.759593203916673e-08, 4.7605697964340554e-08, 4.7602540369772185e-08, 4.8842733920416666e-08, 4.896294068163222e-08, 4.926736219293267e-08, 4.8758444873688255e-08, 4.935626871041617e-08, 4.857935567828955e-08, 4.90953250888442e-08, 4.844641700674128e-08, 4.881483239208857e-08, 4.878578808838887e-08, 7.040213315374961e-07, 4.837894602431885e-08, 7.040214658990463e-07, 0.11417449445152296]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/20/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    4.759593e-08        16233.597901    20.0       640.0
# 1    4.759664e-08        16233.356558    20.0       640.0
# 2    4.760227e-08        16231.407112    20.0       640.0
