# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 7 main
# n = 7
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 7
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [1.7334921079464718, 101.81135692759388]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 109
#          Function evaluations: 261
# [17.239434673880613, 174.1643020393193]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 76
# [3.426327193108807, 74.96571242905586]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 88
# [18.557736736678187, 169.0133622941936]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 79
# [6.168912831171517, 297.665637331466]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 96
# [17.145396339351663, 251.86767863350872]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 95
# [10.765019287956134, 58.01150822019423]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 88
# [8.504881657178455, 94.01903079873337]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 49
#          Function evaluations: 99
# [16.360107378220704, 167.7515479547293]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 73
# [3.9643658170406875, 249.7540697090905]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 67
#          Function evaluations: 129
# [3.060719753287596, 201.10577010939343]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 111
# [13.565794760133796, 100.72661652092785]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 93
# [12.56484076574542, 290.96487085680667]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 87
# [4.311047009967769, 276.74966654751313]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 69
#          Function evaluations: 136
# [19.094797544790108, 108.71914453058763]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 36
#          Function evaluations: 77
# [5.5337396462068655, 289.1271810796102]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 61
#          Function evaluations: 125
# [17.921017558396255, 102.66350224676636]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 32
#          Function evaluations: 68
# [2.643363947770956, 255.72375309218955]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 55
#          Function evaluations: 127
# [6.584531668708737, 255.1483586048193]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 62
#          Function evaluations: 126
# [11.178746882696572, 138.7162562307414]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 51
#          Function evaluations: 105
# [19.26497523833116, 142.31867396604787]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations:
# [array([ 2.08803864, 68.23484796]), array([20.        , 68.22818856]), array([ 3.85019507, 68.21907284]), array([20.        , 68.22946244]), array([20.        , 68.22813846]), array([20.        , 68.23077976]), array([20.        , 68.23138812]), array([20.        , 68.23264515]), array([20.        , 68.23045246]), array([20.        , 68.23069325]), array([ 5.00016359, 68.2347935 ]), array([20.        , 68.22768733]), array([20.        , 68.22931276]), array([20.        , 68.22704152]), array([20.        , 68.22717931]), array([20.        , 68.22601725]), array([20.        , 68.22923712]), array([ 4.45898672, 68.21349784]), array([20.       , 68.2252105]), array([20.        , 68.22850972]), array([20.        , 68.23374315]), array([20.        , 68.22655466]), array([ 2.68813576, 68.20655013]), array([ 4.63559696, 68.21595637]), array([20.        , 68.23451278])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 7).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [35.72222483271787, 3277.9796833186, 121.51440178951879, 3277.8572702042334, 3277.9844977232005, 3277.730689041322, 3277.672234128503, 3277.551456655785, 3277.762138265473, 3277.739001883774, 204.8474475493956, 3278.0278508916945, 3277.871653225435, 3278.08991424464, 3278.0766721664804, 3278.1883508400897, 3277.8789212897873, 163.00676855226098, 3278.265887184356, 3277.9488211626426, 3277.445965084371, 3278.136703472503, 59.2548841717991, 176.1624370460278, 3277.372024487975]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [1.557165035646995e-07, 1.551282231232626e-07, 1.5570944276841346e-07, 1.551282169501224e-07, 1.5512820891351855e-07, 1.5512821790056308e-07, 1.551282500778392e-07, 1.5512825427082307e-07, 1.551282328504232e-07, 1.551282410640955e-07, 1.5569469365750532e-07, 1.551282236962867e-07, 1.5512824643600397e-07, 1.5512821900847487e-07, 1.5512821987997394e-07, 1.551282235819569e-07, 1.551282245770492e-07, 1.557018674965506e-07, 1.551282013901364e-07, 1.5512823892538945e-07, 1.5512826464421294e-07, 1.5512821052428389e-07, 1.5571762193835344e-07, 1.556989278047357e-07, 1.5512825923499605e-07]
# [1.557165035646995e-07, 1.551282231232626e-07, 1.5570944276841346e-07, 1.551282169501224e-07, 1.5512820891351855e-07, 1.5512821790056308e-07, 1.551282500778392e-07, 1.5512825427082307e-07, 1.551282328504232e-07, 1.551282410640955e-07, 1.5569469365750532e-07, 1.551282236962867e-07, 1.5512824643600397e-07, 1.5512821900847487e-07, 1.5512821987997394e-07, 1.551282235819569e-07, 1.551282245770492e-07, 1.557018674965506e-07, 1.551282013901364e-07, 1.5512823892538945e-07, 1.5512826464421294e-07, 1.5512821052428389e-07, 1.5571762193835344e-07, 1.556989278047357e-07, 1.5512825923499605e-07]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/7/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    1.551282e-07         3278.265887     7.0       640.0     20.000000
# 1    1.551282e-07         3277.984498     7.0       640.0     20.000000
# 2    1.551282e-07         3278.136703     7.0       640.0     20.000000
# 3    1.551282e-07         3277.857270     7.0       640.0     20.000000
# 4    1.551282e-07         3277.730689     7.0       640.0     20.000000
# 5    1.551282e-07         3278.089914     7.0       640.0     20.000000
# 6    1.551282e-07         3278.076672     7.0       640.0     20.000000
# 7    1.551282e-07         3277.979683     7.0       640.0     20.000000
# 8    1.551282e-07         3278.188351     7.0       640.0     20.000000
# 9    1.551282e-07         3278.027851     7.0       640.0     20.000000
# 10   1.551282e-07         3277.878921     7.0       640.0     20.000000
# 11   1.551282e-07         3277.762138     7.0       640.0     20.000000
# 12   1.551282e-07         3277.948821     7.0       640.0     20.000000
# 13   1.551282e-07         3277.739002     7.0       640.0     20.000000
# 14   1.551282e-07         3277.871653     7.0       640.0     20.000000
# 15   1.551283e-07         3277.672234     7.0       640.0     20.000000
# 16   1.551283e-07         3277.551457     7.0       640.0     20.000000
# 17   1.551283e-07         3277.372024     7.0       640.0     20.000000
# 18   1.551283e-07         3277.445965     7.0       640.0     20.000000
# 19   1.556947e-07          204.847448     7.0       640.0      5.000164
# 20   1.556989e-07          176.162437     7.0       640.0      4.635597
# 21   1.557019e-07          163.006769     7.0       640.0      4.458987
# 22   1.557094e-07          121.514402     7.0       640.0      3.850195
# 23   1.557165e-07           35.722225     7.0       640.0      2.088039
# 24   1.557176e-07           59.254884     7.0       640.0      2.688136
#
#             D  g_cyl_diameter         g_D
# 0   68.225210        6.584532  255.148359
# 1   68.228138        6.168913  297.665637
# 2   68.226555       14.296007   86.231881
# 3   68.229462       18.557737  169.013362
# 4   68.230780       17.145396  251.867679
# 5   68.227042        4.311047  276.749667
# 6   68.227179       19.094798  108.719145
# 7   68.228189       17.239435  174.164302
# 8   68.226017        5.533740  289.127181
# 9   68.227687       13.565795  100.726617
# 10  68.229237       17.921018  102.663502
center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_7594/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 57
#          Function evaluations: 154
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 59
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 58
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 63
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 62
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 60
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 59
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 64
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 78
#          Function evaluations: 195
# Optimization terminated successfully.
#          Current function value: 0.000493
#          Iterations: 64
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 81
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 129
#          Function evaluations: 278
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 112
#          Function evaluations: 234
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 121
#          Function evaluations: 272
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 98
#          Function evaluations: 203
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 133
#          Function evaluations: 283
# [array([20.        , 70.33601123]), array([20.        , 70.33569833]), array([20.        , 70.33364948]), array([20.        , 70.33956184]), array([20.        , 70.33633898]), array([20.        , 70.33560811]), array([20.       , 70.3374944]), array([20.        , 70.33199538]), array([20.        , 70.33127335]), array([20.        , 70.33522025]), array([20.        , 70.33225011]), array([20.        , 70.33262759]), array([20.       , 70.3377598]), array([20.        , 70.33666634]), array([20.        , 70.33606301]), array([20.        , 70.33987685]), array([20.        , 70.34492528]), array([20.        , 70.33768878]), array([20.        , 70.33460405]), array([ 1.        , 61.76469708]), array([ 1.34828479, 83.27338345]), array([ 1.38896549, 85.7853663 ]), array([ 1.40392525, 86.70909215]), array([ 1.35676257, 83.79688212]), array([ 1.25700374, 77.6366221 ])]
# [0.0004927136195020899, 0.0004927136490053344, 0.0004927135680423543, 0.0004927135674403749, 0.0004927136856227187, 0.0004927135552245786, 0.000492713566409171, 0.0004927135387884757, 0.0004927135272231495, 0.0004927135750837795, 0.0004927135747908491, 0.0004927135523709625, 0.0004927135727264415, 0.0004927136748568456, 0.0004927135697973216, 0.0004927136824969106, 0.0004927137390008984, 0.000492713571877559, 0.0004927135452161775, 1.5074399229591746e-20, 2.6682731665099302e-20, 8.925570858389436e-20, 4.223805495478373e-20, 1.5011083120495435e-20, 2.351420552911657e-18]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 7).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [3084.43647292456, 3084.463919496655, 3084.6436443335315, 3084.125055001391, 3084.4077248712747, 3084.471832961387, 3084.3063813283716, 3084.788753897994, 3084.852098628822, 3084.5058552460005, 3084.76640680281, 3084.7332904257337, 3084.283102946702, 3084.3790106112547, 3084.4319315376356, 3084.0974277149576, 3083.6547253131175, 3084.289331879773, 3084.559907471155, 9.999999999999938, 10.00000000000009, 9.99999999999973, 10.000000000000123, 9.99999999999995, 9.99999999998952]
# [1.60261441028702e-07, 1.6026001992763684e-07, 1.6025062577590398e-07, 1.602776590492842e-07, 1.6026296110199524e-07, 1.6025957692706782e-07, 1.6026820534272035e-07, 1.6024305349882956e-07, 1.6023974858591302e-07, 1.6025780996418237e-07, 1.6024422983831814e-07, 1.602459484551717e-07, 1.6026942094375604e-07, 1.602644544333144e-07, 1.6026166159121875e-07, 1.6027913691179115e-07, 1.6030224050318633e-07, 1.6026909593974017e-07, 1.6025498284124754e-07, 2.4246092411865527e-07, 2.945302460396278e-07, 3.3056905914401006e-07, 3.4460740680293215e-07, 3.0180316226736955e-07, 2.243613713111073e-07]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/7/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    1.602397e-07         3084.852099     7.0       640.0
# 1    1.602431e-07         3084.788754     7.0       640.0
