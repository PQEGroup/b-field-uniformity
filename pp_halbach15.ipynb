# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 15 main
# n = 15
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 15
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [2.2437767907440334, 110.67468915813137]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 93
#          Function evaluations: 242
# [16.608968116817195, 231.966514482474]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 50
#          Function evaluations: 109
# [16.200211572443898, 31.749464668806098]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 97
# [11.320140060706823, 153.98517069913927]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 50
#          Function evaluations: 106
# [12.751770031323604, 112.61404360950074]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 95
# [19.247158826150518, 283.5741470119499]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 74
# [14.791608599395952, 179.68221904085416]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 92
# [11.881697101875801, 34.766076256145155]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 89
# [5.743296472747895, 73.66836026970334]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 47
#          Function evaluations: 106
# [14.336836414998182, 87.2004410918708]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 32
#          Function evaluations: 69
# [11.034407949122265, 207.99639653365003]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 46
#          Function evaluations: 100
# [2.171277151158046, 251.73300562344238]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 126
# [5.564956373992417, 96.79155174142443]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 94
# [13.395400685839178, 97.84306047071661]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 47
#          Function evaluations: 98
# [7.718834658970882, 66.4572183594268]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 88
# [12.047297989861542, 47.58347045462632]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 76
# [6.681682837224583, 55.55802990713004]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 107
# [4.736299132606593, 106.13541092800125]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 90
# [16.703757551380313, 102.95933636840847]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 87
# [3.856811828341981, 106.66515709050923]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations:
# [array([ 3.49674805, 40.43320353]), array([20.        , 40.41553455]), array([20.        , 40.41899798]), array([20.        , 40.42219206]), array([19.8032551 , 40.41935491]), array([20.        , 40.42108538]), array([20.        , 40.42632103]), array([20.        , 40.42024728]), array([ 8.20137364, 40.39699208]), array([20.        , 40.42380983]), array([18.47116244, 40.42396472]), array([ 3.67397274, 40.41466483]), array([ 8.78521407, 40.41131358]), array([19.99806273, 40.41832395]), array([10.44992155, 40.4160184 ]), array([20.        , 40.41830182]), array([20.        , 40.42200532]), array([ 7.48328829, 40.41752408]), array([19.96879678, 40.42124764]), array([ 6.07317119, 40.41981518]), array([ 4.61214688, 40.42723931]), array([17.14837305, 40.41940882]), array([18.41072372, 40.42431276]), array([ 1.56464856, 40.39464943]), array([20.        , 40.41720386])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 15).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [611.4170733903699, 20019.283577422088, 20015.852846728947, 20012.689709782797, 19623.6415173828, 20013.78558423215, 20008.601858716644, 20014.61556601015, 3369.460205505755, 20011.08790746972, 17068.518788436842, 675.5835804244298, 3863.527012182281, 20012.64289900152, 5465.1765605048095, 20016.54236153718, 20012.874621393927, 2802.403912468066, 19951.22466870756, 1845.5575286402825, 1064.0040353927743, 14714.690206954792, 16956.711158807953, 122.65100694982215, 20017.62992369273]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [1.844244020573063e-08, 1.8366855086463788e-08, 1.8366850771729217e-08, 1.836683307458354e-08, 1.8368481943770294e-08, 1.83668436848304e-08, 1.8366859338874165e-08, 1.8366843870902512e-08, 1.843514638341023e-08, 1.836687514580273e-08, 1.837895804567872e-08, 1.844418236010881e-08, 1.8433085103325305e-08, 1.8366848249276595e-08, 1.8426534702425382e-08, 1.8366836515011228e-08, 1.8366832054954718e-08, 1.843703756705803e-08, 1.8367109630893922e-08, 1.844095817260132e-08, 1.8443913442286633e-08, 1.8388573327966793e-08, 1.8379419332017384e-08, 1.8427364254953854e-08, 1.836683989541564e-08]
# [1.844244020573063e-08, 1.8366855086463788e-08, 1.8366850771729217e-08, 1.836683307458354e-08, 1.8368481943770294e-08, 1.83668436848304e-08, 1.8366859338874165e-08, 1.8366843870902512e-08, 1.843514638341023e-08, 1.836687514580273e-08, 1.837895804567872e-08, 1.844418236010881e-08, 1.8433085103325305e-08, 1.8366848249276595e-08, 1.8426534702425382e-08, 1.8366836515011228e-08, 1.8366832054954718e-08, 1.843703756705803e-08, 1.8367109630893922e-08, 1.844095817260132e-08, 1.8443913442286633e-08, 1.8388573327966793e-08, 1.8379419332017384e-08, 1.8427364254953854e-08, 1.836683989541564e-08]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/15/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    1.836683e-08        20012.874621    15.0       640.0     20.000000
# 1    1.836683e-08        20012.689710    15.0       640.0     20.000000
# 2    1.836684e-08        20016.542362    15.0       640.0     20.000000
# 3    1.836684e-08        20017.629924    15.0       640.0     20.000000
# 4    1.836684e-08        20013.785584    15.0       640.0     20.000000
# 5    1.836684e-08        20014.615566    15.0       640.0     20.000000
# 6    1.836685e-08        20012.642899    15.0       640.0     19.998063
# 7    1.836685e-08        20015.852847    15.0       640.0     20.000000
# 8    1.836686e-08        20019.283577    15.0       640.0     20.000000
# 9    1.836686e-08        20008.601859    15.0       640.0     20.000000
# 10   1.836688e-08        20011.087907    15.0       640.0     20.000000
# 11   1.836711e-08        19951.224669    15.0       640.0     19.968797
# 12   1.836848e-08        19623.641517    15.0       640.0     19.803255
# 13   1.837896e-08        17068.518788    15.0       640.0     18.471162
# 14   1.837942e-08        16956.711159    15.0       640.0     18.410724
# 15   1.838857e-08        14714.690207    15.0       640.0     17.148373
# 16   1.842653e-08         5465.176561    15.0       640.0     10.449922
# 17   1.842736e-08          122.651007    15.0       640.0      1.564649
# 18   1.843309e-08         3863.527012    15.0       640.0      8.785214
# 19   1.843515e-08         3369.460206    15.0       640.0      8.201374
# 20   1.843704e-08         2802.403912    15.0       640.0      7.483288
# 21   1.844096e-08         1845.557529    15.0       640.0      6.073171
# 22   1.844244e-08          611.417073    15.0       640.0      3.496748
# 23   1.844391e-08         1064.004035    15.0       640.0      4.612147
# 24   1.844418e-08          675.583580    15.0       640.0      3.673973
#
#             D  g_cyl_diameter         g_D
# 0   40.422005        6.681683   55.558030
# 1   40.422192       11.320140  153.985171
# 2   40.418302       12.047298   47.583470
# 3   40.417204       14.819489   82.541424
center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 15).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 7
#       5 results2_g_center = []
#       6 results2_nonun = []
# ----> 7 for x in results2_x:
#       8     magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
#       9     Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
#
# NameError: name 'results2_x' is not defined

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/12/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    2.789894e-07         3726.849477    12.0       640.0
# 1    2.794277e-07         3987.521562    12.0       640.0
# 2    2.794324e-07         3987.455736    12.0       640.0
# 3    2.794476e-07         3987.238815    12.0       640.0
# 4    2.794501e-07         3987.203541    12.0       640.0
# 5    2.794590e-07         3987.075997    12.0       640.0
# 6    2.794610e-07         3987.047551    12.0       640.0
# 7    2.794653e-07         3986.986272    12.0       640.0
# 8    2.794654e-07         3986.984708    12.0       640.0
# 9    2.794700e-07         3986.918662    12.0       640.0
# 10   2.794703e-07         3986.916143    12.0       640.0
# 11   2.794737e-07         3986.866887    12.0       640.0
# 12   2.794739e-07         3986.864304    12.0       640.0
# 13   2.794788e-07         3986.794690    12.0       640.0
# 14   2.794788e-07         3986.794204    12.0       640.0
# 15   2.794789e-07         3986.792114    12.0       640.0
# 16   2.794826e-07         3986.740464    12.0       640.0
# 17   2.794843e-07         3986.716094    12.0       640.0
# 18   2.794885e-07         3986.656958    12.0       640.0
# 19   2.797677e-07           10.000000    12.0       640.0
# 20   2.797828e-07           10.000000    12.0       640.0
# 21   4.721363e-07           10.000000    12.0       640.0
# 22   5.178398e-07           10.000000    12.0       640.0
# 23   5.458575e-07           10.000000    12.0       640.0
# 24   5.543567e-07           10.000000    12.0       640.0
#
#     stage2_cyl_diameter   stage2_D  stage1_cyl_diameter   stage1_D  \
# 0             19.317128  80.917094            19.999727  78.228006
# 1             20.000000  80.992920            20.000000  78.225612
# 2             20.000000  80.993588            20.000000  78.224413
# 3             20.000000  80.995791            20.000000  78.222160
# 4             20.000000  80.996149            20.000000  78.219048
# 5             20.000000  80.997444            20.000000  78.223991
# 6             20.000000  80.997733            20.000000  78.225189
# 7             20.000000  80.998356            20.000000  78.221755
# 8             20.000000  80.998371            20.000000  78.221507
# 9             20.000000  80.999042            20.000000  78.222735
# 10            20.000000  80.999068            20.000000  78.219562
# 11            20.000000  80.999568            20.000000  78.219130
# 12            20.000000  80.999594            20.000000  78.222375
# 13            20.000000  81.000301            20.000000  78.222370
# 14            20.000000  81.000306            20.000000  78.218933
# 15            20.000000  81.000327            20.000000  78.222723
# 16            20.000000  81.000852            20.000000  78.220382
# 17            20.000000  81.001100            20.000000  78.217835
# 18            20.000000  81.001700            20.000000  78.221157
# 19             1.000000  80.866502             1.000000  78.181244
# 20             1.000000  80.866502             5.012212  78.188623
# 21             1.163465  94.081784             1.902169  78.202463
# 22             1.191713  96.365232             3.540443  78.192109
# 23             1.208171  97.695569             1.611116  78.202122
# 24             1.213048  98.089741             3.140403  78.194000
#
#        objective
# 0   1.036962e-03
# 1   1.111430e-03
# 2   1.111430e-03
# 3   1.111430e-03
# 4   1.111430e-03
# 5   1.111430e-03
# 6   1.111430e-03
# 7   1.111430e-03
# 8   1.111429e-03
# 9   1.111430e-03
# 10  1.111430e-03
# 11  1.111430e-03
# 12  1.111430e-03
# 13  1.111430e-03
# 14  1.111430e-03
# 15  1.111430e-03
# 16  1.111430e-03
# 17  1.111430e-03
# 18  1.111430e-03
# 19  7.518619e-18
# 20  5.608578e-18
# 21  5.988193e-19
# 22  1.900448e-18
# 23  2.268952e-19
# 24  2.802754e-17
