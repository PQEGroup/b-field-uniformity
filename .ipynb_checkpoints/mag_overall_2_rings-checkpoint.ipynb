# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import n_rings
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Optimization of 2 rings
# All variables can be optimized independently for each ring set
#
# 1. Run 50 shots using Nelder-Mead with nonuniformity cost function
# 2. Optimize for field strength using new cost function

# %%
Br = 1.09e3
mag_dir = (0,0,1)
mirror_z = True
base_ring_config = [Br, mag_dir, mirror_z]
# innerrad, width, thickness, dist
bounds = ((1, 150), (2, 20), (2, 20), (1, 300))

# %% [markdown]
# ### Definition of 2 ring objective function

# %%
from maggeometry import n_rings
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
def obj1_nonuniformity(x):
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maggeometry import n_rings
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp':True, 'fatol': 1e-12, 'maxiter':5e3}
method = "Nelder-Mead"

shots = 50
results_x = []
results_fun = []
guesses_x0 = []
with alive_bar(shots, force_tty=True) as bar:
    for i in range(shots):
        x0 = np.zeros(len(bounds))
        for b in range(len(bounds)):
            x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
        res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
        guesses_x0.append(x0)
        results_x.append(res.x)
        results_fun.append(res.fun)
        bar()

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# on 0: Optimization terminated successfully.
# on 0:          Current function value: 0.000001
# on 0:          Iterations: 204
# on 0:          Function evaluations: 357
# on 1: Optimization terminated successfully.
# on 1:          Current function value: 0.000001
# on 1:          Iterations: 248
# on 1:          Function evaluations: 451
# on 2: Optimization terminated successfully.
# on 2:          Current function value: 0.002238
# on 2:          Iterations: 23
# on 2:          Function evaluations: 38
# on 3: Optimization terminated successfully.
# on 3:          Current function value: 0.000010
# on 3:          Iterations: 109
# on 3:          Function evaluations: 190
# on 4: Optimization terminated successfully.
# on 4:          Current function value: 0.000437
# on 4:          Iterations: 32
# on 4:          Function evaluations: 49
# on 5: Optimization terminated successfully.
# on 5:          Current function value: 0.000001
# on 5:          Iterations: 184
# on 5:          Function evaluations: 333
# on 6: Optimization terminated successfully.
# on 6:          Current function value: 0.000001
# on 6:          Iterations: 203
# on 6:          Function evaluations: 365
# on 7: Optimization terminated successfully.
# on 7:          Current function value: 0.000001
# on 7:          Iterations: 272
# on 7:          Function evaluations: 479
# on 8: Optimization terminated successfully.
# on 8:          Current function value: 0.000283
# on 8:          Iterations: 45
# on 8:          Function evaluations: 74
# on 9: Optimization terminated successfully.
# on 9:          Current function value: 0.000287
# on 9:          Iterations: 39
# on 9:          Function evaluations: 64
# on 10: Optimization terminated successfully.
# on 10:          Current function value: 0.000001
# on 10:          Iterations: 422
# on 10:          Function evaluations: 726
# on 11: Optimization terminated successfully.
# on 11:          Current function value: 0.000001
# on 11:          Iterations: 182
# on 11:          Function evaluations: 319
# on 12: Optimization terminated successfully.
# on 12:          Current function value: 0.000001
# on 12:          Iterations: 263
# on 12:          Function evaluations: 567
# on 13: Optimization terminated successfully.
# on 13:          Current function value: 0.000434
# on 13:          Iterations: 42
# on 13:          Function evaluations: 69
# on 14: Optimization terminated successfully.
# on 14:          Current function value: 0.000283
# on 14:          Iterations: 35
# on 14:          Function evaluations: 55
# on 15: Optimization terminated successfully.
# on 15:          Current function value: 0.000437
# on 15:          Iterations: 20
# on 15:          Function evaluations: 34
# on 16: Optimization terminated successfully.
# on 16:          Current function value: 0.000001
# on 16:          Iterations: 244
# on 16:          Function evaluations: 431
# on 17: Optimization terminated successfully.
# on 17:          Current function value: 0.000001
# on 17:          Iterations: 444
# on 17:          Function evaluations: 760
# on 18: Optimization terminated successfully.
# on 18:          Current function value: 0.000283
# on 18:          Iterations: 42
# on 18:          Function evaluations: 72
# on 19: Optimization terminated successfully.
# on 19:          Current function value: 0.000001
# on 19:          Iterations: 135
# on 19:          Function evaluations: 252
# on 20: Optimization terminated successfully.
# on 20:          Current function value: 0.000001
# on 20:          Iterations: 178
# on 20:          Function evaluations: 311
# on 21: Optimization terminated successfully.
# on 21:          Current function value: 0.000283
# on 21:          Iterations: 63
# on 21:          Function evaluations: 95
# on 22: Optimization terminated successfully.
# on 22:          Current function value: 0.000283
# on 22:          Iterations: 36
# on 22:          Function evaluations: 60
# on 23: Optimization terminated successfully.
# on 23:          Current function value: 0.000001
# on 23:          Iterations: 156
# on 23:          Function evaluations: 279
# on 24: Optimization terminated successfully.
# on 24:          Current function value: 0.000001
# on 24:          Iterations: 391
# on 24:          Function evaluations: 686
# on 25: Optimization terminated successfully.
# on 25:          Current function value: 0.000009
# on 25:          Iterations: 430
# on 25:          Function evaluations: 737
# on 26: Optimization terminated successfully.
# on 26:          Current function value: 0.000437
# on 26:          Iterations: 27
# on 26:          Function evaluations: 46
# on 27: Optimization terminated successfully.
# on 27:          Current function value: 0.000001
# on 27:          Iterations: 193
# on 27:          Function evaluations: 355
# on 28: Optimization terminated successfully.
# on 28:          Current function value: 0.000001
# on 28:          Iterations: 144
# on 28:          Function evaluations: 265
# on 29: Optimization terminated successfully.
# on 29:          Current function value: 0.000283
# on 29:          Iterations: 41
# on 29:          Function evaluations: 66
# on 30: Optimization terminated successfully.
# on 30:          Current function value: 0.000001
# on 30:          Iterations: 544
# on 30:          Function evaluations: 940
# on 31: Optimization terminated successfully.
# on 31:          Current function value: 0.000001
# on 31:          Iterations: 173
# on 31:          Function evaluations: 319
# on 32: Optimization terminated successfully.
# on 32:          Current function value: 0.000283
# on 32:          Iterations: 35
# on 32:          Function evaluations: 60
# on 33: Optimization terminated successfully.
# on 33:          Current function value: 0.000283
# on 33:          Iterations: 30
# on 33:          Function evaluations: 48
# on 34: Optimization terminated successfully.
# on 34:          Current function value: 0.000287
# on 34:          Iterations: 40
# on 34:          Function evaluations: 64
# on 35: Optimization terminated successfully.
# on 35:          Current function value: 0.000283
# on 35:          Iterations: 48
# on 35:          Function evaluations: 79
# on 36: Optimization terminated successfully.
# on 36:          Current function value: 0.000001
# on 36:          Iterations: 151
# on 36:          Function evaluations: 269
# on 37: Optimization terminated successfully.
# on 37:          Current function value: 0.000001
# on 37:          Iterations: 187
# on 37:          Function evaluations: 336
# on 38: Optimization terminated successfully.
# on 38:          Current function value: 0.000001
# on 38:          Iterations: 481
# on 38:          Function evaluations: 848
# on 39: Optimization terminated successfully.
# on 39:          Current function value: 0.000009
# on 39:          Iterations: 254
# on 39:          Function evaluations: 438
# on 40: Optimization terminated successfully.
# on 40:          Current function value: 0.000010
# on 40:          Iterations: 369
# on 40:          Function evaluations: 620
# on 41: /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_50217/2421128397.py:19: RuntimeWarning: Maximum number of iterations has been exceeded.
#          res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
# on 42: Optimization terminated successfully.
# on 42:          Current function value: 0.000001
# on 42:          Iterations: 265
# on 42:          Function evaluations: 459
# on 43: Optimization terminated successfully.
# on 43:          Current function value: 0.000437
# on 43:          Iterations: 25
# on 43:          Function evaluations: 41
# on 44: Optimization terminated successfully.
# on 44:          Current function value: 0.000437
# on 44:          Iterations: 20
# on 44:          Function evaluations: 34
# on 45: Optimization terminated successfully.
# on 45:          Current function value: 0.000287
# on 45:          Iterations: 31
# on 45:          Function evaluations: 49
# on 46: Optimization terminated successfully.
# on 46:          Current function value: 0.000437
# on 46:          Iterations: 26
# on 46:          Function evaluations: 42
# on 47: Optimization terminated successfully.
# on 47:          Current function value: 0.000001
# on 47:          Iterations: 389
# on 47:          Function evaluations: 690
# on 48: Optimization terminated successfully.
# on 48:          Current function value: 0.000434
# on 48:          Iterations: 44
# on 48:          Function evaluations: 72
# on 49: Optimization terminated successfully.
# on 49:          Current function value: 0.000001
# on 49:          Iterations: 304
# on 49:          Function evaluations: 526
# |████████████████████████████████████████| 50/50 [100%] in 11:14.1 (0.07/s)
# Objective function values:
# [7.9716762071396e-07, 7.973922882569798e-07, 0.0022375150181476494, 9.608909919999743e-06, 0.00043735987226945655, 8.898748629733948e-07, 8.015696102250376e-07, 1.0035376466251916e-06, 0.0002830875189033077, 0.0002867944253671033, 7.971662270150127e-07, 7.971612787196117e-07, 1.0060157076356608e-06, 0.0004340311454236305, 0.0002830875189033077, 0.00043735987226945655, 9.324980043951263e-07, 7.991891637488816e-07, 0.0002830875189033077, 9.016205628842814e-07, 1.0052224839137612e-06, 0.0002830875189033077, 0.0002830875189033077, 8.758332808513643e-07, 7.975055877821672e-07, 9.377161752212814e-06, 0.00043735987226945655, 8.70513593585079e-07, 9.674444241844902e-07, 0.0002830875189033077, 7.960
# 22  255.795240    136.895413  10.630248       4.624903  136.501049
# 23  255.828007     93.311116   9.034640      19.425344   92.355212
# 24  255.594324    111.258417   2.009199       4.152375  182.409605
# 25   57.756797    138.568962  12.903717       8.745516   94.032940
# 26   57.756788    111.201844  15.825338      18.089771    7.734764
# 27   57.436091    147.615934  10.886689       7.087911   80.018538
# 28   57.387081    149.262336  17.122457       9.291920    6.737920
# 29  300.000000      2.603139  17.677193      18.310820  172.397193
# 30  300.000000     78.776196  17.050944      13.963922  266.172978
# 31  300.000000     67.588526   8.457479      12.877218  217.647313
# 32  300.000000     45.215071   3.400223      18.625284  252.845191
# 33  300.000000     17.182578  15.689752      14.312682  141.447121
# 34  300.000000     66.169786  18.541976      13.407729  256.668106
# 35  300.000000     53.820116   4.823084       4.716042  176.440061
# 36  300.000000     69.680018  14.351998       2.897910  236.880116
# 37  300.000000     64.447149   3.717891      14.452296  263.136250
# 38  300.000000     19.444819  19.610977      19.039858  118.842986
# 39  300.000000     54.733910  19.152082       7.395086  220.276299
# 40  300.000000     29.651455  14.947968       4.767112  195.863773
# 41  300.000000     36.063548   6.481522       4.329222  252.728058
# 42  300.000000     37.994347   9.968348      12.807552  256.504168
# 43  300.000000     55.593363   2.536863      13.624235  234.051639
# 44  300.000000     29.028312   8.353747       8.871474  218.512612
# 45  300.000000     31.738758   3.098975      11.149159  129.356496
# 46  300.000000     53.096402   2.473228      10.636694  197.524257
# 47  300.000000     27.540338  13.452487       7.565734  278.820866
# 48  300.000000     21.645207  16.943233      16.873253  261.463496
# 49  300.000000      4.288659  13.191579       2.850698   65.056110

# %% [markdown]
# ### Define 2nd stage multiobjective cost function
# Only use results that are within +20% of minimum homogeneity for stage 2

# %%
import pandas as pd

guess_threshold = 1.2 # only use results that are within +20% of minimum homogeneity for stage 2

st1 = pd.read_csv('results/2 rings/2023_07_12_2rings_1090T_34.csv')
st1 = np.delete(st1.to_numpy(), 0, axis=1) #remove first column of indices
min_nonun = st1[0][0]
nonun_threshold = min_nonun*guess_threshold
print("Nonuniformity threshold:", nonun_threshold)
st2g = st1[st1[:,0] < nonun_threshold]
# Out:
# Nonuniformity threshold: 9.55261883457757e-07

# %%
Br = 1.09e3
mag_dir = (0,0,1)
mirror_z = True
base_ring_config = [Br, mag_dir, mirror_z]
# innerrad, width, thickness, dist
bounds = ((1, 150), (2, 20), (2, 20), (1, 300))

# %%
# 10G target
field_strength_target = 10

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
def obj2_nonuniformity(x):
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*abs(center_field - field_strength_target)
    return cost

# %% [markdown]
# ### Optimize 2 rings 2nd stage

# %%
results2_x = []
results2_fun = []
options2 = {'disp':True, 'fatol': 1e-17, 'maxiter':5e3}
with alive_bar(len(st2g), force_tty=True) as bar:
    for s0 in st2g:
        res2 = minimize(obj2_nonuniformity, s0[2:6], method=method, options=options2, bounds=bounds)
        results2_x.append(res2.x)
        results2_fun.append(res2.fun)
        bar()
        
print(results2_x)
print(results2_fun)
# Out:
# on 0: Optimization terminated successfully.
# on 0:          Current function value: 0.000000
# on 0:          Iterations: 256
# on 0:          Function evaluations: 455
# on 1: Optimization terminated successfully.
# on 1:          Current function value: 0.000000
# on 1:          Iterations: 169
# on 1:          Function evaluations: 305
# on 2: Optimization terminated successfully.
# on 2:          Current function value: 0.000000
# on 2:          Iterations: 173
# on 2:          Function evaluations: 311
# on 3: Optimization terminated successfully.
# on 3:          Current function value: 0.000000
# on 3:          Iterations: 171
# on 3:          Function evaluations: 310
# on 4: Optimization terminated successfully.
# on 4:          Current function value: 0.000000
# on 4:          Iterations: 171
# on 4:          Function evaluations: 305
# on 5: Optimization terminated successfully.
# on 5:          Current function value: 0.000000
# on 5:          Iterations: 168
# on 5:          Function evaluations: 306
# on 6: Optimization terminated successfully.
# on 6:          Current function value: 0.000000
# on 6:          Iterations: 170
# on 6:          Function evaluations: 314
# on 7: Optimization terminated successfully.
# on 7:          Current function value: 0.000000
# on 7:          Iterations: 173
# on 7:          Function evaluations: 316
# on 8: Optimization terminated successfully.
# on 8:          Current function value: 0.000000
# on 8:          Iterations: 181
# on 8:          Function evaluations: 321
# on 9: Optimization terminated successfully.
# on 9:          Current function value: 0.000000
# on 9:          Iterations: 164
# on 9:          Function evaluations: 301
# on 10: Optimization terminated successfully.
# on 10:          Current function value: 0.000000
# on 10:          Iterations: 146
# on 10:          Function evaluations: 275
# on 11: Optimization terminated successfully.
# on 11:          Current function value: 0.000000
# on 11:          Iterations: 173
# on 11:          Function evaluations: 322
# on 12: Optimization terminated successfully.
# on 12:          Current function value: 0.000000
# on 12:          Iterations: 184
# on 12:          Function evaluations: 333
# on 13: Optimization terminated successfully.
# on 13:          Current function value: 0.000000
# on 13:          Iterations: 142
# on 13:          Function evaluations: 264
# on 14: Optimization terminated successfully.
# on 14:          Current function value: 0.000000
# on 14:          Iterations: 179
# on 14:          Function evaluations: 327
# on 15: Optimization terminated successfully.
# on 15:          Current function value: 0.000000
# on 15:          Iterations: 172
# on 15:          Function evaluations: 314
# on 16: Optimization terminated successfully.
# on 16:          Current function value: 0.000000
# on 16:          Iterations: 180
# on 16:          Function evaluations: 326
# |████████████████████████████████████████| 17/17 [100%] in 1:28.7 (0.19/s)
# [array([149.89845876,  20.        ,   7.27719011, 270.27697555]), array([149.99929265,  20.        ,   7.28953201, 270.53928901]), array([150.        ,  19.99998076,   7.2903658 , 270.56257098]), array([150.        ,  20.        ,   7.29097982, 270.58054077]), array([150.        ,  19.9968407 ,   7.29215266, 270.58271266]), array([149.9999825 ,  19.90095314,   7.32298874, 270.5063931 ]), array([149.8917326 ,  20.        ,   7.28084732, 270.38934565]), array([149.99993734,  19.99894516,   7.29349584, 270.64280345]), array([150.        ,  19.99921183,   7.29407004, 270.66203552]), array([149.82290313,  20.        ,   7.27497546, 270.28420127]), array([150.        ,  16.17416092,   8.80330421, 267.46976514]), array([149.99988256,  14.15842035,   9.92808589, 265.78410537]), array([150.        ,  13.46354245,  10.3930511 , 265.18110197]), array([145.92507562,  20.        ,   6.92385019, 263.66286465]), array([149.9995033 ,  12.36351223,  11.2395768 , 264.28766229]), array([150.        ,  10.60910536,  12.95488935, 262.87939757]), array([149.99509049,   9.02219485,  15.08170708, 261.60576636])]
# [9.118829600624584e-18, 4.812468595291014e-18, 4.8927617733736856e-18, 2.0698281218031594e-17, 1.1375380054230424e-17, 8.296336310212137e-18, 7.234294760891213e-18, 8.813384080036468e-18, 1.2760880885622872e-17, 4.029938022203914e-18, 1.694914118584715e-17, 6.962796412645926e-18, 1.0739748404848009e-17, 4.445454774193365e-18, 1.0034538231618464e-17, 5.0791444684281665e-18, 9.534974472148671e-18]

# %%
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_nonun = []
results2_g_center = []
for x in results2_x:
    obj_ring_config=[[*base_ring_config, *x]]
    magnets = n_rings(obj_ring_config)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    results2_nonun.append(obj1_nonuniformity(x))
    results2_g_center.append(center_field)

print(results2_nonun)
print(results2_g_center)
# Out:
# [1.817148565992386e-06, 9.590014058621605e-07, 8.488073998219699e-07, 8.022097382163237e-07, 7.979775291811513e-07, 7.983627588720448e-07, 8.177803009397089e-07, 9.952846855247067e-07, 1.1411814615053703e-06, 8.016443186892112e-07, 8.630952728271275e-07, 1.2060633588249544e-06, 1.6384663588796196e-06, 8.858649763075057e-07, 1.743500873485799e-06, 1.8935789019349344e-06, 2.245905202916106e-06]
# [10.000000000005018, 10.000000000005018, 9.999999999994236, 9.999999999974198, 10.000000000014255, 9.999999999989608, 9.999999999991154, 9.999999999991145, 10.000000000011182, 10.000000000005027, 9.999999999980362, 9.999999999994227, 10.000000000006555, 10.000000000005018, 9.999999999994245, 9.999999999997318, 9.999999999995755]

# %%
def make_opt_res2_csv(name, nonun, g_center, x, fun):
    r_f = np.array([fun])
    r_n = np.array([nonun])
    r_gc = np.array([g_center])
    r_x = np.array(x)

    a = np.concatenate((r_n.T, r_gc.T, r_x, r_f.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss']
    n = int(b.shape[1]) - len(columns)
    # need 4 specs to define a ring: innerrad, width, thickness, dist
    n_ring_sets = int(n/ 4)
    
    for i in range(1, n_ring_sets+1):
        columns.append('r_' + str(i) + '_innerrad')
        columns.append('r_' + str(i) + '_width')
        columns.append('r_' + str(i) + '_thickness')
        columns.append('r_' + str(i) + '_dist')
    
    columns.append('objective')
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_n.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

# %%
from maghelper import make_opt_res2_csv 
make_opt_res2_csv('results/2 rings/2023_07_12_stage2opt_2rings_1090T_', results2_nonun, results2_g_center, results2_x, results2_fun)
# Out:
# Number of unique results: 17
#     nonuniformity  center_field_gauss  r_1_innerrad  r_1_width  r_1_thickness  \
# 0    7.979775e-07                10.0    150.000000  19.996841       7.292153
# 1    7.983628e-07                10.0    149.999982  19.900953       7.322989
# 2    8.016443e-07                10.0    149.822903  20.000000       7.274975
# 3    8.022097e-07                10.0    150.000000  20.000000       7.290980
# 4    8.177803e-07                10.0    149.891733  20.000000       7.280847
# 5    8.488074e-07                10.0    150.000000  19.999981       7.290366
# 6    8.630953e-07                10.0    150.000000  16.174161       8.803304
# 7    8.858650e-07                10.0    145.925076  20.000000       6.923850
# 8    9.590014e-07                10.0    149.999293  20.000000       7.289532
# 9    9.952847e-07                10.0    149.999937  19.998945       7.293496
# 10   1.141181e-06                10.0    150.000000  19.999212       7.294070
# 11   1.206063e-06                10.0    149.999883  14.158420       9.928086
# 12   1.638466e-06                10.0    150.000000  13.463542      10.393051
# 13   1.743501e-06                10.0    149.999503  12.363512      11.239577
# 14   1.817149e-06                10.0    149.898459  20.000000       7.277190
# 15   1.893579e-06                10.0    150.000000  10.609105      12.954889
# 16   2.245905e-06                10.0    149.995090   9.022195      15.081707
#
#       r_1_dist     objective
# 0   270.582713  1.137538e-17
# 1   270.506393  8.296336e-18
# 2   270.284201  4.029938e-18
# 3   270.580541  2.069828e-17
# 4   270.389346  7.234295e-18
# 5   270.562571  4.892762e-18
# 6   267.469765  1.694914e-17
# 7   263.662865  4.445455e-18
# 8   270.539289  4.812469e-18
# 9   270.642803  8.813384e-18
# 10  270.662036  1.276088e-17
# 11  265.784105  6.962796e-18
# 12  265.181102  1.073975e-17
# 13  264.287662  1.003454e-17
# 14  270.276976  9.118830e-18
# 15  262.879398  5.079144e-18
# 16  261.605766  9.534974e-18
# (array([[7.97977529e-07, 1.00000000e+01, 1.50000000e+02, 1.99968407e+01,
#          7.29215266e+00, 2.70582713e+02, 1.13753801e-17],
#         [7.98362759e-07, 1.00000000e+01, 1.49999982e+02, 1.99009531e+01,
#          7.32298874e+00, 2.70506393e+02, 8.29633631e-18],
#         [8.01644319e-07, 1.00000000e+01, 1.49822903e+02, 2.00000000e+01,
#          7.27497546e+00, 2.70284201e+02, 4.02993802e-18],
#         [8.02209738e-07, 1.00000000e+01, 1.50000000e+02, 2.00000000e+01,
#          7.29097982e+00, 2.70580541e+02, 2.06982812e-17],
#         [8.17780301e-07, 1.00000000e+01, 1.49891733e+02, 2.00000000e+01,
#          7.28084732e+00, 2.70389346e+02, 7.23429476e-18],
#         [8.48807400e-07, 1.00000000e+01, 1.50000000e+02, 1.99999808e+01,
#          7.29036580e+00, 2.70562571e+02, 4.89276177e-18],
#         [8.63095273e-07, 1.00000000e+01, 1.50000000e+02, 1.61741609e+01,
#          8.80330421e+00, 2.67469765e+02, 1.69491412e-17],
#         [8.85864976e-07, 1.00000000e+01, 1.45925076e+02, 2.00000000e+01,
#          6.92385019e+00, 2.63662865e+02, 4.44545477e-18],
