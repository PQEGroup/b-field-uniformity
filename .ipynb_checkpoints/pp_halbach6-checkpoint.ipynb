# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 6 main cylinder
# n = 6
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 6
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [14.346819217234872, 167.38521527846248]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 38
#          Function evaluations: 83
# [11.99842116005105, 114.08094869354096]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 48
#          Function evaluations: 101
# [12.164740079262229, 238.27502797472684]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 45
#          Function evaluations: 96
# [16.28454924181562, 83.52827926593845]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 44
#          Function evaluations: 91
# [6.2270774383111345, 223.59704930157397]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 55
#          Function evaluations: 114
# [19.093264822384462, 168.0880068517141]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 26
#          Function evaluations: 62
# [2.7668764466313442, 234.05556879816902]
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_67629/1290770021.py:19: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
# [7.44057807828602, 278.2031702776735]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 56
#          Function evaluations: 113
# [17.866918602643064, 156.70808583074427]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 29
#          Function evaluations: 66
# [9.255639118635383, 155.66521463198234]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 47
#          Function evaluations: 97
# [15.452179496936216, 107.86615875155132]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 42
#          Function evaluations: 85
# [6.586346547200327, 124.10547752133083]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 51
#          Function evaluations: 103
# [11.725654723498105, 190.1763190074291]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 42
#          Function evaluations: 96
# [1.5995433253851021, 56.82523695872199]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 93
#          Function evaluations: 238
# [12.198620108234019, 62.01237399115239]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 50
#          Function evaluations: 105
# [2.8408826433529186, 228.17615036688102]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 54
#          Function evaluations: 109
# [3.5480145710246926, 135.68228507961805]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 56
#          Function evaluations: 109
# [9.39806480942924, 253.07257773580355]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 47
#          Function evaluations: 99
# [16.88806866511844, 28.39130218263436]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 86
#          Function evaluations: 217
# [2.698998841832511, 66.89414687376103]
# [7.643332049957983, 50.008422375170284]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 61
#          Function evaluations: 122
# [13.04802047434435, 281.63442281934095]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 47
#          Function evaluations: 94
# [2.0507817316028905, 202.37528548511392]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 96
#          Function evaluations: 253
# [10.680801793193611, 98.98554006943576]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 51
#          Function evaluations: 103
# [10.015628185329053, 286.94508276618956]
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 48
#          Function evaluations: 98
# Objective function values:
# [6.4797590410008845e-06, 6.479758979311401e-06, 6.4797589558962825e-06, 6.479758968193691e-06, 6.4797590014853186e-06, 6.47975904963658e-06, 6.4967286393729454e-06, 6.4797589941891665e-06, 6.479758953027248e-06, 6.479758964247477e-06, 6.479758979113104e-06, 6.47975902202439e-06, 6.4797590315264135e-06, 6.497184047030508e-06, 6.4797589718444916e-06, 6.479759054393818e-06, 6.47975899787241e-06, 6.4797589945143645e-06, 6.497113371097814e-06, 6.49713160733234e-06, 6.479759027837242e-06, 6.4797589522545075e-06, 6.497020658632107e-06, 6.479758931612773e-06, 6.479759020650575e-06]
# Result parameters:
# [array([ 20.        , 173.89797577]), array([ 20.        , 173.90321021]), array([ 20.        , 173.90262992]), array([ 20.        , 173.89916821]), array([ 20.        , 173.89902727]), array([ 20.        , 173.89886178]), array([  3.52095117, 173.81663001]), array([ 20.        , 173.89838839]), array([ 20.        , 173.90159505]), array([ 20.        , 173.90479509]), array([ 20.        , 173.89741499]), array([ 20.       , 173.9029593]), array([ 20.        , 173.90582614]), array([  1.        , 173.67142864]), array([ 20.       , 173.8989027]), array([ 20.     , 173.89666]), array([ 20.        , 173.90208591]), array([ 20.       , 173.9025096]), array([  1.        , 173.82998723]), array([  1.        , 173.75811772]), array([ 20.        , 173.90659783]), array([ 20.       , 173.9005897]), array([  2.34125829, 173.82648703]), array([ 20.        , 173.90156864]), array([ 20.        , 173.89926418])]
# Starting guesses:
# [[14.346819217234872, 167.38521527846248], [11.99842116005105, 114.08094869354096], [12.164740079262229, 238.27502797472684], [16.28454924181562, 83.52827926593845], [6.2270774383111345, 223.59704930157397], [19.093264822384462, 168.0880068517141], [2.7668764466313442, 234.05556879816902], [7.44057807828602, 278.2031702776735], [17.866918602643064, 156.70808583074427], [9.255639118635383, 155.66521463198234], [15.452179496936216, 107.86615875155132], [6.586346547200327, 124.10547752133083], [11.725654723498105, 190.1763190074291], [1.5995433253851021, 56.82523695872199], [12.198620108234019, 62.01237399115239], [2.8408826433529186, 228.17615036688102], [3.5480145710246926, 135.68228507961805], [9.39806480942924, 253.07257773580355], [16.88806866511844, 28.39130218263436], [2.698998841832511, 66.89414687376103], [7.643332049957983, 50.008422375170284], [13.04802047434435, 281.63442281934095], [2.0507817316028905, 202.37528548511392], [10.680801793193611, 98.98554006943576], [10.015628185329053, 286.94508276618956]]

# %%
print(results_x)
# Out:
# [array([ 20.        , 173.89797577]), array([ 20.        , 173.90321021]), array([ 20.        , 173.90262992]), array([ 20.        , 173.89916821]), array([ 20.        , 173.89902727]), array([ 20.        , 173.89886178]), array([  3.52095117, 173.81663001]), array([ 20.        , 173.89838839]), array([ 20.        , 173.90159505]), array([ 20.        , 173.90479509]), array([ 20.        , 173.89741499]), array([ 20.       , 173.9029593]), array([ 20.        , 173.90582614]), array([  1.        , 173.67142864]), array([ 20.       , 173.8989027]), array([ 20.     , 173.89666]), array([ 20.        , 173.90208591]), array([ 20.       , 173.9025096]), array([  1.        , 173.82998723]), array([  1.        , 173.75811772]), array([ 20.        , 173.90659783]), array([ 20.       , 173.9005897]), array([  2.34125829, 173.82648703]), array([ 20.        , 173.90156864]), array([ 20.        , 173.89926418])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 6).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
print(results_g_center)
# Out:
# [431.74911982397197, 431.7230402122072, 431.72593130423354, 431.7431785084858, 431.7438807207991, 431.74470528793023, 13.393609422010082, 431.74706394633773, 431.7310871839102, 431.7151443455662, 431.75191390969593, 431.7242902811124, 431.71000772276784, 1.082196077087104, 431.74450139413744, 431.75567576741116, 431.72864162526133, 431.7265307368915, 1.0802159962371003, 1.08111283289712, 431.7061633265545, 431.7360961224248, 5.921433125435814, 431.7312187741905, 431.742700354307]

# %%
print(results_fun)
# Out:
# [6.4797590410008845e-06, 6.479758979311401e-06, 6.4797589558962825e-06, 6.479758968193691e-06, 6.4797590014853186e-06, 6.47975904963658e-06, 6.4967286393729454e-06, 6.4797589941891665e-06, 6.479758953027248e-06, 6.479758964247477e-06, 6.479758979113104e-06, 6.47975902202439e-06, 6.4797590315264135e-06, 6.497184047030508e-06, 6.4797589718444916e-06, 6.479759054393818e-06, 6.47975899787241e-06, 6.4797589945143645e-06, 6.497113371097814e-06, 6.49713160733234e-06, 6.479759027837242e-06, 6.4797589522545075e-06, 6.497020658632107e-06, 6.479758931612773e-06, 6.479759020650575e-06]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0        0.000006          431.731219     6.0       640.0     20.000000
# 1        0.000006          431.736096     6.0       640.0     20.000000
# 2        0.000006          431.731087     6.0       640.0     20.000000
# 3        0.000006          431.725931     6.0       640.0     20.000000
# 4        0.000006          431.715144     6.0       640.0     20.000000
# 5        0.000006          431.743179     6.0       640.0     20.000000
# 6        0.000006          431.744501     6.0       640.0     20.000000
# 7        0.000006          431.751914     6.0       640.0     20.000000
# 8        0.000006          431.723040     6.0       640.0     20.000000
# 9        0.000006          431.747064     6.0       640.0     20.000000
# 10       0.000006          431.726531     6.0       640.0     20.000000
# 11       0.000006          431.728642     6.0       640.0     20.000000
# 12       0.000006          431.743881     6.0       640.0     20.000000
# 13       0.000006          431.742700     6.0       640.0     20.000000
# 14       0.000006          431.724290     6.0       640.0     20.000000
# 15       0.000006          431.706163     6.0       640.0     20.000000
# 16       0.000006          431.710008     6.0       640.0     20.000000
# 17       0.000006          431.749120     6.0       640.0     20.000000
# 18       0.000006          431.744705     6.0       640.0     20.000000
# 19       0.000006          431.755676     6.0       640.0     20.000000
# 20       0.000006           13.393609     6.0       640.0      3.520951
# 21       0.000006            5.921433     6.0       640.0      2.341258
# 22       0.000006            1.080216     6.0       640.0      1.000000
# 23       0.000006            1.081113     6.0       640.0      1.000000
# 24       0.000006            1.082196     6.0       640.0      1.000000
#
#              D  g_cyl_diameter         g_D
# 0   173.901569       10.680802   98.985540
# 1   173.900590       13.048020  281.634423
# 2   173.901595       17.866919  156.708086
# 3   173.902630       12.164740  238.275028
# 4   173.904795        9.255639  155.665215
# 5   173.899168       16.284549   83.528279
# 6   173.898903       12.198620   62.012374
# 7   173.897415       15.452179  107.866159
# 8   173.903210       11.998421  114.080949
# 9   173.898388        7.440578  278.203170
# 10  173.902510        9.398065  253.072578
# 11  173.902086        3.548015  135.682285
# 12  173.899027        6.227077  223.597049
# 13  173.899264       10.015628  286.945083
# 14  173.902959        6.586347  124.105478
# 15  173.906598        7.643332   50.008422
# 16  173.905826       11.725655  190.176319
# 17  173.897976       14.346819  167.385215
# 18  173.898862       19.093265  168.088007
# 19  173.896660        2.840883  228.176150
# 20  173.816630        2.766876  234.055569
# 21  173.826487        2.050782  202.375285
# 22  173.829987       16.888069   28.391302
# 23  173.758118        2.698999   66.894147
# 24  173.671429        1.599543   56.825237

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/2023_08_08_pippin1_halbach6main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[  6.         640.          20.         173.90156864  10.68080179
#    98.98554007]
#  [  6.         640.          20.         173.9005897   13.04802047
#   281.63442282]
#  [  6.         640.          20.         173.90159505  17.8669186
#   156.70808583]
#  [  6.         640.          20.         173.90262992  12.16474008
#   238.27502797]
#  [  6.         640.          20.         173.90479509   9.25563912
#   155.66521463]
#  [  6.         640.          20.         173.89916821  16.28454924
#    83.52827927]
#  [  6.         640.          20.         173.8989027   12.19862011
#    62.01237399]
#  [  6.         640.          20.         173.89741499  15.4521795
#   107.86615875]
#  [  6.         640.          20.         173.90321021  11.99842116
#   114.08094869]
#  [  6.         640.          20.         173.89838839   7.44057808
#   278.20317028]
#  [  6.         640.          20.         173.9025096    9.39806481
#   253.07257774]
#  [  6.         640.          20.         173.90208591   3.54801457
#   135.68228508]
#  [  6.         640.          20.         173.89902727   6.22707744
#   223.5970493 ]
#  [  6.         640.          20.         173.89926418  10.01562819
#   286.94508277]
#  [  6.         640.          20.         173.9029593    6.58634655
#   124.10547752]
#  [  6.         640.          20.         173.90659783   7.64333205
#    50.00842238]
#  [  6.         640.          20.         173.90582614  11.72565472
#   190.17631901]
#  [  6.         640.          20.         173.89797577  14.34681922
#   167.38521528]
#  [  6.         640.          20.         173.89886178  19.09326482
#   168.08800685]
#  [  6.         640.          20.         173.89666      2.84088264
#   228.17615037]
#  [  6.         640.           3.52095117 173.81663001   2.76687645
#   234.0555688 ]
#  [  6.         640.           2.34125829 173.82648703   2.05078173
#   202.37528549]
#  [  6.         640.           1.         173.82998723  16.88806867
#    28.39130218]
#  [  6.         640.           1.         173.75811772   2.69899884
#    66.89414687]
#  [  6.         640.           1.         173.67142864   1.59954333
#    56.82523696]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 6
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 63
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 93
#          Function evaluations: 216
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 67
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 89
#          Function evaluations: 214
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 66
#          Function evaluations: 165
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_67629/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 68
#          Function evaluations: 173
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 60
#          Function evaluations: 153
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 91
#          Function evaluations: 209
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 95
#          Function evaluations: 220
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 80
#          Function evaluations: 200
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 96
#          Function evaluations: 224
# Optimization terminated successfully.
#          Current function value: 0.002463
#          Iterations: 70
#          Function evaluations: 177
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 140
#          Function evaluations: 291
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 118
#          Function evaluations: 273
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 117
#          Function evaluations: 270
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 123
#          Function evaluations: 276
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 128
#          Function evaluations: 289
# [array([ 20.        , 193.65124203]), array([ 20.        , 193.64859947]), array([ 20.        , 193.65233298]), array([ 20.        , 193.64853155]), array([ 20.        , 193.65058921]), array([ 20.        , 193.64753868]), array([ 20.        , 193.65040453]), array([ 20.        , 193.64768219]), array([ 20.        , 193.64855897]), array([ 20.        , 193.64744976]), array([ 20.        , 193.64821126]), array([ 20.       , 193.6463783]), array([ 20.        , 193.64735064]), array([ 20.        , 193.65186833]), array([ 20.        , 193.64954033]), array([ 20.        , 193.64734869]), array([ 20.        , 193.64906841]), array([ 20.        , 193.65050575]), array([ 20.        , 193.64916107]), array([ 20.        , 193.64738425]), array([  3.23772819, 184.93416058]), array([  2.62938487, 150.28013494]), array([  2.64899581, 151.39870845]), array([  2.65653039, 151.82844656]), array([  2.65354994, 151.65845656])]
# [0.002463205141632393, 0.0024632050989850836, 0.0024632051258968828, 0.002463205095332566, 0.0024632051292408285, 0.0024632050831405144, 0.00246320514965767, 0.0024632051064111247, 0.0024632051042754507, 0.002463205079747048, 0.0024632050979126793, 0.002463205143909324, 0.002463205101210446, 0.0024632051204803284, 0.0024632050942453745, 0.0024632050994744317, 0.0024632050850021906, 0.0024632051314937256, 0.002463205110764308, 0.00246320510159229, 6.732516474486012e-19, 7.311977195317587e-18, 1.729752581855101e-17, 3.270404492207043e-18, 1.198482368511501e-18]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 6).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [347.84730937028286, 347.85685094903636, 347.84337033066697, 347.8570962095482, 347.849666502276, 347.8606813107586, 347.8503333122094, 347.86016312330935, 347.8569972122414, 347.8610023827259, 347.85825272184286, 347.86487135500784, 347.8613602950767, 347.84504799689216, 347.85345371974574, 347.861367358575, 347.8551577041938, 347.84996784453745, 347.8548231229014, 347.8612389515008, 9.9999999999999, 10.000000000000885, 9.999999999997858, 10.000000000000409, 10.00000000000015]
# [7.290882813965832e-06, 7.2906767823886545e-06, 7.2909677744630606e-06, 7.290671479058764e-06, 7.29083190977261e-06, 7.290594080330111e-06, 7.290817580403002e-06, 7.290605331034914e-06, 7.2906736418072985e-06, 7.290587141977254e-06, 7.290646530219952e-06, 7.29050384560737e-06, 7.290579482244333e-06, 7.290931553044364e-06, 7.290750078549259e-06, 7.290579324685595e-06, 7.29071328003472e-06, 7.29082541344854e-06, 7.2907205763591195e-06, 7.290582101801496e-06, 6.767981849500208e-06, 8.265616910686207e-06, 8.07432948081031e-06, 8.004669811116541e-06, 8.031971351545395e-06]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/6/{today}_pippin2_halbach{n}main_1090mT_25.csv', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0        0.000007           10.000000     6.0       640.0
# 1        0.000007          347.864871     6.0       640.0
# 2        0.000007          347.861367     6.0       640.0
# 3        0.000007          347.861360     6.0       640.0
# 4        0.000007          347.861239     6.0       640.0
# 5        0.000007          347.861002     6.0       640.0
# 6        0.000007          347.860681     6.0       640.0
# 7        0.000007          347.860163     6.0       640.0
# 8        0.000007          347.858253     6.0       640.0
# 9        0.000007          347.857096     6.0       640.0
# 10       0.000007          347.856997     6.0       640.0
# 11       0.000007          347.856851     6.0       640.0
# 12       0.000007          347.855158     6.0       640.0
# 13       0.000007          347.854823     6.0       640.0
# 14       0.000007          347.853454     6.0       640.0
# 15       0.000007          347.850333     6.0       640.0
# 16       0.000007          347.849968     6.0       640.0
# 17       0.000007          347.849667     6.0       640.0
# 18       0.000007          347.847309     6.0       640.0
# 19       0.000007          347.845048     6.0       640.0
# 20       0.000007          347.843370     6.0       640.0
# 21       0.000008           10.000000     6.0       640.0
# 22       0.000008           10.000000     6.0       640.0
# 23       0.000008           10.000000     6.0       640.0
# 24       0.000008           10.000000     6.0       640.0
#
#     stage2_cyl_diameter    stage2_D  stage1_cyl_diameter    stage1_D  \
# 0              3.237728  184.934161             3.520951  173.816630
# 1             20.000000  193.646378            20.000000  173.902086
# 2             20.000000  193.647349            20.000000  173.906598
# 3             20.000000  193.647351            20.000000  173.899027
# 4             20.000000  193.647384            20.000000  173.896660
# 5             20.000000  193.647450            20.000000  173.898388
# 6             20.000000  193.647539            20.000000  173.899168
# 7             20.000000  193.647682            20.000000  173.897415
# 8             20.000000  193.648211            20.000000  173.902510
# 9             20.000000  193.648532            20.000000  173.902630
# 10            20.000000  193.648559            20.000000  173.903210
# 11            20.000000  193.648599            20.000000  173.900590
# 12            20.000000  193.649068            20.000000  173.905826
# 13            20.000000  193.649161            20.000000  173.898862
# 14            20.000000  193.649540            20.000000  173.902959
# 15            20.000000  193.650405            20.000000  173.898903
# 16            20.000000  193.650506            20.000000  173.897976
# 17            20.000000  193.650589            20.000000  173.904795
# 18            20.000000  193.651242            20.000000  173.901569
# 19            20.000000  193.651868            20.000000  173.899264
# 20            20.000000  193.652333            20.000000  173.901595
# 21             2.656530  151.828447             1.000000  173.758118
# 22             2.653550  151.658457             1.000000  173.671429
# 23             2.648996  151.398708             1.000000  173.829987
# 24             2.629385  150.280135             2.341258  173.826487
#
#        objective
# 0   6.732516e-19
# 1   2.463205e-03
# 2   2.463205e-03
# 3   2.463205e-03
# 4   2.463205e-03
# 5   2.463205e-03
# 6   2.463205e-03
# 7   2.463205e-03
# 8   2.463205e-03
# 9   2.463205e-03
# 10  2.463205e-03
# 11  2.463205e-03
# 12  2.463205e-03
# 13  2.463205e-03
# 14  2.463205e-03
# 15  2.463205e-03
# 16  2.463205e-03
# 17  2.463205e-03
# 18  2.463205e-03
# 19  2.463205e-03
# 20  2.463205e-03
# 21  3.270404e-18
# 22  1.198482e-18
# 23  1.729753e-17
# 24  7.311977e-18
