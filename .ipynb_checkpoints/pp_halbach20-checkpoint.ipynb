# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 16 main
# n = 16
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 16
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [11.532085581006715, 198.6122917209087]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 54
#          Function evaluations: 113
# [17.316910262354845, 74.95824073332457]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 31
#          Function evaluations: 67
# [4.9475629943709185, 208.7719686859447]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 50
#          Function evaluations: 107
# [13.37161125557516, 251.91166294941874]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 62
#          Function evaluations: 125
# [16.651694283638495, 244.01602472688862]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 85
# [4.01561949220826, 67.29096404430851]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 52
#          Function evaluations: 122
# [19.147545081928794, 174.14058834169268]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 39
#          Function evaluations: 86
# [12.761575077339588, 40.28332368518204]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 47
#          Function evaluations: 97
# [12.743816655025928, 169.0104023236082]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 37
#          Function evaluations: 81
# [4.028246389249244, 38.07186335499124]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 103
#          Function evaluations: 244
# [15.715167421680079, 211.9466106965134]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 84
# [10.004497761548828, 272.49695616603947]

# %%
print(results_x)

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 12).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [4274.8651972712305, 105.47904610982968, 4275.003796841355, 4275.418138312737, 4274.734260495499, 4275.396647370372, 4275.065336598325, 134.07000809795446, 38.690074624490556, 27.756144620022354, 4275.136739819992, 4275.0025006904425, 4275.405574505725, 10.698852673889036, 4274.309447472675, 268.72875917760985, 4275.042386894845, 4274.687976462936, 4275.259697970092, 4275.349340209069, 4275.109598710287, 4274.819032670251, 4275.538189264109, 4275.175049642105, 4275.041825543492]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [2.6923637615112664e-07, 2.7021416389804995e-07, 2.692363767532988e-07, 2.6923638203177946e-07, 2.6923638038691146e-07, 2.6923634034238454e-07, 2.6923636968525305e-07, 2.702085110060605e-07, 2.702211602456835e-07, 2.702196687790872e-07, 2.692363750767769e-07, 2.69236369637409e-07, 2.692363778725141e-07, 2.7019888534261324e-07, 2.692364402654825e-07, 2.701779154685889e-07, 2.692363693350391e-07, 2.69236399953413e-07, 2.6923636461007854e-07, 2.692363826990671e-07, 2.6923640068662826e-07, 2.692363745699121e-07, 2.6923639922154714e-07, 2.6923639348984983e-07, 2.6923640690091995e-07]
# [2.6923637615112664e-07, 2.7021416389804995e-07, 2.692363767532988e-07, 2.6923638203177946e-07, 2.6923638038691146e-07, 2.6923634034238454e-07, 2.6923636968525305e-07, 2.702085110060605e-07, 2.702211602456835e-07, 2.702196687790872e-07, 2.692363750767769e-07, 2.69236369637409e-07, 2.692363778725141e-07, 2.7019888534261324e-07, 2.692364402654825e-07, 2.701779154685889e-07, 2.692363693350391e-07, 2.69236399953413e-07, 2.6923636461007854e-07, 2.692363826990671e-07, 2.6923640068662826e-07, 2.692363745699121e-07, 2.6923639922154714e-07, 2.6923639348984983e-07, 2.6923640690091995e-07]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/12/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    2.692363e-07         4275.396647    12.0       640.0     20.000000
# 1    2.692364e-07         4275.259698    12.0       640.0     20.000000
# 2    2.692364e-07         4275.042387    12.0       640.0     20.000000
# 3    2.692364e-07         4275.002501    12.0       640.0     20.000000
# 4    2.692364e-07         4275.065337    12.0       640.0     20.000000
# 5    2.692364e-07         4274.819033    12.0       640.0     20.000000
# 6    2.692364e-07         4275.136740    12.0       640.0     20.000000
# 7    2.692364e-07         4274.865197    12.0       640.0     20.000000
# 8    2.692364e-07         4275.003797    12.0       640.0     20.000000
# 9    2.692364e-07         4275.405575    12.0       640.0     20.000000
# 10   2.692364e-07         4274.734260    12.0       640.0     20.000000
# 11   2.692364e-07         4275.418138    12.0       640.0     20.000000
# 12   2.692364e-07         4275.349340    12.0       640.0     20.000000
# 13   2.692364e-07         4275.175050    12.0       640.0     20.000000
# 14   2.692364e-07         4275.538189    12.0       640.0     20.000000
# 15   2.692364e-07         4274.687976    12.0       640.0     20.000000
# 16   2.692364e-07         4275.109599    12.0       640.0     20.000000
# 17   2.692364e-07         4275.041826    12.0       640.0     20.000000
# 18   2.692364e-07         4274.309447    12.0       640.0     19.999727
# 19   2.701779e-07          268.728759    12.0       640.0      5.012212
# 20   2.701989e-07           10.698853    12.0       640.0      1.000000
# 21   2.702085e-07          134.070008    12.0       640.0      3.540443
# 22   2.702142e-07          105.479046    12.0       640.0      3.140403
# 23   2.702197e-07           27.756145    12.0       640.0      1.611116
# 24   2.702212e-07           38.690075    12.0       640.0      1.902169
#
#             D  g_cyl_diameter         g_D
# 0   78.219130       17.696334  150.535088
# 1   78.220382       15.408167   65.471884
# 2   78.222370       13.478227  199.129403
# 3   78.222735        6.465221   51.946102
# 4   78.222160       18.005118  201.396915
# 5   78.224413       10.947785  204.618347
# 6   78.221507       18.253062  205.435697
# 7   78.223991        7.621451  257.716072
# 8   78.222723        3.169772   99.608375
# 9   78.219048       19.914768  139.728499
# 10  78.225189       19.515627  294.341080
# 11  78.218933        8.983278  201.306064
# 12  78.219562       12.425875   37.545488
# 13  78.221157       12.102017  279.306429
# 14  78.217835        9.343802   55.857105
# 15  78.225612       12.701528  225.370076
# 16  78.221755       10.228325   32.347858
# 17  78.222375       13.976332  273.447936
# 18  78.228006        6.771823   71.511893
# 19  78.188623        3.094612  245.875213
# 20  78.181244       15.408293   25.465396
# 21  78.192109        2.438175  165.186139
# 22  78.194000        1.932020  253.862864
# 23  78.202122        1.085248  252.448297
# 24  78.202463        1.896347   77.950304

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/12/2023_08_12_pippin1_halbach12main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[ 12.         640.          20.          78.21912982  17.6963336
#   150.53508828]
#  [ 12.         640.          20.          78.2203824   15.40816667
#    65.47188393]
#  [ 12.         640.          20.          78.22237012  13.47822702
#   199.1294033 ]
#  [ 12.         640.          20.          78.22273498   6.46522121
#    51.94610199]
#  [ 12.         640.          20.          78.2221602   18.0051175
#   201.39691492]
#  [ 12.         640.          20.          78.22441328  10.94778481
#   204.61834653]
#  [ 12.         640.          20.          78.22150707  18.25306243
#   205.4356965 ]
#  [ 12.         640.          20.          78.22399097   7.6214511
#   257.71607185]
#  [ 12.         640.          20.          78.22272312   3.16977175
#    99.60837534]
#  [ 12.         640.          20.          78.21904817  19.91476826
#   139.72849871]
#  [ 12.         640.          20.          78.22518879  19.51562748
#   294.34108011]
#  [ 12.         640.          20.          78.21893326   8.98327804
#   201.30606366]
#  [ 12.         640.          20.          78.2195625   12.4258753
#    37.54548793]
#  [ 12.         640.          20.          78.22115665  12.10201686
#   279.30642917]
#  [ 12.         640.          20.          78.21783529   9.34380169
#    55.85710532]
#  [ 12.         640.          20.          78.22561221  12.70152767
#   225.37007565]
#  [ 12.         640.          20.          78.22175533  10.22832497
#    32.34785805]
#  [ 12.         640.          20.          78.22237526  13.97633201
#   273.44793562]
#  [ 12.         640.          19.99972667  78.22800642   6.77182268
#    71.51189275]
#  [ 12.         640.           5.0122123   78.18862264   3.09461239
#   245.87521337]
#  [ 12.         640.           1.          78.18124444  15.40829279
#    25.46539555]
#  [ 12.         640.           3.5404427   78.19210895   2.4381748
#   165.18613851]
#  [ 12.         640.           3.14040278  78.19399974   1.93202028
#   253.86286446]
#  [ 12.         640.           1.61111649  78.20212152   1.08524752
#   252.44829745]
#  [ 12.         640.           1.90216879  78.20246288   1.89634728
#    77.95030421]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 12
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_99295/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 64
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 67
#          Function evaluations: 171
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 84
#          Function evaluations: 201
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 83
#          Function evaluations: 199
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 67
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 67
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 69
#          Function evaluations: 175
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 64
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 0.001111
#          Iterations: 67
#          Function evaluations: 169
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 74
#          Function evaluations: 151
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 119
#          Function evaluations: 269
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 133
#          Function evaluations: 290
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 129
#          Function evaluations: 297
# [array([20.      , 80.999568]), array([20.        , 81.00085204]), array([20.        , 81.00030128]), array([20.        , 80.99904216]), array([20.        , 80.99579081]), array([20.        , 80.99358807]), array([20.        , 80.99837139]), array([20.        , 80.99744428]), array([20.        , 81.00032744]), array([20.        , 80.99614902]), array([20.        , 80.99773317]), array([20.        , 81.00030621]), array([20.        , 80.99906774]), array([20.        , 81.00170021]), array([20.        , 81.00109956]), array([20.        , 80.99291966]), array([20.        , 80.99835551]), array([20.        , 80.99959423]), array([19.31712772, 80.91709414]), array([ 1.        , 80.86650218]), array([ 1.        , 80.86650218]), array([ 1.19171339, 96.36523153]), array([ 1.21304788, 98.08974114]), array([ 1.20817138, 97.69556869]), array([ 1.16346512, 94.08178402])]
# [0.0011114296798713332, 0.0011114297458194803, 0.0011114297281914944, 0.0011114296232410039, 0.0011114297098735826, 0.0011114298834735991, 0.0011114294748664556, 0.001111429786544852, 0.0011114296769918265, 0.001111429888432806, 0.0011114298265711238, 0.001111429726014255, 0.001111429792214904, 0.0011114297540789524, 0.0011114296755950846, 0.001111429818201133, 0.0011114296817599587, 0.0011114298243963202, 0.0010369617464151698, 5.608577808510156e-18, 7.51861910430159e-18, 1.900447988001705e-18, 2.802753524112976e-17, 2.268952419542451e-19, 5.988193091679591e-19]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 12).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [3986.8668871364894, 3986.740463605772, 3986.7946899378403, 3986.9186617547393, 3987.2388146088642, 3987.455735556378, 3986.9847080634163, 3987.0759968143884, 3986.792114065639, 3987.20354110265, 3987.0475507195824, 3986.794204351786, 3986.9161433677073, 3986.6569580251075, 3986.716094448644, 3987.5215622648648, 3986.986271621006, 3986.864304190492, 3726.8494774424203, 9.999999999979954, 9.999999999973125, 10.00000000000367, 10.000000000050559, 9.999999999999584, 10.000000000001268]
# [2.7947369409480263e-07, 2.794825953544199e-07, 2.794787799842055e-07, 2.794700414492779e-07, 2.7944756693793974e-07, 2.794323701802628e-07, 2.794653629452007e-07, 2.79459026539875e-07, 2.7947894813530145e-07, 2.79450090232161e-07, 2.794610354533047e-07, 2.794788135624476e-07, 2.794702609127006e-07, 2.7948846626964576e-07, 2.794842903536919e-07, 2.794277292536579e-07, 2.7946530509569595e-07, 2.7947391195248654e-07, 2.7898943788509496e-07, 2.797827750164463e-07, 2.797677489959129e-07, 5.178398384923456e-07, 5.543566741096262e-07, 5.458575465370068e-07, 4.721362775964773e-07]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/12/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    2.789894e-07         3726.849477    12.0       640.0
# 1    2.794277e-07         3987.521562    12.0       640.0
# 2    2.794324e-07         3987.455736    12.0       640.0
# 3    2.794476e-07         3987.238815    12.0       640.0
# 4    2.794501e-07         3987.203541    12.0       640.0
# 5    2.794590e-07         3987.075997    12.0       640.0
# 6    2.794610e-07         3987.047551    12.0       640.0
# 7    2.794653e-07         3986.986272    12.0       640.0
# 8    2.794654e-07         3986.984708    12.0       640.0
# 9    2.794700e-07         3986.918662    12.0       640.0
# 10   2.794703e-07         3986.916143    12.0       640.0
# 11   2.794737e-07         3986.866887    12.0       640.0
# 12   2.794739e-07         3986.864304    12.0       640.0
# 13   2.794788e-07         3986.794690    12.0       640.0
# 14   2.794788e-07         3986.794204    12.0       640.0
# 15   2.794789e-07         3986.792114    12.0       640.0
# 16   2.794826e-07         3986.740464    12.0       640.0
# 17   2.794843e-07         3986.716094    12.0       640.0
# 18   2.794885e-07         3986.656958    12.0       640.0
# 19   2.797677e-07           10.000000    12.0       640.0
# 20   2.797828e-07           10.000000    12.0       640.0
# 21   4.721363e-07           10.000000    12.0       640.0
# 22   5.178398e-07           10.000000    12.0       640.0
# 23   5.458575e-07           10.000000    12.0       640.0
# 24   5.543567e-07           10.000000    12.0       640.0
#
#     stage2_cyl_diameter   stage2_D  stage1_cyl_diameter   stage1_D  \
# 0             19.317128  80.917094            19.999727  78.228006
# 1             20.000000  80.992920            20.000000  78.225612
# 2             20.000000  80.993588            20.000000  78.224413
# 3             20.000000  80.995791            20.000000  78.222160
# 4             20.000000  80.996149            20.000000  78.219048
# 5             20.000000  80.997444            20.000000  78.223991
# 6             20.000000  80.997733            20.000000  78.225189
# 7             20.000000  80.998356            20.000000  78.221755
# 8             20.000000  80.998371            20.000000  78.221507
# 9             20.000000  80.999042            20.000000  78.222735
# 10            20.000000  80.999068            20.000000  78.219562
# 11            20.000000  80.999568            20.000000  78.219130
# 12            20.000000  80.999594            20.000000  78.222375
# 13            20.000000  81.000301            20.000000  78.222370
# 14            20.000000  81.000306            20.000000  78.218933
# 15            20.000000  81.000327            20.000000  78.222723
# 16            20.000000  81.000852            20.000000  78.220382
# 17            20.000000  81.001100            20.000000  78.217835
# 18            20.000000  81.001700            20.000000  78.221157
# 19             1.000000  80.866502             1.000000  78.181244
# 20             1.000000  80.866502             5.012212  78.188623
# 21             1.163465  94.081784             1.902169  78.202463
# 22             1.191713  96.365232             3.540443  78.192109
# 23             1.208171  97.695569             1.611116  78.202122
# 24             1.213048  98.089741             3.140403  78.194000
#
#        objective
# 0   1.036962e-03
# 1   1.111430e-03
# 2   1.111430e-03
# 3   1.111430e-03
# 4   1.111430e-03
# 5   1.111430e-03
# 6   1.111430e-03
# 7   1.111430e-03
# 8   1.111429e-03
# 9   1.111430e-03
# 10  1.111430e-03
# 11  1.111430e-03
# 12  1.111430e-03
# 13  1.111430e-03
# 14  1.111430e-03
# 15  1.111430e-03
# 16  1.111430e-03
# 17  1.111430e-03
# 18  1.111430e-03
# 19  7.518619e-18
# 20  5.608578e-18
# 21  5.988193e-19
# 22  1.900448e-18
# 23  2.268952e-19
# 24  2.802754e-17
