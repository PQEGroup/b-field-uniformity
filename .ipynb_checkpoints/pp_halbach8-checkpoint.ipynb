# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 8 main cylinder
# n = 8
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 8
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [9.474490557670881, 230.02135454707255]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 51
#          Function evaluations: 102
# [18.815090106320778, 144.44041183388953]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 32
#          Function evaluations: 64
# [15.9441428920006, 108.28665807680193]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 38
#          Function evaluations: 75
# [4.962398317083652, 178.4955966852865]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 67
#          Function evaluations: 139
# [19.23212266900074, 197.39203668009736]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 35
#          Function evaluations: 64
# [7.51800923837522, 60.596287850031324]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 93
#          Function evaluations: 230
# [3.4756819806798127, 139.6865763435684]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 58
#          Function evaluations: 114
# [10.277654555526377, 195.78698550048753]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 57
#          Function evaluations: 116
# [15.220532288290087, 194.43155160318503]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 52
#          Function evaluations: 101
# [9.83455999821996, 165.3038827468206]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 54
#          Function evaluations: 105
# [17.083030395827592, 125.9512196185661]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 30
#          Function evaluations: 61
# [11.061901570159398, 214.960064077759]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 48
#          Function evaluations: 96
# [5.955074775552616, 42.10623137107639]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 67
#          Function evaluations: 135
# [18.553396153724048, 289.0589632724649]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 43
#          Function evaluations: 90
# [5.358078159582755, 63.639039692166236]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 99
#          Function evaluations: 258
# [7.782999560652776, 60.915200895579964]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 57
#          Function evaluations: 116
# [12.248581245297482, 72.59789846764833]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 50
#          Function evaluations: 101
# [10.249026248915879, 40.42953984398438]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 54
#          Function evaluations: 111
# [10.84914452865686, 29.47598259372005]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 55
#          Function evaluations: 108
# [2.0149691411734407, 44.50749066062838]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 95
#          Function evaluations: 228
# [12.980525786368553, 85.23423445863378]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 52
#          Function evaluations: 100
# [17.014368565655534, 199.1612418646439]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 36
#          Function evaluations: 73
# [14.476220243926909, 118.16880503425018]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 41
#          Function evaluations: 86
# [6.952976918025158, 297.0591850878996]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 57
#          Function evaluations: 113
# [15.037139123296248, 54.43873995037903]
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 73
#          Function evaluations: 189
# Objective function values:
# [1.4664597983847526e-06, 1.4664598150110539e-06, 1.4664598123971907e-06, 1.4664597943832018e-06, 1.4664598047363706e-06, 1.4711087385635832e-06, 1.4664597936473447e-06, 1.4664598058011585e-06, 1.4664597563854197e-06, 1.4664597667080958e-06, 1.4664598462114854e-06, 1.4664598107141241e-06, 1.4664597902328052e-06, 1.466459782439818e-06, 1.4711142859889343e-06, 1.4664598280443812e-06, 1.4664598003787964e-06, 1.4664598128534854e-06, 1.4664597727595269e-06, 1.4711198331891016e-06, 1.4664598224813714e-06, 1.4664597863874645e-06, 1.466459765630688e-06, 1.4664597990764996e-06, 1.4711166883833347e-06]
# Result parameters:
# [array([ 20.        , 120.18872555]), array([ 20.        , 120.18615446]), array([ 20.        , 120.18586413]), array([ 20.        , 120.18752543]), array([ 20.        , 120.18667875]), array([  1.        , 120.14654728]), array([ 20.        , 120.18898058]), array([ 20.        , 120.18832158]), array([ 20.        , 120.18777923]), array([ 20.        , 120.18936319]), array([ 20.        , 120.18880142]), array([ 20.        , 120.19022536]), array([ 20.        , 120.19028788]), array([ 20.        , 120.18656361]), array([  1.26320011, 120.16827244]), array([ 20.        , 120.19156758]), array([ 20.        , 120.18727896]), array([ 20.        , 120.18753116]), array([ 20.        , 120.19084922]), array([  1.        , 120.11501495]), array([ 20.        , 120.18984332]), array([ 20.        , 120.18705861]), array([ 20.        , 120.18765085]), array([ 20.        , 120.18713284]), array([  1.        , 120.13783637])]
# Starting guesses:
# [[9.474490557670881, 230.02135454707255], [18.815090106320778, 144.44041183388953], [15.9441428920006, 108.28665807680193], [4.962398317083652, 178.4955966852865], [19.23212266900074, 197.39203668009736], [7.51800923837522, 60.596287850031324], [3.4756819806798127, 139.6865763435684], [10.277654555526377, 195.78698550048753], [15.220532288290087, 194.43155160318503], [9.83455999821996, 165.3038827468206], [17.083030395827592, 125.9512196185661], [11.061901570159398, 214.960064077759], [5.955074775552616, 42.10623137107639], [18.553396153724048, 289.0589632724649], [5.358078159582755, 63.639039692166236], [7.782999560652776, 60.915200895579964], [12.248581245297482, 72.59789846764833], [10.249026248915879, 40.42953984398438], [10.84914452865686, 29.47598259372005], [2.0149691411734407, 44.50749066062838], [12.980525786368553, 85.23423445863378], [17.014368565655534, 199.1612418646439], [14.476220243926909, 118.16880503425018], [6.952976918025158, 297.0591850878996], [15.037139123296248, 54.43873995037903]]

# %%
print(results_x)
# Out:
# [array([ 20.        , 120.18872555]), array([ 20.        , 120.18615446]), array([ 20.        , 120.18586413]), array([ 20.        , 120.18752543]), array([ 20.        , 120.18667875]), array([  1.        , 120.14654728]), array([ 20.        , 120.18898058]), array([ 20.        , 120.18832158]), array([ 20.        , 120.18777923]), array([ 20.        , 120.18936319]), array([ 20.        , 120.18880142]), array([ 20.        , 120.19022536]), array([ 20.        , 120.19028788]), array([ 20.        , 120.18656361]), array([  1.26320011, 120.16827244]), array([ 20.        , 120.19156758]), array([ 20.        , 120.18727896]), array([ 20.        , 120.18753116]), array([ 20.        , 120.19084922]), array([  1.        , 120.11501495]), array([ 20.        , 120.18984332]), array([ 20.        , 120.18705861]), array([ 20.        , 120.18765085]), array([ 20.        , 120.18713284]), array([  1.        , 120.13783637])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), n).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
print(results_g_center)
# Out:
# [1206.7803632559248, 1206.8320401042715, 1206.837875686692, 1206.8044843763723, 1206.8215019706256, 3.019068300712596, 1206.7752374621793, 1206.7884825601582, 1206.7993832077275, 1206.767547682766, 1206.7788384641362, 1206.7502198170646, 1206.7489632977868, 1206.8238164299944, 4.815707167056802, 1206.723244526237, 1206.8094381588303, 1206.8043691926225, 1206.7376816115213, 3.020654981718071, 1206.7578980641144, 1206.8138669908124, 1206.8019634718312, 1206.8123750986986, 3.0195065019296297]

# %%
print(results_fun)
# Out:
# [1.4664597983847526e-06, 1.4664598150110539e-06, 1.4664598123971907e-06, 1.4664597943832018e-06, 1.4664598047363706e-06, 1.4711087385635832e-06, 1.4664597936473447e-06, 1.4664598058011585e-06, 1.4664597563854197e-06, 1.4664597667080958e-06, 1.4664598462114854e-06, 1.4664598107141241e-06, 1.4664597902328052e-06, 1.466459782439818e-06, 1.4711142859889343e-06, 1.4664598280443812e-06, 1.4664598003787964e-06, 1.4664598128534854e-06, 1.4664597727595269e-06, 1.4711198331891016e-06, 1.4664598224813714e-06, 1.4664597863874645e-06, 1.466459765630688e-06, 1.4664597990764996e-06, 1.4711166883833347e-06]

# %%
import pandas as pd
n=8
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime 
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0        0.000001         1206.799383     8.0       640.0       20.0000
# 1        0.000001         1206.801963     8.0       640.0       20.0000
# 2        0.000001         1206.767548     8.0       640.0       20.0000
# 3        0.000001         1206.737682     8.0       640.0       20.0000
# 4        0.000001         1206.823816     8.0       640.0       20.0000
# 5        0.000001         1206.813867     8.0       640.0       20.0000
# 6        0.000001         1206.748963     8.0       640.0       20.0000
# 7        0.000001         1206.775237     8.0       640.0       20.0000
# 8        0.000001         1206.804484     8.0       640.0       20.0000
# 9        0.000001         1206.780363     8.0       640.0       20.0000
# 10       0.000001         1206.812375     8.0       640.0       20.0000
# 11       0.000001         1206.809438     8.0       640.0       20.0000
# 12       0.000001         1206.821502     8.0       640.0       20.0000
# 13       0.000001         1206.788483     8.0       640.0       20.0000
# 14       0.000001         1206.750220     8.0       640.0       20.0000
# 15       0.000001         1206.837876     8.0       640.0       20.0000
# 16       0.000001         1206.804369     8.0       640.0       20.0000
# 17       0.000001         1206.832040     8.0       640.0       20.0000
# 18       0.000001         1206.757898     8.0       640.0       20.0000
# 19       0.000001         1206.723245     8.0       640.0       20.0000
# 20       0.000001         1206.778838     8.0       640.0       20.0000
# 21       0.000001            3.019068     8.0       640.0        1.0000
# 22       0.000001            4.815707     8.0       640.0        1.2632
# 23       0.000001            3.019507     8.0       640.0        1.0000
# 24       0.000001            3.020655     8.0       640.0        1.0000
#
#              D  g_cyl_diameter         g_D
# 0   120.187779       15.220532  194.431552
# 1   120.187651       14.476220  118.168805
# 2   120.189363        9.834560  165.303883
# 3   120.190849       10.849145   29.475983
# 4   120.186564       18.553396  289.058963
# 5   120.187059       17.014369  199.161242
# 6   120.190288        5.955075   42.106231
# 7   120.188981        3.475682  139.686576
# 8   120.187525        4.962398  178.495597
# 9   120.188726        9.474491  230.021355
# 10  120.187133        6.952977  297.059185
# 11  120.187279       12.248581   72.597898
# 12  120.186679       19.232123  197.392037
# 13  120.188322       10.277655  195.786986
# 14  120.190225       11.061902  214.960064
# 15  120.185864       15.944143  108.286658
# 16  120.187531       10.249026   40.429540
# 17  120.186154       18.815090  144.440412
# 18  120.189843       12.980526   85.234234
# 19  120.191568        7.783000   60.915201
# 20  120.188801       17.083030  125.951220
# 21  120.146547        7.518009   60.596288
# 22  120.168272        5.358078   63.639040
# 23  120.137836       15.037139   54.438740
# 24  120.115015        2.014969   44.507491

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/2023_08_08_pippin1_halbach8main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[  8.         640.          20.         120.18777923  15.22053229
#   194.4315516 ]
#  [  8.         640.          20.         120.18765085  14.47622024
#   118.16880503]
#  [  8.         640.          20.         120.18936319   9.83456
#   165.30388275]
#  [  8.         640.          20.         120.19084922  10.84914453
#    29.47598259]
#  [  8.         640.          20.         120.18656361  18.55339615
#   289.05896327]
#  [  8.         640.          20.         120.18705861  17.01436857
#   199.16124186]
#  [  8.         640.          20.         120.19028788   5.95507478
#    42.10623137]
#  [  8.         640.          20.         120.18898058   3.47568198
#   139.68657634]
#  [  8.         640.          20.         120.18752543   4.96239832
#   178.49559669]
#  [  8.         640.          20.         120.18872555   9.47449056
#   230.02135455]
#  [  8.         640.          20.         120.18713284   6.95297692
#   297.05918509]
#  [  8.         640.          20.         120.18727896  12.24858125
#    72.59789847]
#  [  8.         640.          20.         120.18667875  19.23212267
#   197.39203668]
#  [  8.         640.          20.         120.18832158  10.27765456
#   195.7869855 ]
#  [  8.         640.          20.         120.19022536  11.06190157
#   214.96006408]
#  [  8.         640.          20.         120.18586413  15.94414289
#   108.28665808]
#  [  8.         640.          20.         120.18753116  10.24902625
#    40.42953984]
#  [  8.         640.          20.         120.18615446  18.81509011
#   144.44041183]
#  [  8.         640.          20.         120.18984332  12.98052579
#    85.23423446]
#  [  8.         640.          20.         120.19156758   7.78299956
#    60.9152009 ]
#  [  8.         640.          20.         120.18880142  17.0830304
#   125.95121962]
#  [  8.         640.           1.         120.14654728   7.51800924
#    60.59628785]
#  [  8.         640.           1.26320011 120.16827244   5.35807816
#    63.63903969]
#  [  8.         640.           1.         120.13783637  15.03713912
#    54.43873995]
#  [  8.         640.           1.         120.11501495   2.01496914
#    44.50749066]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 8
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 60
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 67
#          Function evaluations: 173
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_69391/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 63
#          Function evaluations: 168
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 61
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 59
#          Function evaluations: 146
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 56
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 59
#          Function evaluations: 160
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 64
#          Function evaluations: 159
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 92
#          Function evaluations: 213
# Optimization terminated successfully.
#          Current function value: 0.001673
#          Iterations: 63
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 130
#          Function evaluations: 289
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 128
#          Function evaluations: 285
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 132
#          Function evaluations: 290
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 132
#          Function evaluations: 301
# [array([ 20.        , 126.25869619]), array([ 20.        , 126.25939516]), array([ 20.        , 126.26191903]), array([ 20.        , 126.26270078]), array([ 20.       , 126.2617404]), array([ 20.        , 126.26096523]), array([ 20.        , 126.25848894]), array([ 20.        , 126.26226208]), array([ 20.        , 126.25778771]), array([ 20.        , 126.25987372]), array([ 20.        , 126.26251025]), array([ 20.       , 126.2553281]), array([ 20.        , 126.26056608]), array([ 20.        , 126.26174462]), array([ 20.        , 126.26062401]), array([ 20.        , 126.26026046]), array([ 20.        , 126.26182835]), array([ 20.        , 126.26093224]), array([ 20.        , 126.26086742]), array([ 20.        , 126.26276475]), array([ 20.        , 126.26068766]), array([  1.65841514, 109.4888805 ]), array([  1.55987832, 102.98681801]), array([  1.6446827 , 108.58279313]), array([  1.67340955, 110.47820942])]
# [0.001673048997081334, 0.0016730489969148175, 0.0016730489500415033, 0.0016730489847984339, 0.0016730489636638806, 0.0016730489703646017, 0.001673049040573351, 0.0016730489595326735, 0.0016730490129050145, 0.001673049011955882, 0.0016730489613900614, 0.001673049069227014, 0.0016730489822107742, 0.0016730489690409335, 0.0016730489604780499, 0.0016730489655813019, 0.0016730489625174118, 0.0016730489499843558, 0.0016730489545737346, 0.0016730489850277233, 0.001673049005465486, 1.2472091479879068e-17, 9.371729757459194e-18, 7.048415023667677e-18, 3.235949102114762e-19]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), n).flatten()

# %%
import datetime
import pandas as pd

# %%
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [1093.4347732300719, 1093.422654305789, 1093.3788965392573, 1093.3653433342574, 1093.3819934891246, 1093.3954328159393, 1093.4383667332004, 1093.3729490124342, 1093.450524993235, 1093.4143570694666, 1093.3686466526585, 1093.4931728503468, 1093.4023530240502, 1093.3819203228543, 1093.4013487544257, 1093.4076518074096, 1093.3804686769329, 1093.3960047211244, 1093.3971286031979, 1093.364234404749, 1093.4002451153933, 9.999999999993069, 9.99999999999623, 10.000000000003777, 9.999999999999813]
# [1.544208325613761e-06, 1.544225598630145e-06, 1.5442879267686369e-06, 1.5443072783271024e-06, 1.5442835248495157e-06, 1.5442643744731754e-06, 1.5442032439906605e-06, 1.5442964133983295e-06, 1.5441858897206784e-06, 1.5442374388330254e-06, 1.5443025479455857e-06, 1.5441251603143208e-06, 1.5442545214535218e-06, 1.5442836341060177e-06, 1.5442559328558482e-06, 1.5442469533884268e-06, 1.544285697305034e-06, 1.5442635404724547e-06, 1.5442619427381748e-06, 1.5443088592886536e-06, 1.5442575474840224e-06, 1.799375529898581e-06, 2.486246385692166e-06, 1.8663710767957639e-06, 1.7349308536278493e-06]

# %%
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/8/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0        0.000002         1093.493173     8.0       640.0
# 1        0.000002         1093.450525     8.0       640.0
# 2        0.000002         1093.438367     8.0       640.0
# 3        0.000002         1093.434773     8.0       640.0
# 4        0.000002         1093.422654     8.0       640.0
# 5        0.000002         1093.414357     8.0       640.0
# 6        0.000002         1093.407652     8.0       640.0
# 7        0.000002         1093.402353     8.0       640.0
# 8        0.000002         1093.401349     8.0       640.0
# 9        0.000002         1093.400245     8.0       640.0
# 10       0.000002         1093.397129     8.0       640.0
# 11       0.000002         1093.396005     8.0       640.0
# 12       0.000002         1093.395433     8.0       640.0
# 13       0.000002         1093.381993     8.0       640.0
# 14       0.000002         1093.381920     8.0       640.0
# 15       0.000002         1093.380469     8.0       640.0
# 16       0.000002         1093.378897     8.0       640.0
# 17       0.000002         1093.372949     8.0       640.0
# 18       0.000002         1093.368647     8.0       640.0
# 19       0.000002         1093.365343     8.0       640.0
# 20       0.000002         1093.364234     8.0       640.0
# 21       0.000002           10.000000     8.0       640.0
# 22       0.000002           10.000000     8.0       640.0
# 23       0.000002           10.000000     8.0       640.0
# 24       0.000002           10.000000     8.0       640.0
#
#     stage2_cyl_diameter    stage2_D  stage1_cyl_diameter    stage1_D  \
# 0             20.000000  126.255328              20.0000  120.187279
# 1             20.000000  126.257788              20.0000  120.187525
# 2             20.000000  126.258489              20.0000  120.190288
# 3             20.000000  126.258696              20.0000  120.187779
# 4             20.000000  126.259395              20.0000  120.187651
# 5             20.000000  126.259874              20.0000  120.188726
# 6             20.000000  126.260260              20.0000  120.185864
# 7             20.000000  126.260566              20.0000  120.186679
# 8             20.000000  126.260624              20.0000  120.190225
# 9             20.000000  126.260688              20.0000  120.188801
# 10            20.000000  126.260867              20.0000  120.189843
# 11            20.000000  126.260932              20.0000  120.186154
# 12            20.000000  126.260965              20.0000  120.187059
# 13            20.000000  126.261740              20.0000  120.186564
# 14            20.000000  126.261745              20.0000  120.188322
# 15            20.000000  126.261828              20.0000  120.187531
# 16            20.000000  126.261919              20.0000  120.189363
# 17            20.000000  126.262262              20.0000  120.188981
# 18            20.000000  126.262510              20.0000  120.187133
# 19            20.000000  126.262701              20.0000  120.190849
# 20            20.000000  126.262765              20.0000  120.191568
# 21             1.673410  110.478209               1.0000  120.115015
# 22             1.658415  109.488880               1.0000  120.146547
# 23             1.644683  108.582793               1.0000  120.137836
# 24             1.559878  102.986818               1.2632  120.168272
#
#        objective
# 0   1.673049e-03
# 1   1.673049e-03
# 2   1.673049e-03
# 3   1.673049e-03
# 4   1.673049e-03
# 5   1.673049e-03
# 6   1.673049e-03
# 7   1.673049e-03
# 8   1.673049e-03
# 9   1.673049e-03
# 10  1.673049e-03
# 11  1.673049e-03
# 12  1.673049e-03
# 13  1.673049e-03
# 14  1.673049e-03
# 15  1.673049e-03
# 16  1.673049e-03
# 17  1.673049e-03
# 18  1.673049e-03
# 19  1.673049e-03
# 20  1.673049e-03
# 21  3.235949e-19
# 22  1.247209e-17
# 23  7.048415e-18
# 24  9.371730e-18
