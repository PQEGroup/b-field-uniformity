# %%
import numpy as np
import magpylib as magpy
from magpylib.magnet import Cuboid, Cylinder, CylinderSegment
from maggeometry import halbach_cylinder
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %% [markdown]
# ### Nelder-Mead Adaptive Optimization of Halbach 9 main
# n = 9
#
# ### Pippin 1

# %%
# def halbach_cylinder(Br, c_d, c_h, D, n, alternate=False):

# %%
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n = 9
c_h = 640
          #c_d,     D
bounds = ((1, 20), (21, 300))

def obj1_nonuniformity(x):
    magnets = halbach_cylinder(Br, x[0], c_h, x[1], n)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    return av_nonuniformity

# %%
import numpy as np
from scipy.optimize import minimize, Bounds
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_grid
from alive_progress import alive_bar

options = {'disp': True, 'fatol': 1e-12, 'maxiter': 5e3, 'adaptive': True}
method = "Nelder-Mead"

shots = 25
results_x = []
results_fun = []
guesses_x0 = []
b_len = len(bounds)
for i in range(shots):
    x0 = [0, 0]
    for b in range(b_len):
        x0[b] = np.random.uniform(low=bounds[b][0], high=bounds[b][1])
    print(x0)
    res = minimize(obj1_nonuniformity, x0, method=method, options=options, bounds=bounds)
    guesses_x0.append(x0)
    results_x.append(res.x)
    results_fun.append(res.fun)

print("Objective function values:")
print(results_fun)
print("Result parameters:")
print(results_x)
print("Starting guesses:")
print(guesses_x0)
# Out:
# [2.7000510921819596, 97.43632649359748]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 48
#          Function evaluations: 122
# [5.679328330958482, 120.72900456141744]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 60
#          Function evaluations: 119
# [15.433210684059935, 65.28749915783507]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 40
#          Function evaluations: 83
# [1.6291923470105645, 45.98559947827238]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 93
#          Function evaluations: 244
# [16.785908578080036, 249.2987792506442]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 41
#          Function evaluations: 85
# [3.082970095856048, 185.4931617272502]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 44
#          Function evaluations: 97
# [14.531143981912969, 212.24631398586178]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 38
#          Function evaluations: 81
# [12.60566206085765, 71.19480892971524]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 97
# [18.441440464236113, 182.1825667750872]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 96
# [4.958774249897534, 259.98841886625615]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 42
#          Function evaluations: 97
# [19.35591199542167, 291.28337463276836]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 46
#          Function evaluations: 93
# [15.501960893844895, 278.5132808179894]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 45
#          Function evaluations: 99
# [6.51366022216731, 37.27165437630104]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 63
#          Function evaluations: 124
# [16.937326289845842, 295.7976520678546]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 87
# [16.72389300970552, 293.2484514999234]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 43
#          Function evaluations: 88
# [3.4867945179609943, 23.426387065926026]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 51
#          Function evaluations: 120
# [10.29396369212085, 25.57777126066368]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 77
#          Function evaluations: 190
# [5.5110957195271855, 123.24845807080415]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 35
#          Function evaluations: 81
# [7.628613263555302, 143.70719621658543]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 59
#          Function evaluations: 122
# [14.698109830739977, 72.36254777970728]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations:
# [array([ 3.79010159, 56.13758569]), array([20.        , 56.11776391]), array([20.        , 56.12185334]), array([ 1.62226497, 56.11014299]), array([20.        , 56.12025687]), array([ 4.96529007, 56.13548307]), array([20.        , 56.12294515]), array([19.99879992, 56.12823989]), array([20.        , 56.12323205]), array([ 8.25368876, 56.11180629]), array([20.        , 56.12019049]), array([20.        , 56.11527386]), array([20.        , 56.12009573]), array([20.        , 56.12328628]), array([20.       , 56.1200595]), array([ 2.68033299, 56.11851309]), array([ 1.        , 56.12781919]), array([ 8.34558235, 56.11111674]), array([20.        , 56.12197757]), array([20.        , 56.12642299]), array([20.        , 56.12275698]), array([20.        , 56.11898586]), array([20.       , 56.1208093]), array([20.       , 56.1209107]), array([20.       , 56.1160253])]

# %%
c_h = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 9).flatten()

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results_g_center = []
results_nonun = []
for x in results_x:
    magnets = halbach_cylinder(Br, x[0], c_h[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results_g_center.append(center_field)
    results_nonun.append(av_nonuniformity)
print(results_g_center)
# Out:
# [223.57525429129905, 6230.010886534991, 6229.10295517604, 41.0006119965972, 6229.457377787717, 383.7459601633126, 6228.860586855872, 6226.938065650813, 6228.796900663543, 1061.2487510733363, 6229.472116292522, 6230.563821821878, 6229.493154463415, 6228.784863308592, 6229.501196693827, 111.89088251075354, 15.569446129491114, 1085.038089883455, 6229.075377364767, 6228.0886417113215, 6228.902357554399, 6229.739568699517, 6229.334733649903, 6229.312221174438, 6230.396950903195]

# %%
print(results_fun)
print(results_nonun)
# Out:
# [4.667109136247317e-08, 4.6509281716138064e-08, 4.6509277690546795e-08, 4.6697203891585186e-08, 4.6509235533793164e-08, 4.6509341554141656e-08, 4.669464029679305e-08, 4.6509272812305944e-08, 4.669656098205972e-08, 4.650926759193496e-08, 0.11417449445200617, 4.6667765961158566e-08, 4.66924300707056e-08, 4.6509195799841105e-08, 4.669534437596689e-08, 4.6658816022715904e-08, 4.6509251765984454e-08, 4.668277327067187e-08, 4.669089710640207e-08, 4.650926716054473e-08, 4.65092513068992e-08, 4.669395935451796e-08, 4.6509262995343646e-08, 4.6509329268187796e-08, 4.650927032043707e-08]
# [4.667109136247317e-08, 4.6509281716138064e-08, 4.6509277690546795e-08, 4.6697203891585186e-08, 4.6509235533793164e-08, 4.6509341554141656e-08, 4.669464029679305e-08, 4.6509272812305944e-08, 4.669656098205972e-08, 4.650926759193496e-08, 0.11417449445200617, 4.6667765961158566e-08, 4.66924300707056e-08, 4.6509195799841105e-08, 4.669534437596689e-08, 4.6658816022715904e-08, 4.6509251765984454e-08, 4.668277327067187e-08, 4.669089710640207e-08, 4.650926716054473e-08, 4.65092513068992e-08, 4.669395935451796e-08, 4.6509262995343646e-08, 4.6509329268187796e-08, 4.650927032043707e-08]

# %%
import pandas as pd
def make_opt_res_halbach_csv(name, fun, g_center, r_n, r_ch, x, guesses):
    r_f = np.array([fun])
    r_g = np.array(guesses)
    r_gc = np.array([g_center])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_g), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('cyl_diameter')
    columns.append('D')
    columns.append('g_cyl_diameter')
    columns.append('g_D')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    
    c = np.concatenate((r_f.T, r_x), axis=1)
    new_array = [tuple(row) for row in c]
    u = np.unique(new_array, axis=0)
    n_unique = len(u)
    print('Number of unique results:', n_unique)
    print(b_df)
    b_df.to_csv(name + str(n_unique) + '.csv')
    return b, b_df

import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b, b_df = make_opt_res_halbach_csv(f'results/halbach/pippin/run1/9/{today}_pippin1_halbach{n}main_1090mT_', results_fun, results_g_center, r_n, c_h, results_x, guesses_x0)
# Out:
# Number of unique results: 25
#     nonuniformity  center_field_gauss  n_rods  cyl_height  cyl_diameter  \
# 0    7.020790e-08         6229.075377     9.0       640.0     20.000000
# 1    7.020793e-08         6229.739569     9.0       640.0     20.000000
# 2    7.020793e-08         6228.902358     9.0       640.0     20.000000
# 3    7.020794e-08         6228.796901     9.0       640.0     20.000000
# 4    7.020794e-08         6229.457378     9.0       640.0     20.000000
# 5    7.020795e-08         6229.312221     9.0       640.0     20.000000
# 6    7.020796e-08         6228.784863     9.0       640.0     20.000000
# 7    7.020796e-08         6229.102955     9.0       640.0     20.000000
# 8    7.020796e-08         6229.493154     9.0       640.0     20.000000
# 9    7.020797e-08         6229.472116     9.0       640.0     20.000000
# 10   7.020797e-08         6230.396951     9.0       640.0     20.000000
# 11   7.020797e-08         6228.860587     9.0       640.0     20.000000
# 12   7.020797e-08         6229.501197     9.0       640.0     20.000000
# 13   7.020797e-08         6230.010887     9.0       640.0     20.000000
# 14   7.020798e-08         6229.334734     9.0       640.0     20.000000
# 15   7.020799e-08         6228.088642     9.0       640.0     20.000000
# 16   7.020800e-08         6230.563822     9.0       640.0     20.000000
# 17   7.020801e-08         6226.938066     9.0       640.0     19.998800
# 18   7.044712e-08         1085.038090     9.0       640.0      8.345582
# 19   7.044843e-08         1061.248751     9.0       640.0      8.253689
# 20   7.045911e-08           15.569446     9.0       640.0      1.000000
# 21   7.047926e-08          383.745960     9.0       640.0      4.965290
# 22   7.048297e-08           41.000612     9.0       640.0      1.622265
# 23   7.048631e-08          223.575254     9.0       640.0      3.790102
# 24   7.048823e-08          111.890883     9.0       640.0      2.680333
#
#             D  g_cyl_diameter         g_D
# 0   56.121978        7.628613  143.707196
# 1   56.118986       16.227038  199.560554
# 2   56.122757       18.855129  155.477832
# 3   56.123232       18.441440  182.182567
# 4   56.120257       16.785909  249.298779
# 5   56.120911       17.233275  121.267817
# 6   56.123286       16.937326  295.797652
# 7   56.121853       15.433211   65.287499
# 8   56.120096        6.513660   37.271654
# 9   56.120190       19.355912  291.283375
# 10  56.116025       18.087646   94.580089
# 11  56.122945       14.531144  212.246314
# 12  56.120060       16.723893  293.248451
# 13  56.117764        5.679328  120.729005
# 14  56.120809       16.386591  256.631121
# 15  56.126423       14.698110   72.362548
# 16  56.115274       15.501961  278.513281
# 17  56.128240       12.605662   71.194809
# 18  56.111117        5.511096  123.248458
# 19  56.111806        4.958774  259.988419
# 20  56.127819       10.293964   25.577771
# 21  56.135483        3.082970  185.493162
# 22  56.110143        1.629192   45.985599
# 23  56.137586        2.700051   97.436326
# 24  56.118513        3.486795   23.426387

# %%
st1 = pd.read_csv(f'results/halbach/pippin/run1/9/2023_08_13_pippin1_halbach9main_1090mT_25.csv')
st1 = np.delete(st1.to_numpy(), [0,1,2], axis=1) #remove first column of indices
print (st1)
# Out:
# [[  9.         640.          20.          56.12197757   7.62861326
#   143.70719622]
#  [  9.         640.          20.          56.11898586  16.22703828
#   199.56055378]
#  [  9.         640.          20.          56.12275698  18.85512857
#   155.47783203]
#  [  9.         640.          20.          56.12323205  18.44144046
#   182.18256678]
#  [  9.         640.          20.          56.12025687  16.78590858
#   249.29877925]
#  [  9.         640.          20.          56.1209107   17.23327496
#   121.26781745]
#  [  9.         640.          20.          56.12328628  16.93732629
#   295.79765207]
#  [  9.         640.          20.          56.12185334  15.43321068
#    65.28749916]
#  [  9.         640.          20.          56.12009573   6.51366022
#    37.27165438]
#  [  9.         640.          20.          56.12019049  19.355912
#   291.28337463]
#  [  9.         640.          20.          56.1160253   18.08764634
#    94.58008944]
#  [  9.         640.          20.          56.12294515  14.53114398
#   212.24631399]
#  [  9.         640.          20.          56.1200595   16.72389301
#   293.2484515 ]
#  [  9.         640.          20.          56.11776391   5.67932833
#   120.72900456]
#  [  9.         640.          20.          56.1208093   16.38659145
#   256.63112112]
#  [  9.         640.          20.          56.12642299  14.69810983
#    72.36254778]
#  [  9.         640.          20.          56.11527386  15.50196089
#   278.51328082]
#  [  9.         640.          19.99879992  56.12823989  12.60566206
#    71.19480893]
#  [  9.         640.           8.34558235  56.11111674   5.51109572
#   123.24845807]
#  [  9.         640.           8.25368876  56.11180629   4.95877425
#   259.98841887]
#  [  9.         640.           1.          56.12781919  10.29396369
#    25.57777126]
#  [  9.         640.           4.96529007  56.13548307   3.0829701
#   185.49316173]
#  [  9.         640.           1.62226497  56.11014299   1.62919235
#    45.98559948]
#  [  9.         640.           3.79010159  56.13758569   2.70005109
#    97.43632649]
#  [  9.         640.           2.68033299  56.11851309   3.48679452
#    23.42638707]]

# %%
field_strength_target = 10
dist1 = 0

grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
Br = 1.09e3
n_rods = 9
c_h = 640
def product_nonuniformity(x):
    #x -> n_rods, c_h, c_d, D
    c_d, D = x
    magnets = halbach_cylinder(Br, c_d, c_h, D, n_rods)
    grid_field, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_nonuniformity(magnets, grid, grid_res)
    cost = av_nonuniformity*np.abs(np.abs(center_field) - field_strength_target)
    return cost

# %%
results2_x = []
results2_fun = []
method2 = 'Nelder-Mead'
bounds2 = ((1, 20), (21, 300))
options2 = {'disp': True, 'fatol': 1e-18, 'maxiter': 5e3, 'adaptive': True}
for s0 in st1:
    res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
    results2_x.append(res2.x)
    results2_fun.append(res2.fun)
        
print(results2_x)
print(results2_fun)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 61
#          Function evaluations: 170
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 62
#          Function evaluations: 166
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 63
#          Function evaluations: 161
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 62
#          Function evaluations: 170
# /var/folders/06/7pjfbw510cz2ch1m7lx8vvl80000gn/T/ipykernel_7637/2015679465.py:7: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res2 = minimize(product_nonuniformity, s0[2:4], method=method2, options=options2, bounds=bounds2)
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 59
#          Function evaluations: 158
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 58
#          Function evaluations: 157
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 65
#          Function evaluations: 174
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 60
#          Function evaluations: 163
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 57
#          Function evaluations: 152
# Optimization terminated successfully.
#          Current function value: 0.000427
#          Iterations: 62
#          Function evaluations: 165
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 116
#          Function evaluations: 232
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 79
#          Function evaluations: 162
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 86
#          Function evaluations: 181
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 52
#          Function evaluations: 95
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 91
#          Function evaluations: 187
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 72
#          Function evaluations: 148
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 84
#          Function evaluations: 176
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 83
#          Function evaluations: 168
# [array([20.        , 57.51612093]), array([20.        , 57.52266696]), array([20.        , 57.51657716]), array([20.        , 57.52376514]), array([20.        , 57.53422428]), array([20.        , 57.51297235]), array([20.        , 57.52328415]), array([20.        , 57.52078919]), array([20.        , 57.51008198]), array([20.        , 57.51625353]), array([20.        , 57.52199777]), array([20.        , 57.52601878]), array([20.        , 57.52032076]), array([20.        , 57.51659781]), array([20.        , 57.51194446]), array([20.        , 57.51863208]), array([20.        , 57.51644287]), array([ 1.        , 70.03385924]), array([ 1.        , 70.03385924]), array([ 1.        , 70.03385924]), array([ 1.        , 70.03385924]), array([ 1.        , 70.03385924]), array([ 1.        , 70.03385923]), array([ 1.        , 70.03385924]), array([ 1.        , 70.03385924])]
# [0.0004265756643804721, 0.00042657545964700606, 0.00042657568205635833, 0.00042657564189833435, 0.00042657592172231544, 0.0004265753786298943, 0.00042657544023788895, 0.00042657561959840904, 0.0004265758617126548, 0.0004265755631771934, 0.000426575721467558, 0.00042657579734052786, 0.0004265757225588623, 0.0004265756067322866, 0.0004265753803865044, 0.00042657550772287405, 0.00042657575484246734, 1.3822939285807962e-19, 4.685913267604188e-18, 1.1437135124106317e-17, 1.6608758297956677e-17, 8.784916522492671e-19, 7.189374366871465e-21, 1.7464878018998963e-18, 3.685451956640128e-19]

# %%
r_ch = np.full((1, shots), 640).flatten()
r_n = np.full((1, shots), 9).flatten()

# %%
import pandas as pd
def make_opt_res2_halbach_csv(name, nonun, g_center, r_n, r_ch, x, stage1, objective):
    r_f = np.array([nonun])
    r_gc = np.array([g_center])
    r_obj = np.array([objective])
    r_n = np.array([r_n])
    r_ch = np.array([r_ch])
    r_x = np.array(x)
    r_s1 = np.array(stage1)

    a = np.concatenate((r_f.T, r_gc.T, r_n.T, r_ch.T, r_x, r_s1, r_obj.T), axis=1)
    b = a[a[:, 0].argsort()]

    columns = ['nonuniformity', 'center_field_gauss', 'n_rods', 'cyl_height']

    columns.append('stage2_cyl_diameter')
    columns.append('stage2_D')
    columns.append('stage1_cyl_diameter')
    columns.append('stage1_D')
    columns.append('objective')
    
    
    columns = np.array(columns)
    b_df = pd.DataFrame(b, columns = columns)
    b_df.to_csv(name + '.csv')
    return b_df

# %%
from maggeometry import halbach_cylinder
from maghelper import get_field_on_axes, get_nonuniformity, make_flux_stream, centered_sweep_range, get_grid_nonuniformity, make_xy_grid, get_grid_mag_and_nonuniformity
grid_res = 101
grid = make_xy_grid([-10, 10], [-10, 10], grid_res)
results2_g_center = []
results2_nonun = []
for x in results2_x:
    magnets = halbach_cylinder(Br, x[0], r_ch[0], x[1], n)
    Gmag, Gnon, center_field, av_nonuniformity, max_abs_nonuniformity = get_grid_mag_and_nonuniformity(magnets, grid, grid_res)
    results2_g_center.append(center_field)
    results2_nonun.append(av_nonuniformity)
print(results2_g_center)
print(results2_nonun)
# Out:
# [5930.746620692204, 5929.396805215763, 5930.652530463474, 5929.170401610522, 5927.014768184983, 5931.3960333018695, 5929.269562258924, 5929.783962244011, 5931.992282913042, 5930.719274194554, 5929.53477376236, 5928.705826977612, 5929.880548242363, 5930.648270339061, 5931.6080647554245, 5930.2287586716, 5930.680226078119, 10.000000000000922, 9.999999999968743, 9.99999999992372, 10.000000000110774, 9.999999999994142, 9.999999999999952, 9.999999999988352, 9.999999999997542]
# [7.204761353739547e-08, 7.206400815555011e-08, 7.204876149402498e-08, 7.206679533710825e-08, 7.209309735307043e-08, 7.203966365884647e-08, 7.20655539929657e-08, 7.205932215078795e-08, 7.203249199487662e-08, 7.20479292163745e-08, 7.206237276589786e-08, 7.207247831040774e-08, 7.205816385695728e-08, 7.204880061349391e-08, 7.203708447464142e-08, 7.205388931940367e-08, 7.204843675961077e-08, 1.499349330846092e-07, 1.4991672287645406e-07, 1.4993560349748272e-07, 1.499342480792261e-07, 1.4995355813060534e-07, 1.4989844314661725e-07, 1.49944368877602e-07, 1.49907876251954e-07]

# %%
import datetime
today = datetime.datetime.today().strftime('%Y_%m_%d')

b_df = make_opt_res2_halbach_csv(f'results/halbach/pippin/run1/9/{today}_pippin2_halbach{n}main_1090mT_25', results2_nonun, results2_g_center, r_n, r_ch, results2_x, st1[:, 2:4], results2_fun)
print(b_df)
# Out:
#     nonuniformity  center_field_gauss  n_rods  cyl_height  \
# 0    7.203249e-08         5931.992283     9.0       640.0
# 1    7.203708e-08         5931.608065     9.0       640.0
